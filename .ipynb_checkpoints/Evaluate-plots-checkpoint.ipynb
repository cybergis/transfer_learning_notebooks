# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools
import os
import pickle
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.metrics import confusion_matrix

"""
plot_history(): reads Keras result and ogenerate figure of Loss, Dice Coefficient, and Accuracy.
"""
def plot_history(history):
    loss_list = [s for s in history.keys() if 'loss' in s and 'val' not in s]
    val_loss_list = [s for s in history.keys() if 'loss' in s and 'val' in s]
    dice_list = [s for s in history.keys() if 'dice' in s and 'val' not in s]
    val_dice_list = [s for s in history.keys() if 'dice' in s and 'val' in s]
    acc_list = [s for s in history.keys() if 'acc' in s and 'val' not in s]
    val_acc_list = [s for s in history.keys() if 'acc' in s and 'val' in s]
    
    if len(loss_list) == 0:
        print('Loss is missing in history')
        return 
    
    ## As loss always exists
    epochs = range(1,len(history[loss_list[0]]) + 1)
    
    ## Loss
    plt.subplot(1,3,1)
    for l in loss_list:
        plt.plot(epochs, history[l], 'b', label='Training loss (' + str(str(format(history[l][-1],'.5f'))+')'))
    for l in val_loss_list:
        plt.plot(epochs, history[l], 'g', label='Validation loss (' + str(str(format(history[l][-1],'.5f'))+')'))
    
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    ## Dice Coefficient
    plt.subplot(1,3,2)
    for l in dice_list:
        plt.plot(epochs, history[l], 'b', label='Training Dice Coefficient (' + str(format(history[l][-1],'.5f'))+')')
    for l in val_dice_list:    
        plt.plot(epochs, history[l], 'g', label='Validation Dice Coefficient (' + str(format(history[l][-1],'.5f'))+')')

    plt.title('Dice Coefficient')
    plt.xlabel('Epochs')
    plt.ylabel('Dice Coefficient')
    plt.legend()
    
    ## Accuracy
    plt.subplot(1,3,3)
    for l in acc_list:
        plt.plot(epochs, history[l], 'b', label='Training accuracy (' + str(format(history[l][-1],'.5f'))+')')
    for l in val_acc_list:    
        plt.plot(epochs, history[l], 'g', label='Validation accuracy (' + str(format(history[l][-1],'.5f'))+')')

    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# %% [markdown]
# # Transfer Learning model
# ### Baseline
#
# Transfer learning model with NAIP dataset

# %%
root_path = 'training_results/'
infile = open(root_path+'history_transfered_NAIP_20201005-143648.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# ----
#
# ## SpatialDropout2D

# %%
### Dropout rate 0.3
infile = open(root_path+'history_transfered_NAIP_spatialdropout2D_0.3_20201005-101704.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %%
### Dropout rate 0.5
infile = open(root_path+'history_transfered_NAIP_spatialdropout2D_0.5_20201005-113304.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %%
### Dropout rate 0.7
infile = open(root_path+'history_transfered_NAIP_spatialdropout2D_0.7_20201005-123002.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# -----
#
# ## Dropout

# %%
### Dropout rate 0.7
infile = open(root_path+'history_transfered_NAIP_Dropout_0.3_20201005-133238.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %%
### Dropout rate 0.5
infile = open(root_path+'history_transfered_NAIP_Dropout_0.5_20201005-174907.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %%
### Dropout rate 0.7
infile = open(root_path+'history_transfered_NAIP_Dropout_0.7_20201005-154738.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# -----
# # Train from scratch
#
# with Train 300/300 and Valid 300/300

# %%
root_path = 'training_results/'
#infile = open(root_path+'history_attention2_transfered_08082020.pickle','rb')
infile = open(root_path+'history_train_from_scratch_NoNAIP_20201012-111316.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %%
#infile = open(root_path+'history_attention2_transfered_08082020.pickle','rb')
infile = open(root_path+'history_train_from_scratch_NAIP_20201012-121601.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# ---
# # Train from scratch
#
# ### 200 Samples

# %%
infile = open(root_path+'history_train_from_scratch_NAIP_100_samples_20201012-174105.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# ### 700 Samples

# %%
infile = open(root_path+'history_train_from_scratch_NAIP_350_samples_20201013-131534.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# ### 1000 Samples

# %%
infile = open(root_path+'history_train_from_scratch_NAIP_500_samples_20201012-204040.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# ---
#
# # Transfer Learning
#
# ### 200 Samples (Training 80 each class / Validation 20 each class)

# %%
infile = open(root_path+'history_transfere-_learning_NAIP_100_samples_20201012-150904.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# ### 700 Samples (Training 262 each class / Validation 88 each class)

# %%
infile = open(root_path+'history_transfere-_learning_NAIP_350_samples_20201012-155935.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# ### 1000 Samples (Training 375 each class / Validation 125 each class)

# %%
infile = open(root_path+'history_transfere-_learning_NAIP_500_samples_20201012-170026.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# ---
#
# # 100 Epochs
#
# ## Transfer Learning
#
# ### 200 Samples

# %%
root_path = 'training_results/'
infile = open(root_path+'history_transfere_learning_NAIP_100_samples_100_epochs_20201102-145944.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# ### 700 Samples

# %%
root_path = 'training_results/'
infile = open(root_path+'history_transfere_learning_NAIP_350_samples_100_epochs_20201102-151522.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# ### 1000 samples

# %%
root_path = 'training_results/'
infile = open(root_path+'history_transfere_learning_NAIP_500_samples_100_epochs_20201102-153500.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# ----
#
# ## Training from Scratch
#
# ### 200 samples

# %%
root_path = 'training_results/'
infile = open(root_path+'history_train_from_scratch_NAIP_100_samples_100_epoch_20201102-145356.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# ### 700 samples

# %%
root_path = 'training_results/'
infile = open(root_path+'history_train_from_scratch_NAIP_350_samples_100_epoch_20201102-163005.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# ### 1000 samples

# %%
root_path = 'training_results/'
infile = open(root_path+'history_train_from_scratch_NAIP_100_samples_100_epoch_20201102-145356.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# ----
#
# ## Fine-Tuning WITHOUT NAIP 200 Epochs
#
# ### 100 samples

# %%
root_path = 'training_results/Without_NAIP/'
infile = open(root_path+'history_fine_tuning_learning_No_NAIP_100_samples20201116-102247.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %%
root_path = 'training_results/Without_NAIP/'
tranfer_learning_history = open(root_path+'history_transfere-_learning_No_NAIP_100_samples_20201116-101740.pickle','rb')
fine_tuned_history = open(root_path+'history_fine_tuning_learning_No_NAIP_100_samples20201116-102247.pickle','rb')
new_dict = pickle.load(infile)
infile.close()

# # first pass 
# training_loss = tranfer_learning_history.history['loss']
# validation_loss = tranfer_learning_history.history['val_loss']

# training_accuracy = tranfer_learning_history.history['accuracy']
# validation_accuracy = tranfer_learning_history.history['val_accuracy']

# training_dice = tranfer_learning_history.history['dice_coef']
# validation_dice = tranfer_learning_history.history['val_dice_coef']

# # fine_tuned_model.history

# training_loss += fine_tuned_model.history['loss']
# validation_loss += fine_tuned_model.history['val_loss']

# training_accuracy += fine_tuned_model.history['accuracy']
# validation_accuracy +=  fine_tuned_model.history['val_accuracy']

# training_dice += fine_tuned_model.history['dice_coef']
# validation_dice +=  fine_tuned_model.history['val_dice_coef']


# import matplotlib.pyplot as plt
# plt.figure(figsize=(30, 8))
# plt.subplot(1,3, 1)
# plt.plot(training_accuracy, label='Training Accuracy')
# plt.plot(validation_accuracy, label='Validation Accuracy')
# # plt.ylim([0, 1])
# plt.plot([99,99], plt.ylim(), label='Start Fine Tuning')
# plt.legend(loc='lower right')
# plt.title('Training and Validation Accuracy')

# plt.subplot(1, 3, 2)
# plt.plot(training_loss, label='Training Loss')
# plt.plot(validation_loss, label='Validation Loss')
# # plt.ylim([0, 1.0])
# plt.plot([99,99],  plt.ylim(), label='Start Fine Tuning')
# plt.legend(loc='upper right')
# plt.title('Training and Validation Loss')
# plt.xlabel('epoch')

# plt.subplot(1, 3, 3)
# plt.plot(training_dice, label='Training Dice Coeff')
# plt.plot(validation_dice, label='Validation  Dice Coeff')
# # plt.ylim([0, 1.0])
# plt.plot([99,99],  plt.ylim(), label='Start Fine Tuning')
# plt.legend(loc='upper right')
# plt.title('Training and Validation Dice Coeff')
# plt.xlabel('epoch')

# plt.show()

# %%
root_path = 'training_results/'
infile = open(root_path+'history_transfere_learning_without_NAIP_100_samples_200_epochs_20201123-101308.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# ----
#
# ## Transfer learning WITHOUT NAIP 200 Epochs
#
# ### 100 samples

# %%
root_path = 'training_results/'
infile = open(root_path+'history_transfere_learning_without_NAIP_100_samples_200_epochs_20201123-101308.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# ### 700 samples

# %%
root_path = 'training_results/'
infile = open(root_path+'history_transfere_learning_without_NAIP_700_samples_200_epochs_20201123-104330.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)

# %% [markdown]
# ### 1200 samples

# %%
root_path = 'training_results/'
infile = open(root_path+'history_transfere_learning_without_NAIP_1200_samples_200_epochs_20201123-114352.pickle','rb')
new_dict = pickle.load(infile)
infile.close()
plt.figure(figsize=(20,5))
plot_history(new_dict)
