# %%
# Load all the dependencies
import os
import sys
import random
import warnings
import numpy as np
from itertools import chain
from numpy import genfromtxt
from tensorflow import random
from keras import backend as K
from keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import Layer, UpSampling2D, GlobalAveragePooling2D, Multiply, Dense, Reshape, Permute, multiply, dot, add, Input
from keras.layers.core import Dropout, Lambda, SpatialDropout2D, Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Model, load_model, model_from_yaml, Sequential
import tensorflow as tf

np.random.seed(1337) # for reproducibility
random.set_seed(1337)
print(tf.__version__)
# Out:
# 2.3.0

# %%
# Use dice coefficient function as the loss function 
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)

# Jacard coefficient
def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

# calculate loss value
def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)

# calculate loss value
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def Residual_CNN_block(x, size, dropout=0.0, batch_norm=True):
    if K.image_dim_ordering() == 'th':
        axis = 1
    else:
        axis = 3
    conv = Conv2D(size, (3, 3), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    return conv

class multiplication(Layer):
    def __init__(self,inter_channel = None,**kwargs):
        super(multiplication, self).__init__(**kwargs)
        self.inter_channel = inter_channel
    def build(self,input_shape=None):
        self.k = self.add_weight(name='k',shape=(1,),initializer='zeros',dtype='float32',trainable=True)
    def get_config(self):
        base_config = super(multiplication, self).get_config()
        config = {'inter_channel':self.inter_channel}
        return dict(list(base_config.items()) + list(config.items()))  
    def call(self,inputs):
        g,x,x_query,phi_g,x_value = inputs[0],inputs[1],inputs[2],inputs[3],inputs[4]
        h,w,c = int(x.shape[1]),int(x.shape[2]),int(x.shape[3])
        x_query = K.reshape(x_query, shape=(-1,h*w, self.inter_channel//4))
        phi_g = K.reshape(phi_g,shape=(-1,h*w,self.inter_channel//4))
        x_value = K.reshape(x_value,shape=(-1,h*w,c))
        scale = dot([K.permute_dimensions(phi_g,(0,2,1)), x_query], axes=(1, 2))
        soft_scale = Activation('softmax')(scale)
        scaled_value = dot([K.permute_dimensions(soft_scale,(0,2,1)),K.permute_dimensions(x_value,(0,2,1))],axes=(1, 2))
        scaled_value = K.reshape(scaled_value, shape=(-1,h,w,c))        
        customize_multi = self.k * scaled_value
        layero = add([customize_multi,x])
        my_concat = Lambda(lambda x: K.concatenate([x[0], x[1]], axis=3))
        concate = my_concat([layero,g])
        return concate 
    def compute_output_shape(self,input_shape):
        ll = list(input_shape)[1]
        return (None,ll[1],ll[1],ll[3]*3)
    def get_custom_objects():
        return {'multiplication': multiplication}

def attention_up_and_concatenate(inputs):
    g,x = inputs[0],inputs[1]
    inter_channel = g.get_shape().as_list()[3]
    g = Conv2DTranspose(inter_channel, (2,2), strides=[2, 2],padding='same')(g)
    x_query = Conv2D(inter_channel//4, [1, 1], strides=[1, 1], data_format='channels_last')(x)
    phi_g = Conv2D(inter_channel//4, [1, 1], strides=[1, 1], data_format='channels_last')(g)
    x_value = Conv2D(inter_channel//2, [1, 1], strides=[1, 1], data_format='channels_last')(x)
    inputs = [g,x,x_query,phi_g,x_value]
    concate = multiplication(inter_channel)(inputs)
    return concate

class multiplication2(Layer):
    def __init__(self,inter_channel = None,**kwargs):
        super(multiplication2, self).__init__(**kwargs)
        self.inter_channel = inter_channel
    def build(self,input_shape=None):
        self.k = self.add_weight(name='k',shape=(1,),initializer='zeros',dtype='float32',trainable=True)
    def get_config(self):
        base_config = super(multiplication2, self).get_config()
        config = {'inter_channel':self.inter_channel}
        return dict(list(base_config.items()) + list(config.items()))  
    def call(self,inputs):
        g,x,rate = inputs[0],inputs[1],inputs[2]
        scaled_value = multiply([x, rate])
        att_x =  self.k * scaled_value
        att_x = add([att_x,x])
        my_concat = Lambda(lambda x: K.concatenate([x[0], x[1]], axis=3))
        concate = my_concat([att_x, g])
        return concate 
    def compute_output_shape(self,input_shape):
        ll = list(input_shape)[1]
        return (None,ll[1],ll[1],ll[3]*2)
    def get_custom_objects():
        return {'multiplication2': multiplication2}

def attention_up_and_concatenate2(inputs):
    g, x = inputs[0],inputs[1]
    inter_channel = g.get_shape().as_list()[3]
    g = Conv2DTranspose(inter_channel//2, (3,3), strides=[2, 2],padding='same')(g)
    g = Conv2D(inter_channel//2, [1, 1], strides=[1, 1], data_format='channels_last')(g)
    theta_x = Conv2D(inter_channel//4, [1, 1], strides=[1, 1], data_format='channels_last')(x)
    phi_g = Conv2D(inter_channel//4, [1, 1], strides=[1, 1], data_format='channels_last')(g)
    f = Activation('relu')(add([theta_x, phi_g]))
    psi_f = Conv2D(1, [1, 1], strides=[1, 1], data_format='channels_last')(f)
    rate = Activation('sigmoid')(psi_f)
    concate =  multiplication2()([g,x,rate])
    return concate

# %%
loaded_model = load_model('June21/model/model_augv_attention2.h5', 
                             custom_objects={'multiplication': multiplication,'multiplication2': multiplication2, 
                                             'dice_coef_loss':dice_coef_loss, 'dice_coef':dice_coef,})

# remove the last 2 layer using pop() function
loaded_model.layers.pop()
loaded_model.layers.pop()

for (index, layer) in enumerate(loaded_model.layers):
    if (index > len(loaded_model.layers)-5):
      print("Here")
      layer.trainable = True
    else:
      layer.trainable = False

# Create new model from the model using the input and output of the last layer (after poping last 2 layers)
model_without_last = Model(loaded_model.input,  loaded_model.layers[-1].output)

# See model structure
#model_without_last.summary()
# Out:
# Here
# Here
# Here
# Here

# %%
# Number of output masks (1 in case you predict only one type of objects)
OUTPUT_MASK_CHANNELS = 1

# 1 dimensional convolution and generate probabilities from Sigmoid function
conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1), name='conv2d_last')(model_without_last.output)
new_out = Activation('sigmoid', name='activation_last')(conv_final)

# Created new model with the newly added last two layers 
transfered_model = Model(inputs=model_without_last.input, outputs=new_out)

# New model structure
#transfered_model.summary()

# %% [markdown]
# # If want to train on the data **without** the NAIP, run the block below.

# %%
data_path = 'Covington_data/non-overlap/'

# read in training and validation data
X_train = np.load(data_path+'train_data.npy')
Y_train = np.load(data_path+'train_label.npy')
X_Validation = np.load(data_path+'vali_data.npy')
Y_Validation = np.load(data_path+'vali_label.npy')

# The dataset has 9 channels:
# 0. Curvature
# 1. Slope
# 2. Openness
# 3. DEM
# 4. TPI 21
# 5. Reflectance (LiDAR intensity)
# 6. Geomorphon
# 7. TPI 9
# 8. TPI 3
# but the model expects 8 channels
# So we exclude TPI_9 channel from the data set
X_train_new = X_train[:,:,:,(0,1,2,3,4,5,6,8)]
print(X_train_new.shape)

X_Validation_new = X_Validation[:,:,:,(0,1,2,3,4,5,6,8)]
print(X_Validation_new.shape)
# Out:
# (350, 224, 224, 8)
# (400, 224, 224, 8)

# %% [markdown]
# # If want to train on the data **with** the NAIP, run the block below.

# %%
data_path = 'Covington_data/include_NAIP/'

# read in training and validation sample patches
X_train_new = np.load(data_path+'train_data.npy')
X_Validation_new = np.load(data_path+'vali_data.npy')
print(X_train_new.shape)
print(X_Validation_new.shape)

#Read training and validation labels
Y_Validation = np.load(data_path+'vali_label.npy')
Y_train = np.load(data_path+'train_label.npy')

#Cast both labales to float32
Y_Validation = Y_Validation.astype(np.float32)
Y_train = Y_train.astype(np.float32)
# Out:
# (600, 224, 224, 8)
# (600, 224, 224, 8)

# %%
patch_size = 224
IMG_WIDTH = patch_size
IMG_HEIGHT = patch_size
# Number of feature channels 
INPUT_CHANNELS = 8
# Number of output masks (1 in case you predict only one type of objects)
OUTPUT_MASK_CHANNELS = 1
maxepoch = 1000
# hyperparameters
# learning_rate = 0.0000359
learning_rate = 0.0001
patience = 20
aug = 'v'
transfered_model.compile(optimizer=Adam(lr=learning_rate),loss = dice_coef_loss,metrics=[dice_coef,'accuracy'])
callbacks = [
        ReduceLROnPlateau(monitor='val_loss', factor=0.7, patience=patience, min_lr=1e-9, verbose=1, mode='min'),
        EarlyStopping(monitor='val_loss', patience=patience+10, verbose=0),
        ModelCheckpoint('model'+aug+'_attention2.h5', monitor='val_loss', save_best_only=True, verbose=0),
    ]

# %%
ltranfer_learning_results = transfered_model.fit(X_train_new, Y_train, validation_data=(X_Validation_new,Y_Validation), batch_size=32, epochs=maxepoch, callbacks=callbacks)
# Out:
# Epoch 1/1000
# 19/19 [==============================] - 9s 469ms/step - loss: -0.0954 - dice_coef: 0.0953 - accuracy: 0.0693 - val_loss: -0.0568 - val_dice_coef: 0.0568 - val_accuracy: 0.2985
# Epoch 2/1000
# 19/19 [==============================] - 7s 367ms/step - loss: -0.0954 - dice_coef: 0.0955 - accuracy: 0.1138 - val_loss: -0.0568 - val_dice_coef: 0.0568 - val_accuracy: 0.8449
# Epoch 3/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.0955 - dice_coef: 0.0956 - accuracy: 0.1797 - val_loss: -0.0569 - val_dice_coef: 0.0569 - val_accuracy: 0.8741
# Epoch 4/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.0955 - dice_coef: 0.0953 - accuracy: 0.2623 - val_loss: -0.0569 - val_dice_coef: 0.0569 - val_accuracy: 0.8773
# Epoch 5/1000
# 19/19 [==============================] - 7s 369ms/step - loss: -0.0957 - dice_coef: 0.0960 - accuracy: 0.3486 - val_loss: -0.0569 - val_dice_coef: 0.0569 - val_accuracy: 0.8760
# Epoch 6/1000
# 19/19 [==============================] - 7s 367ms/step - loss: -0.0957 - dice_coef: 0.0953 - accuracy: 0.4211 - val_loss: -0.0569 - val_dice_coef: 0.0569 - val_accuracy: 0.8741
# Epoch 7/1000
# 19/19 [==============================] - 7s 368ms/step - loss: -0.0959 - dice_coef: 0.0956 - accuracy: 0.4906 - val_loss: -0.0570 - val_dice_coef: 0.0570 - val_accuracy: 0.8723
# Epoch 8/1000
# 19/19 [==============================] - 7s 368ms/step - loss: -0.0959 - dice_coef: 0.0961 - accuracy: 0.5540 - val_loss: -0.0570 - val_dice_coef: 0.0570 - val_accuracy: 0.8719
# Epoch 9/1000
# 19/19 [==============================] - 7s 367ms/step - loss: -0
1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2112 - dice_coef: 0.2115 - accuracy: 0.9385 - val_loss: -0.1228 - val_dice_coef: 0.1226 - val_accuracy: 0.9572
# Epoch 938/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2119 - dice_coef: 0.2119 - accuracy: 0.9384 - val_loss: -0.1229 - val_dice_coef: 0.1227 - val_accuracy: 0.9572
# Epoch 939/1000
# 19/19 [==============================] - 7s 367ms/step - loss: -0.2117 - dice_coef: 0.2117 - accuracy: 0.9386 - val_loss: -0.1230 - val_dice_coef: 0.1228 - val_accuracy: 0.9573
# Epoch 940/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2113 - dice_coef: 0.2112 - accuracy: 0.9387 - val_loss: -0.1231 - val_dice_coef: 0.1229 - val_accuracy: 0.9574
# Epoch 941/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2130 - dice_coef: 0.2131 - accuracy: 0.9388 - val_loss: -0.1232 - val_dice_coef: 0.1230 - val_accuracy: 0.9574
# Epoch 942/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2123 - dice_coef: 0.2124 - accuracy: 0.9387 - val_loss: -0.1233 - val_dice_coef: 0.1231 - val_accuracy: 0.9574
# Epoch 943/1000
# 19/19 [==============================] - 7s 367ms/step - loss: -0.2122 - dice_coef: 0.2119 - accuracy: 0.9388 - val_loss: -0.1234 - val_dice_coef: 0.1232 - val_accuracy: 0.9574
# Epoch 944/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2127 - dice_coef: 0.2130 - accuracy: 0.9388 - val_loss: -0.1236 - val_dice_coef: 0.1234 - val_accuracy: 0.9574
# Epoch 945/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2136 - dice_coef: 0.2136 - accuracy: 0.9389 - val_loss: -0.1237 - val_dice_coef: 0.1235 - val_accuracy: 0.9575
# Epoch 946/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2137 - dice_coef: 0.2136 - accuracy: 0.9388 - val_loss: -0.1238 - val_dice_coef: 0.1236 - val_accuracy: 0.9574
# Epoch 947/1000
# 19/19 [==============================] - 7s 367ms/step - loss: -0.2124 - dice_coef: 0.2112 - accuracy: 0.9389 - val_loss: -0.1239 - val_dice_coef: 0.1237 - val_accuracy: 0.9575
# Epoch 948/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2140 - dice_coef: 0.2139 - accuracy: 0.9389 - val_loss: -0.1240 - val_dice_coef: 0.1238 - val_accuracy: 0.9576
# Epoch 949/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2136 - dice_coef: 0.2136 - accuracy: 0.9392 - val_loss: -0.1241 - val_dice_coef: 0.1239 - val_accuracy: 0.9576
# Epoch 950/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2140 - dice_coef: 0.2138 - accuracy: 0.9391 - val_loss: -0.1242 - val_dice_coef: 0.1240 - val_accuracy: 0.9576
# Epoch 951/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2138 - dice_coef: 0.2140 - accuracy: 0.9391 - val_loss: -0.1244 - val_dice_coef: 0.1241 - val_accuracy: 0.9577
# Epoch 952/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2135 - dice_coef: 0.2138 - accuracy: 0.9391 - val_loss: -0.1245 - val_dice_coef: 0.1243 - val_accuracy: 0.9577
# Epoch 953/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2143 - dice_coef: 0.2143 - accuracy: 0.9393 - val_loss: -0.1246 - val_dice_coef: 0.1244 - val_accuracy: 0.9578
# Epoch 954/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2141 - dice_coef: 0.2147 - accuracy: 0.9393 - val_loss: -0.1247 - val_dice_coef: 0.1245 - val_accuracy: 0.9578
# Epoch 955/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2146 - dice_coef: 0.2148 - accuracy: 0.9393 - val_loss: -0.1248 - val_dice_coef: 0.1246 - val_accuracy: 0.9578
# Epoch 956/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.
1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2189 - dice_coef: 0.2193 - accuracy: 0.9398 - val_loss: -0.1270 - val_dice_coef: 0.1268 - val_accuracy: 0.9582
# Epoch 975/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2184 - dice_coef: 0.2186 - accuracy: 0.9399 - val_loss: -0.1271 - val_dice_coef: 0.1269 - val_accuracy: 0.9583
# Epoch 976/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2176 - dice_coef: 0.2185 - accuracy: 0.9400 - val_loss: -0.1272 - val_dice_coef: 0.1270 - val_accuracy: 0.9585
# Epoch 977/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2189 - dice_coef: 0.2184 - accuracy: 0.9401 - val_loss: -0.1274 - val_dice_coef: 0.1271 - val_accuracy: 0.9584
# Epoch 978/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2184 - dice_coef: 0.2189 - accuracy: 0.9399 - val_loss: -0.1275 - val_dice_coef: 0.1273 - val_accuracy: 0.9584
# Epoch 979/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2198 - dice_coef: 0.2198 - accuracy: 0.9401 - val_loss: -0.1276 - val_dice_coef: 0.1274 - val_accuracy: 0.9585
# Epoch 980/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2196 - dice_coef: 0.2197 - accuracy: 0.9402 - val_loss: -0.1277 - val_dice_coef: 0.1275 - val_accuracy: 0.9585
# Epoch 981/1000
# 19/19 [==============================] - 7s 367ms/step - loss: -0.2197 - dice_coef: 0.2199 - accuracy: 0.9402 - val_loss: -0.1278 - val_dice_coef: 0.1276 - val_accuracy: 0.9585
# Epoch 982/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2199 - dice_coef: 0.2202 - accuracy: 0.9403 - val_loss: -0.1279 - val_dice_coef: 0.1277 - val_accuracy: 0.9586
# Epoch 983/1000
# 19/19 [==============================] - 7s 365ms/step - loss: -0.2204 - dice_coef: 0.2202 - accuracy: 0.9403 - val_loss: -0.1281 - val_dice_coef: 0.1279 - val_accuracy: 0.9585
# Epoch 984/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2199 - dice_coef: 0.2198 - accuracy: 0.9402 - val_loss: -0.1282 - val_dice_coef: 0.1280 - val_accuracy: 0.9586
# Epoch 985/1000
# 19/19 [==============================] - 7s 367ms/step - loss: -0.2210 - dice_coef: 0.2209 - accuracy: 0.9404 - val_loss: -0.1283 - val_dice_coef: 0.1281 - val_accuracy: 0.9585
# Epoch 986/1000
# 19/19 [==============================] - 7s 367ms/step - loss: -0.2208 - dice_coef: 0.2211 - accuracy: 0.9404 - val_loss: -0.1284 - val_dice_coef: 0.1282 - val_accuracy: 0.9587
# Epoch 987/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2202 - dice_coef: 0.2200 - accuracy: 0.9404 - val_loss: -0.1285 - val_dice_coef: 0.1283 - val_accuracy: 0.9587
# Epoch 988/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2216 - dice_coef: 0.2215 - accuracy: 0.9406 - val_loss: -0.1286 - val_dice_coef: 0.1284 - val_accuracy: 0.9587
# Epoch 989/1000
# 19/19 [==============================] - 7s 367ms/step - loss: -0.2207 - dice_coef: 0.2211 - accuracy: 0.9405 - val_loss: -0.1288 - val_dice_coef: 0.1285 - val_accuracy: 0.9588
# Epoch 990/1000
# 19/19 [==============================] - 7s 365ms/step - loss: -0.2216 - dice_coef: 0.2211 - accuracy: 0.9405 - val_loss: -0.1289 - val_dice_coef: 0.1287 - val_accuracy: 0.9587
# Epoch 991/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2208 - dice_coef: 0.2214 - accuracy: 0.9405 - val_loss: -0.1290 - val_dice_coef: 0.1288 - val_accuracy: 0.9588
# Epoch 992/1000
# 19/19 [==============================] - 7s 364ms/step - loss: -0.2215 - dice_coef: 0.2211 - accuracy: 0.9406 - val_loss: -0.1291 - val_dice_coef: 0.1289 - val_accuracy: 0.9588
# Epoch 993/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2210 - dice_coef: 0.2205 - accuracy: 0.9406 - val_loss: -0.1293 - val_dice_coef: 0.1290 - val_accuracy: 0.9588
# Epoch 994/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2220 - dice_coef: 0.2221 - accuracy: 0.9408 - val_loss: -0.1294 - val_dice_coef: 0.1291 - val_accuracy: 0.9589
# Epoch 995/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2227 - dice_coef: 0.2226 - accuracy: 0.9408 - val_loss: -0.1295 - val_dice_coef: 0.1293 - val_accuracy: 0.9589
# Epoch 996/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2230 - dice_coef: 0.2235 - accuracy: 0.9407 - val_loss: -0.1296 - val_dice_coef: 0.1294 - val_accuracy: 0.9589
# Epoch 997/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2217 - dice_coef: 0.2220 - accuracy: 0.9407 - val_loss: -0.1297 - val_dice_coef: 0.1295 - val_accuracy: 0.9590
# Epoch 998/1000
# 19/19 [==============================] - 7s 367ms/step - loss: -0.2219 - dice_coef: 0.2223 - accuracy: 0.9409 - val_loss: -0.1298 - val_dice_coef: 0.1296 - val_accuracy: 0.9589
# Epoch 999/1000
# 19/19 [==============================] - 7s 366ms/step - loss: -0.2233 - dice_coef: 0.2233 - accuracy: 0.9408 - val_loss: -0.1300 - val_dice_coef: 0.1297 - val_accuracy: 0.9590
# Epoch 1000/1000
# 19/19 [==============================] - 7s 360ms/step - loss: -0.2231 - dice_coef: 0.2234 - accuracy: 0.9409 - val_loss: -0.1301 - val_dice_coef: 0.1299 - val_accuracy: 0.9590

# %%
import pickle
import time
timestr = time.strftime("%Y%m%d-%H%M%S")
root_path = ''
# save the trained model
model_yaml = transfered_model.to_yaml()
with open(root_path+"model_attention2_transfered_NAIP_"+timestr+".yaml", "w") as yaml_file:
    yaml_file.write(model_yaml)
# save the weights
transfered_model.save(root_path+"model_attention2_transfered_NAIP_"+timestr+".h5")
# save the intermdediate results and training statistics
with open(root_path+"history_attention2_transfered_NAIP_"+timestr+".pickle", 'wb') as file_pi:
    pickle.dump(ltranfer_learning_results.history, file_pi, protocol=2)

# %% [markdown]
# ### Will wait for the whole area data to do prediction

# %%
# Save the predicted labels.
X_test = np.load(root_path+'ModelJun14/prediction_data.npy')
preds_test = model.predict(X_test)
preds_test_t = (preds_test > 0.5).astype(np.uint8)
np.save(root_path+'ModelJun14/preds_test_total_attention2.npy',preds_test_t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c574e7fc8f89> in <module>
#       1 # Save the predicted labels.
# ----> 2 X_test = np.load(root_path+'ModelJun14/prediction_data.npy')
#       3 preds_test = model.predict(X_test)
#       4 preds_test_t = (preds_test > 0.5).astype(np.uint8)
#       5 np.save(root_path+'ModelJun14/preds_test_total_attention2.npy',preds_test_t)
#
# NameError: name 'np' is not defined

# %% [markdown]
# # Progress 21/09/2020
# 1. Genreating the result for transfer learnign without NAIP again
# 2. Created the [plan until Mid Oct 2020]("https://docs.google.com/document/d/1Kqz18zgB-DSkDarr-m8Y-__0ZCNzXAkTZw7Xg7kIy08/edit#")
#     - The goal is to finish the first draft by Mid Oct.
#
# # Plan work
# 1. Start writing the paper
# 2. Try training the model with more weight of stream class.
# 3. Weekly plan until Mid October 2020[.]('https://analyticsindiamag.com/top-10-papers-on-transfer-learning-one-must-read-in-2020/')
#
# # Progress 14/09/2020
# 1. Read and summarize more  [transfer learning paper]('https://openreview.net/pdf?id=ryxyCeHtPB')
#     - propose "attentive feature distillation and selection (AFDS)"
#     - AFDS dynamically learns not only the features to transfer, but also the unimportant neurons to skip
#
#
# # Plan work
# 1. Start writing the paper
# 2. Try training the model with more weight of stream class.
# 3. Weekly plan until Mid October 2020
#
# **Qual Exam beginning of next semester**
#
# ---
#
# # Progress 07/09/2020
# 1. Presented the progress in CEGIS
#
# 2. Generated total dataset for Covingtoin area (without NAIP imagery)
#
# 3. Run prediction of the Convington area with the dataset without NAIP and using the original model that is trained on Rowan creek area
#
#
# # Plan work
# 1. Try training the model with more weight of stream class.
#
# ---
#
# # Progress 31/08/2020
# 1. Corrected the data (removing None class (-9999) from test dataset)
#     - will generate the new test results
#
#
# 2. Preparing for CEGIS presentation
#     - Added prelim results
#     - Will add the base scenario which is the U-net model predict the dataset without NAIP in Covinton river
#
#
#
# 3. preparing the script for the presentation
#
# # Plan for this week
# 1. Finish the presentation for CEGIS
# 2. Read and summarize more paper
# 3. Try training the model with more weight of stream class.
#
# ----
#
# # Progress 24/08/2020
#
# **Comments:** Try to get the why and what it hold true and how to make or to apply to other places.
#
# 1. Generate the whole area and do testing
#     - Generated the dataset
#     - Evaluated the testing data and generated the prelim results
# **Problem:** the data has more than 2 classes as shown in evaluation.
#
#
# 2. Created the outline of the presentation for CEGIS
#     - Still need more details:
#     https://docs.google.com/presentation/d/1PWrlgGEMCCJLXsAHeiTe40xdA22RtISE6gUpRbbplRs/edit?usp=sharing
#
# # Plan for this week
# 1. Finish the presentation for CEGIS
# 2. Read and summarize more paper
# 3. Try training the model with more weight of stream class.
# 4. Correct the data (remove the None class)
#
# ---
#
# # Progress 17/08/2020
# 1. Finished generating the new dataset
#     - Cleaned the NAIP data and all raw data of Covington River
#     - Included NAIP imagery into the dataset
#     - Edited the data preprocessing script to make it easier to add or remove data
#     - Added script documents and comments
#
# 2. Generating the whole area dataset the included NAIP imagery
#     - Using High memory node on Keeling
#     - **Problem:** The VPN disconnected after 2 hours in!!! T_T I have to start over.
#
# 3. Trained the model with new dataset
#     - The performance is significatly higher than the dataset without NAIP
#
# 4. Read more papers and added summary of the read paper
#     -https://docs.google.com/document/d/1BApPn0aWTwstEpbnKC9g0p5KSOhi74_rF7nzRYM9CtE/edit
#
# # Plan for this week
# 1. Generate the whole area and do testing
# 2. Start preparing the presentation for CEGIS
# 3. Read and summarize more papers
#     - Focus more on machine learning in hydro, remote sensing classification.
#
#
#
# ---
#
#
#
# # Prgress 10/08/2020
#
# 1. Successfully trained the model on my own PC.
#     - Fixed cuCNN and CUDA version problems
#     - Trained with 4 trainable layers
#       **Problem:** The model just disrtegards the stream class.
#       **Root cause:** Unbalanced sample of stream and non-stream classes
#
# 2. In progress: Adding NAIP image to the dataset.
#     - Extracted the NAIP for Covinton and put it on Keeling
#     - modifying the preprocessing code
#
# 3. Outline the Introduction of the paper and reviewed some papers
#     - https://docs.google.com/document/d/1BApPn0aWTwstEpbnKC9g0p5KSOhi74_rF7nzRYM9CtE/edit
#
# # Plan for this week
# 1. Finished adding the NAIP and train the model again
# 2. Start the first draft of the introduction
