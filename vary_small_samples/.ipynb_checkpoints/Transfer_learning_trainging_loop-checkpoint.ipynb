# %%
## Load all the dependencies
import os
import sys
import random
import warnings
import numpy as np
from itertools import chain
from numpy import genfromtxt
from tensorflow import random
from keras import backend as K
# from keras import backend as k
from keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import Layer, UpSampling2D, GlobalAveragePooling2D, Multiply, Dense, Reshape, Permute, multiply, dot, add, Input
from keras.layers.core import Dropout, Lambda, SpatialDropout2D, Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Model, load_model, model_from_yaml, Sequential

import tensorflow as tf

# os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

np.random.seed(1337) # for reproducibility
random.set_seed(1337)
print(tf.__version__)



# Use dice coefficient function as the loss function 
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)

# Jacard coefficient
def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

# calculate loss value
def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)

# calculate loss value
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def Residual_CNN_block(x, size, dropout=0.0, batch_norm=True):
    if K.image_dim_ordering() == 'th':
        axis = 1
    else:
        axis = 3
    conv = Conv2D(size, (3, 3), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    return conv

class multiplication(Layer):
    def __init__(self,inter_channel = None,**kwargs):
        super(multiplication, self).__init__(**kwargs)
        self.inter_channel = inter_channel
    def build(self,input_shape=None):
        self.k = self.add_weight(name='k',shape=(1,),initializer='zeros',dtype='float32',trainable=True)
    def get_config(self):
        base_config = super(multiplication, self).get_config()
        config = {'inter_channel':self.inter_channel}
        return dict(list(base_config.items()) + list(config.items()))  
    def call(self,inputs):
        g,x,x_query,phi_g,x_value = inputs[0],inputs[1],inputs[2],inputs[3],inputs[4]
        h,w,c = int(x.shape[1]),int(x.shape[2]),int(x.shape[3])
        x_query = K.reshape(x_query, shape=(-1,h*w, self.inter_channel//4))
        phi_g = K.reshape(phi_g,shape=(-1,h*w,self.inter_channel//4))
        x_value = K.reshape(x_value,shape=(-1,h*w,c))
        scale = dot([K.permute_dimensions(phi_g,(0,2,1)), x_query], axes=(1, 2))
        soft_scale = Activation('softmax')(scale)
        scaled_value = dot([K.permute_dimensions(soft_scale,(0,2,1)),K.permute_dimensions(x_value,(0,2,1))],axes=(1, 2))
        scaled_value = K.reshape(scaled_value, shape=(-1,h,w,c))        
        customize_multi = self.k * scaled_value
        layero = add([customize_multi,x])
        my_concat = Lambda(lambda x: K.concatenate([x[0], x[1]], axis=3))
        concate = my_concat([layero,g])
        return concate 
    def compute_output_shape(self,input_shape):
        ll = list(input_shape)[1]
        return (None,ll[1],ll[1],ll[3]*3)
    def get_custom_objects():
        return {'multiplication': multiplication}

def attention_up_and_concatenate(inputs):
    g,x = inputs[0],inputs[1]
    inter_channel = g.get_shape().as_list()[3]
    g = Conv2DTranspose(inter_channel, (2,2), strides=[2, 2],padding='same')(g)
    x_query = Conv2D(inter_channel//4, [1, 1], strides=[1, 1], data_format='channels_last')(x)
    phi_g = Conv2D(inter_channel//4, [1, 1], strides=[1, 1], data_format='channels_last')(g)
    x_value = Conv2D(inter_channel//2, [1, 1], strides=[1, 1], data_format='channels_last')(x)
    inputs = [g,x,x_query,phi_g,x_value]
    concate = multiplication(inter_channel)(inputs)
    return concate

class multiplication2(Layer):
    def __init__(self,inter_channel = None,**kwargs):
        super(multiplication2, self).__init__(**kwargs)
        self.inter_channel = inter_channel
    def build(self,input_shape=None):
        self.k = self.add_weight(name='k',shape=(1,),initializer='zeros',dtype='float32',trainable=True)
    def get_config(self):
        base_config = super(multiplication2, self).get_config()
        config = {'inter_channel':self.inter_channel}
        return dict(list(base_config.items()) + list(config.items()))  
    def call(self,inputs):
        g,x,rate = inputs[0],inputs[1],inputs[2]
        scaled_value = multiply([x, rate])
        att_x =  self.k * scaled_value
        att_x = add([att_x,x])
        my_concat = Lambda(lambda x: K.concatenate([x[0], x[1]], axis=3))
        concate = my_concat([att_x, g])
        return concate 
    def compute_output_shape(self,input_shape):
        ll = list(input_shape)[1]
        return (None,ll[1],ll[1],ll[3]*2)
    def get_custom_objects():
        return {'multiplication2': multiplication2}

def attention_up_and_concatenate2(inputs):
    g, x = inputs[0],inputs[1]
    inter_channel = g.get_shape().as_list()[3]
    g = Conv2DTranspose(inter_channel//2, (3,3), strides=[2, 2],padding='same')(g)
    g = Conv2D(inter_channel//2, [1, 1], strides=[1, 1], data_format='channels_last')(g)
    theta_x = Conv2D(inter_channel//4, [1, 1], strides=[1, 1], data_format='channels_last')(x)
    phi_g = Conv2D(inter_channel//4, [1, 1], strides=[1, 1], data_format='channels_last')(g)
    f = Activation('relu')(add([theta_x, phi_g]))
    psi_f = Conv2D(1, [1, 1], strides=[1, 1], data_format='channels_last')(f)
    rate = Activation('sigmoid')(psi_f)
    concate =  multiplication2()([g,x,rate])
    return concate


for sample_size in range(30,110,10):
    for round_num in range(1,11):
        
        name = "model_fine_tuning_"
        name += 'No_NAIP_'
        name += str(sample_size)+"_"
        name += "samples_r"+str(round_num)+"_"
        
        print(name)
        root_path = './training_results/'+str(sample_size)+'/'
        
        if os.path.exists(root_path+name+".h5"):
            print("exists")
            continue;

        loaded_model = load_model('../June21/model/model_augv_attention2.h5', 
                                     custom_objects={'multiplication': multiplication,'multiplication2': multiplication2, 
                                                     'dice_coef_loss':dice_coef_loss, 'dice_coef':dice_coef,})

        # remove the last 2 layer using pop() function
        loaded_model.layers.pop()
        loaded_model.layers.pop()

        for (index, layer) in enumerate(loaded_model.layers):
            if (index < 4):
                print("index ",index)
                layer.trainable = True
            else:
                layer.trainable = False

        # Create new model from the model using the input and output of the last layer (after poping last 2 layers)
        model_without_last = Model(loaded_model.input,  loaded_model.layers[-1].output)

        # See model structure
        #model_without_last.summary()
        # Number of output masks (1 in case you predict only one type of objects)
        OUTPUT_MASK_CHANNELS = 1

        # 1 dimensional convolution and generate probabilities from Sigmoid function
        conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1), name='conv2d_last')(model_without_last.output)
        new_out = Activation('sigmoid', name='activation_last')(conv_final)

        # Created new model with the newly added last two layers 
        transfered_model = Model(inputs=model_without_last.input, outputs=new_out)

        # New model structure
        # transfered_model.summary()



        # The dataset has 9 channels:
        # 0. Curvature
        # 1. Slope
        # 2. Openness
        # 3. DEM
        # 4. TPI 21
        # 5. Reflectance (LiDAR intensity)
        # 6. Geomorphon
        # 7. TPI 9
        # 8. TPI 3

        data_path = './samples/'+str(sample_size)+'/'+str(round_num)+'/'
        # read in training and validation data
        X_train_new = np.load(data_path+'train_data.npy')
        print(X_train_new.shape)
        Y_train = np.load(data_path+'train_label.npy')
        print(Y_train.shape)
        X_Validation_new = np.load(data_path+'vali_data.npy')
        print(X_Validation_new.shape)
        Y_Validation = np.load(data_path+'vali_label.npy')
        print(Y_Validation.shape)

        # The 300 training + 300 validation samples files
        # data_path = './samples/'
        # # read in training and validation data
        # X_train = np.load(data_path+'train_data.npy')
        # Y_train = np.load(data_path+'train_label.npy')
        # X_Validation = np.load(data_path+'vali_data.npy')
        # Y_Validation = np.load(data_path+'vali_label.npy')

        patch_size = 224
        IMG_WIDTH = patch_size
        IMG_HEIGHT = patch_size
        # Number of feature channels 
        INPUT_CHANNELS = 8
        # Number of output masks (1 in case you predict only one type of objects)
        OUTPUT_MASK_CHANNELS = 1
        maxepoch = 50
        # hyperparameters
        # learning_rate = 0.0000359
        # learning_rate = 0.0001
        learning_rate = 0.001
        patience = 10
        aug = 'v'
        transfered_model.compile(optimizer=Adam(lr=learning_rate),loss = dice_coef_loss, metrics=[dice_coef,'accuracy'])
        callbacks = [
                ReduceLROnPlateau(monitor='val_loss', factor=0.7, patience=patience, min_lr=1e-9, verbose=1, mode='min'),
                EarlyStopping(monitor='val_loss', patience=patience+10, verbose=0),
                ModelCheckpoint('first_pass_model'+aug+'_attention2.h5', monitor='val_loss', save_best_only=True, verbose=0),
            ]

        fine_tuned_model_P1_history = transfered_model.fit(X_train_new, Y_train, validation_data=(X_Validation_new,Y_Validation), batch_size=2, epochs=maxepoch, callbacks=callbacks)


        for (index, layer) in enumerate(transfered_model.layers):
            layer.trainable = True


        patch_size = 224
        IMG_WIDTH = patch_size
        IMG_HEIGHT = patch_size
        # Number of feature channels 
        INPUT_CHANNELS = 8
        # Number of output masks (1 in case you predict only one type of objects)
        OUTPUT_MASK_CHANNELS = 1
        maxepoch = 50
        # hyperparameters
        # 100 times smaller learning rate
        learning_rate = 0.0000359
        patience = 10
        aug = 'v'
        transfered_model.compile(optimizer=Adam(lr=learning_rate),loss = dice_coef_loss,metrics=[dice_coef,'accuracy'])
        callbacks = [
                ReduceLROnPlateau(monitor='val_loss', factor=0.7, patience=patience, min_lr=1e-9, verbose=1, mode='min'),
                EarlyStopping(monitor='val_loss', patience=patience+10, verbose=0),
                ModelCheckpoint('second_pass_model'+aug+'_attention2.h5', monitor='val_loss', save_best_only=True, verbose=0),
            ]

        fine_tuned_model_P2_history = transfered_model.fit(X_train_new, Y_train, validation_data=(X_Validation_new,Y_Validation), batch_size=1, epochs=maxepoch, callbacks=callbacks)


        import pickle
        # save the trained model
        model_yaml = transfered_model.to_yaml()
        with open(root_path+name+".yaml", "w") as yaml_file:
            yaml_file.write(model_yaml)
        # save the weights
        transfered_model.save(root_path+name+".h5")
        # save the intermdediate rescults and training statistics
        with open(root_path+name+".pickle", 'wb') as file_pi:
            pickle.dump(fine_tuned_model_P2_history.history, file_pi, protocol=2)

        from IPython.display import Audio
        sound_file = '../../wink.mp3'

        Audio(sound_file, autoplay=True)
# Out:
# Using TensorFlow backend.
# 2.1.0
# model_fine_tuning_No_NAIP_30_samples_r1_
# exists
# model_fine_tuning_No_NAIP_30_samples_r2_
# exists
# model_fine_tuning_No_NAIP_30_samples_r3_
# exists
# model_fine_tuning_No_NAIP_30_samples_r4_
# exists
# model_fine_tuning_No_NAIP_30_samples_r5_
# exists
# model_fine_tuning_No_NAIP_30_samples_r6_
# exists
# model_fine_tuning_No_NAIP_30_samples_r7_
# exists
# model_fine_tuning_No_NAIP_30_samples_r8_
# exists
# model_fine_tuning_No_NAIP_30_samples_r9_
# exists
# model_fine_tuning_No_NAIP_30_samples_r10_
# exists
# model_fine_tuning_No_NAIP_40_samples_r1_
# exists
# model_fine_tuning_No_NAIP_40_samples_r2_
# exists
# model_fine_tuning_No_NAIP_40_samples_r3_
# exists
# model_fine_tuning_No_NAIP_40_samples_r4_
# exists
# model_fine_tuning_No_NAIP_40_samples_r5_
# exists
# model_fine_tuning_No_NAIP_40_samples_r6_
# exists
# model_fine_tuning_No_NAIP_40_samples_r7_
# exists
# model_fine_tuning_No_NAIP_40_samples_r8_
# exists
# model_fine_tuning_No_NAIP_40_samples_r9_
# exists
# model_fine_tuning_No_NAIP_40_samples_r10_
# exists
# model_fine_tuning_No_NAIP_50_samples_r1_
# exists
# model_fine_tuning_No_NAIP_50_samples_r2_
# exists
# model_fine_tuning_No_NAIP_50_samples_r3_
# exists
# model_fine_tuning_No_NAIP_50_samples_r4_
# exists
# model_fine_tuning_No_NAIP_50_samples_r5_
# exists
# model_fine_tuning_No_NAIP_50_samples_r6_
# exists
# model_fine_tuning_No_NAIP_50_samples_r7_
# exists
# model_fine_tuning_No_NAIP_50_samples_r8_
# exists
# model_fine_tuning_No_NAIP_50_samples_r9_
# exists
# model_fine_tuning_No_NAIP_50_samples_r10_
# exists
# model_fine_tuning_No_NAIP_60_samples_r1_
# exists
# model_fine_tuning_No_NAIP_60_samples_r2_
# exists
# model_fine_tuning_No_NAIP_60_samples_r3_
# exists
# model_fine_tuning_No_NAIP_60_samples_r4_
# exists
# model_fine_tuning_No_NAIP_60_samples_r5_
# exists
# model_fine_tuning_No_NAIP_60_samples_r6_
# exists
# model_fine_tuning_No_NAIP_60_samples_r7_
# exists
# model_fine_tuning_No_NAIP_60_samples_r8_
# exists
# model_fine_tuning_No_NAIP_60_samples_r9_
# exists
# model_fine_tuning_No_NAIP_60_samples_r10_
# exists
# model_fine_tuning_No_NAIP_70_samples_r1_
# exists
# model_fine_tuning_No_NAIP_70_samples_r2_
# exists
# model_fine_tuning_No_NAIP_70_samples_r3_
# exists
# model_fine_tuning_No_NAIP_70_samples_r4_
# exists
# model_fine_tuning_No_NAIP_70_samples_r5_
# exists
# model_fine_tuning_No_NAIP_70_samples_r6_
# exists
# model_fine_tuning_No_NAIP_70_samples_r7_
# exists
# model_fine_tuning_No_NAIP_70_samples_r8_
# exists
# model_fine_tuning_No_NAIP_70_samples_r9_
# exists
# model_fine_tuning_No_NAIP_70_samples_r10_
# exists
# model_fine_tuning_No_NAIP_80_samples_r1_
# exists
# model_fine_tuning_No_NAIP_80_samples_r2_
# exists
# model_fine_tuning_No_NAIP_80_samples_r3_
# exists
# model_fine_tuning_No_NAIP_80_samples_r4_
# exists
# model_fine_tuning_No_NAIP_80_samples_r5_
# exists
# model_fine_tuning_No_NAIP_80_samples_r6_
# exists
# model_fine_tuning_No_NAIP_80_samples_r7_
# exists
# model_fine_tuning_No_NAIP_80_samples_r8_
# exists
# model_fine_tuning_No_NAIP_80_samples_r9_
# exists
# model_fine_tuning_No_NAIP_80_samples_r10_
# exists
# model_fine_tuning_No_NAIP_90_samples_r1_
# exists
# model_fine_tuning_No_NAIP_90_samples_r2_
# exists
# model_fine_tuning_No_NAIP_90_samples_r3_
# exists
# model_fine_tuning_No_NAIP_90_samples_r4_
# exists
# model_fine_tuning_No_NAIP_90_samples_r5_
# exists
# model_fine_tuning_No_NAIP_90_samples_r6_
# exists
# model_fine_tuning_No_NAIP_90_samples_r7_
# exists
# model_fine_tuning_No_NAIP_90_samples_r8_
# exists
# model_fine_tuning_No_NAIP_90_samples_r9_
# exists
# model_fine_tuning_No_NAIP_90_samples_r10_
# exists
# model_fine_tuning_No_NAIP_100_samples_r1_
# exists
# model_fine_tuning_No_NAIP_100_samples_r2_
# exists
# model_fine_tuning_No_NAIP_100_samples_r3_
# exists
# model_fine_tuning_No_NAIP_100_samples_r4_
# exists
# model_fine_tuning_No_NAIP_100_samples_r5_
# exists
# model_fine_tuning_No_NAIP_100_samples_r6_
# exists
# model_fine_tuning_No_NAIP_100_samples_r7_
# exists
# model_fine_tuning_No_NAIP_100_samples_r8_
# index  0
# index  1
# index  2
# index  3
# (80, 224, 224, 8)
# (80, 224, 224, 1)
# (20, 224, 224, 8)
# (20, 224, 224, 1)
# Train on 80 samples, validate on 20 samples
# Epoch 1/50
# 80/80 [==============================] - 11s 132ms/step - loss: -0.0610 - dice_coef: 0.0610 - accuracy: 0.0455 - val_loss: -0.0275 - val_dice_coef: 0.0275 - val_accuracy: 0.0156
# Epoch 2/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.0727 - dice_coef: 0.0727 - accuracy: 0.0783 - val_loss: -0.0318 - val_dice_coef: 0.0318 - val_accuracy: 0.3861
# Epoch 3/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.0855 - dice_coef: 0.0855 - accuracy: 0.3413 - val_loss: -0.0443 - val_dice_coef: 0.0443 - val_accuracy: 0.7611
# Epoch 4/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.1104 - dice_coef: 0.1104 - accuracy: 0.6272 - val_loss: -0.0568 - val_dice_coef: 0.0568 - val_accuracy: 0.9718
# Epoch 5/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.1643 - dice_coef: 0.1643 - accuracy: 0.9598 - val_loss: -0.0866 - val_dice_coef: 0.0866 - val_accuracy: 0.9842
# Epoch 6/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.2593 - dice_coef: 0.2593 - accuracy: 0.9623 - val_loss: -0.1461 - val_dice_coef: 0.1461 - val_accuracy: 0.9682
# Epoch 7/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.3813 - dice_coef: 0.3813 - accuracy: 0.9669 - val_loss: -0.0300 - val_dice_coef: 0.0300 - val_accuracy: 0.0879
# Epoch 8/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.4533 - dice_coef: 0.4533 - accuracy: 0.9696 - val_loss: -0.0672 - val_dice_coef: 0.0672 - val_accuracy: 0.6759
# Epoch 9/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.4990 - dice_coef: 0.4990 - accuracy: 0.9712 - val_loss: -0.1340 - val_dice_coef: 0.1340 - val_accuracy: 0.8734
# Epoch 10/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.4696 - dice_coef: 0.4696 - accuracy: 0.9693 - val_loss: -0.1333 - val_dice_coef: 0.1333 - val_accuracy: 0.6599
# Epoch 11/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5209 - dice_coef: 0.5209 - accuracy: 0.9724 - val_loss: -0.1753 - val_dice_coef: 0.1753 - val_accuracy: 0.9192
# Epoch 12/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5460 - dice_coef: 0.5460 - accuracy: 0.9722 - val_loss: -0.2465 - val_dice_coef: 0.2465 - val_accuracy: 0.9869
# Epoch 13/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5419 - dice_coef: 0.5419 - accuracy: 0.9729 - val_loss: -0.2446 - val_dice_coef: 0.2446 - val_accuracy: 0.9856
# Epoch 14/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5651 - dice_coef: 0.5651 - accuracy: 0.9734 - val_loss: -0.2571 - val_dice_coef: 0.2571 - val_accuracy: 0.9827
# Epoch 15/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5505 - dice_coef: 0.5505 - accuracy: 0.9743 - val_loss: -0.2074 - val_dice_coef: 0.2074 - val_accuracy: 0.9688
# Epoch 16/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5825 - dice_coef: 0.5825 - accuracy: 0.9750 - val_loss: -0.2768 - val_dice_coef: 0.2768 - val_accuracy: 0.9795
# Epoch 17/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5630 - dice_coef: 0.5630 - accuracy: 0.9744 - val_loss: -0.2677 - val_dice_coef: 0.2677 - val_accuracy: 0.9859
# Epoch 18/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5682 - dice_coef: 0.5682 - accuracy: 0.9753 - val_loss: -0.2702 - val_dice_coef: 0.2702 - val_accuracy: 0.9855
# Epoch 19/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5898 - dice_coef: 0.5898 - accuracy: 0.9757 - val_loss: -0.2889 - val_dice_coef: 0.2889 - val_accuracy: 0.9868
# Epoch 20/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6166 - dice_coef: 0.6166 - accuracy: 0.9768 - val_loss: -0.2794 - val_dice_coef: 0.2794 - val_accuracy: 0.9858
# Epoch 21/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5787 - dice_coef: 0.5787 - accuracy: 0.9755 - val_loss: -0.2844 - val_dice_coef: 0.2844 - val_accuracy: 0.9868
# Epoch 22/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5897 - dice_coef: 0.5897 - accuracy: 0.9768 - val_loss: -0.2722 - val_dice_coef: 0.2722 - val_accuracy: 0.9837
# Epoch 23/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5763 - dice_coef: 0.5763 - accuracy: 0.9749 - val_loss: -0.2652 - val_dice_coef: 0.2652 - val_accuracy: 0.9818
# Epoch 24/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5863 - dice_coef: 0.5863 - accuracy: 0.9761 - val_loss: -0.2625 - val_dice_coef: 0.2625 - val_accuracy: 0.9842
# Epoch 25/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5850 - dice_coef: 0.5850 - accuracy: 0.9768 - val_loss: -0.2701 - val_dice_coef: 0.2701 - val_accuracy: 0.9848
# Epoch 26/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5789 - dice_coef: 0.5789 - accuracy: 0.9767 - val_loss: -0.2823 - val_dice_coef: 0.2823 - val_accuracy: 0.9855
# Epoch 27/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5831 - dice_coef: 0.5831 - accuracy: 0.9756 - val_loss: -0.2906 - val_dice_coef: 0.2906 - val_accuracy: 0.9843
# Epoch 28/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6036 - dice_coef: 0.6036 - accuracy: 0.9769 - val_loss: -0.2799 - val_dice_coef: 0.2799 - val_accuracy: 0.9832
# Epoch 29/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5976 - dice_coef: 0.5976 - accuracy: 0.9772 - val_loss: -0.2905 - val_dice_coef: 0.2905 - val_accuracy: 0.9878
# Epoch 30/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5968 - dice_coef: 0.5968 - accuracy: 0.9769 - val_loss: -0.2973 - val_dice_coef: 0.2973 - val_accuracy: 0.9891
# Epoch 31/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6377 - dice_coef: 0.6377 - accuracy: 0.9780 - val_loss: -0.2490 - val_dice_coef: 0.2490 - val_accuracy: 0.9856
# Epoch 32/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5681 - dice_coef: 0.5681 - accuracy: 0.9751 - val_loss: -0.2892 - val_dice_coef: 0.2892 - val_accuracy: 0.9870
# Epoch 33/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5856 - dice_coef: 0.5856 - accuracy: 0.9766 - val_loss: -0.2245 - val_dice_coef: 0.2245 - val_accuracy: 0.9819
# Epoch 34/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5994 - dice_coef: 0.5994 - accuracy: 0.9774 - val_loss: -0.2481 - val_dice_coef: 0.2481 - val_accuracy: 0.9840
# Epoch 35/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5970 - dice_coef: 0.5970 - accuracy: 0.9766 - val_loss: -0.2424 - val_dice_coef: 0.2424 - val_accuracy: 0.9860
# Epoch 36/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5457 - dice_coef: 0.5457 - accuracy: 0.9759 - val_loss: -0.2922 - val_dice_coef: 0.2922 - val_accuracy: 0.9853
# Epoch 37/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5715 - dice_coef: 0.5715 - accuracy: 0.9755 - val_loss: -0.2852 - val_dice_coef: 0.2852 - val_accuracy: 0.9860
# Epoch 38/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5886 - dice_coef: 0.5886 - accuracy: 0.9767 - val_loss: -0.2956 - val_dice_coef: 0.2956 - val_accuracy: 0.9877
# Epoch 39/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6273 - dice_coef: 0.6273 - accuracy: 0.9782 - val_loss: -0.2855 - val_dice_coef: 0.2855 - val_accuracy: 0.9875
# Epoch 40/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5712 - dice_coef: 0.5712 - accuracy: 0.9761 - val_loss: -0.2948 - val_dice_coef: 0.2948 - val_accuracy: 0.9871
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# Epoch 41/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5876 - dice_coef: 0.5876 - accuracy: 0.9770 - val_loss: -0.2767 - val_dice_coef: 0.2767 - val_accuracy: 0.9856
# Epoch 42/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6078 - dice_coef: 0.6078 - accuracy: 0.9775 - val_loss: -0.2678 - val_dice_coef: 0.2678 - val_accuracy: 0.9864
# Epoch 43/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6363 - dice_coef: 0.6363 - accuracy: 0.9789 - val_loss: -0.2881 - val_dice_coef: 0.2881 - val_accuracy: 0.9884
# Epoch 44/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5863 - dice_coef: 0.5863 - accuracy: 0.9755 - val_loss: -0.2951 - val_dice_coef: 0.2951 - val_accuracy: 0.9871
# Epoch 45/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6154 - dice_coef: 0.6154 - accuracy: 0.9770 - val_loss: -0.2875 - val_dice_coef: 0.2875 - val_accuracy: 0.9860
# Epoch 46/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6014 - dice_coef: 0.6014 - accuracy: 0.9775 - val_loss: -0.2914 - val_dice_coef: 0.2914 - val_accuracy: 0.9866
# Epoch 47/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5632 - dice_coef: 0.5632 - accuracy: 0.9769 - val_loss: -0.2914 - val_dice_coef: 0.2914 - val_accuracy: 0.9849
# Epoch 48/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5767 - dice_coef: 0.5767 - accuracy: 0.9766 - val_loss: -0.2880 - val_dice_coef: 0.2880 - val_accuracy: 0.9828
# Epoch 49/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6260 - dice_coef: 0.6260 - accuracy: 0.9790 - val_loss: -0.2977 - val_dice_coef: 0.2977 - val_accuracy: 0.9849
# Epoch 50/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6141 - dice_coef: 0.6141 - accuracy: 0.9783 - val_loss: -0.2920 - val_dice_coef: 0.2920 - val_accuracy: 0.9866
# Train on 80 samples, validate on 20 samples
# Epoch 1/50
# 80/80 [==============================] - 21s 264ms/step - loss: -0.4549 - dice_coef: 0.4549 - accuracy: 0.9683 - val_loss: -0.1796 - val_dice_coef: 0.1796 - val_accuracy: 0.9849
# Epoch 2/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.5145 - dice_coef: 0.5145 - accuracy: 0.9772 - val_loss: -0.1573 - val_dice_coef: 0.1573 - val_accuracy: 0.9790
# Epoch 3/50
# 80/80 [==============================] - 10s 122ms/step - loss: -0.5489 - dice_coef: 0.5489 - accuracy: 0.9824 - val_loss: -0.1979 - val_dice_coef: 0.1979 - val_accuracy: 0.9851
# Epoch 4/50
# 80/80 [==============================] - 10s 123ms/step - loss: -0.5705 - dice_coef: 0.5705 - accuracy: 0.9847 - val_loss: -0.1455 - val_dice_coef: 0.1455 - val_accuracy: 0.9763
# Epoch 5/50
# 80/80 [==============================] - 10s 123ms/step - loss: -0.5771 - dice_coef: 0.5771 - accuracy: 0.9860 - val_loss: -0.2179 - val_dice_coef: 0.2179 - val_accuracy: 0.9856
# Epoch 6/50
# 80/80 [==============================] - 10s 122ms/step - loss: -0.5867 - dice_coef: 0.5867 - accuracy: 0.9866 - val_loss: -0.2152 - val_dice_coef: 0.2152 - val_accuracy: 0.9775
# Epoch 7/50
# 80/80 [==============================] - 10s 122ms/step - loss: -0.5976 - dice_coef: 0.5976 - accuracy: 0.9881 - val_loss: -0.1936 - val_dice_coef: 0.1936 - val_accuracy: 0.9809
# Epoch 8/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.5983 - dice_coef: 0.5983 - accuracy: 0.9882 - val_loss: -0.2296 - val_dice_coef: 0.2296 - val_accuracy: 0.9832
# Epoch 9/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.6050 - dice_coef: 0.6050 - accuracy: 0.9896 - val_loss: -0.2112 - val_dice_coef: 0.2112 - val_accuracy: 0.9709
# Epoch 10/50
# 80/80 [==============================] - 10s 122ms/step - loss: -0.6121 - dice_coef: 0.6121 - accuracy: 0.9899 - val_loss: -0.2532 - val_dice_coef: 0.2532 - val_accuracy: 0.9806
# Epoch 11/50
# 80/80 [==============================] - 10s 122ms/step - loss: -0.6114 - dice_coef: 0.6114 - accuracy: 0.9909 - val_loss: -0.2500 - val_dice_coef: 0.2500 - val_accuracy: 0.9842
# Epoch 12/50
# 80/80 [==============================] - 10s 122ms/step - loss: -0.6169 - dice_coef: 0.6169 - accuracy: 0.9906 - val_loss: -0.2387 - val_dice_coef: 0.2387 - val_accuracy: 0.9783
# Epoch 13/50
# 80/80 [==============================] - 10s 124ms/step - loss: -0.6081 - dice_coef: 0.6081 - accuracy: 0.9897 - val_loss: -0.2014 - val_dice_coef: 0.2014 - val_accuracy: 0.9833
# Epoch 14/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6255 - dice_coef: 0.6255 - accuracy: 0.9911 - val_loss: -0.2258 - val_dice_coef: 0.2258 - val_accuracy: 0.9839
# Epoch 15/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6234 - dice_coef: 0.6234 - accuracy: 0.9912 - val_loss: -0.2169 - val_dice_coef: 0.2169 - val_accuracy: 0.9833
# Epoch 16/50
# 80/80 [==============================] - 10s 122ms/step - loss: -0.6319 - dice_coef: 0.6319 - accuracy: 0.9923 - val_loss: -0.2160 - val_dice_coef: 0.2160 - val_accuracy: 0.9805
# Epoch 17/50
# 80/80 [==============================] - 9s 119ms/step - loss: -0.6365 - dice_coef: 0.6365 - accuracy: 0.9933 - val_loss: -0.1834 - val_dice_coef: 0.1834 - val_accuracy: 0.9769
# Epoch 18/50
# 80/80 [==============================] - 9s 119ms/step - loss: -0.6265 - dice_coef: 0.6264 - accuracy: 0.9915 - val_loss: -0.1846 - val_dice_coef: 0.1846 - val_accuracy: 0.9813
# Epoch 19/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.6229 - dice_coef: 0.6229 - accuracy: 0.9914 - val_loss: -0.2105 - val_dice_coef: 0.2105 - val_accuracy: 0.9843
# Epoch 20/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.6217 - dice_coef: 0.6217 - accuracy: 0.9921 - val_loss: -0.2138 - val_dice_coef: 0.2138 - val_accuracy: 0.9823
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 2.5130000358331015e-05.
# Epoch 21/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6222 - dice_coef: 0.6222 - accuracy: 0.9914 - val_loss: -0.2433 - val_dice_coef: 0.2433 - val_accuracy: 0.9818
# Epoch 22/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6389 - dice_coef: 0.6389 - accuracy: 0.9931 - val_loss: -0.2269 - val_dice_coef: 0.2269 - val_accuracy: 0.9806
# Epoch 23/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.6439 - dice_coef: 0.6439 - accuracy: 0.9933 - val_loss: -0.2371 - val_dice_coef: 0.2371 - val_accuracy: 0.9788
# Epoch 24/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6579 - dice_coef: 0.6579 - accuracy: 0.9947 - val_loss: -0.2440 - val_dice_coef: 0.2440 - val_accuracy: 0.9802
# Epoch 25/50
# 80/80 [==============================] - 9s 118ms/step - loss: -0.6627 - dice_coef: 0.6627 - accuracy: 0.9950 - val_loss: -0.2351 - val_dice_coef: 0.2351 - val_accuracy: 0.9776
# Epoch 26/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.6685 - dice_coef: 0.6685 - accuracy: 0.9954 - val_loss: -0.2611 - val_dice_coef: 0.2611 - val_accuracy: 0.9796
# Epoch 27/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6599 - dice_coef: 0.6599 - accuracy: 0.9946 - val_loss: -0.2250 - val_dice_coef: 0.2250 - val_accuracy: 0.9755
# Epoch 28/50
# 80/80 [==============================] - 9s 119ms/step - loss: -0.6640 - dice_coef: 0.6640 - accuracy: 0.9946 - val_loss: -0.2393 - val_dice_coef: 0.2393 - val_accuracy: 0.9760
# Epoch 29/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.6745 - dice_coef: 0.6745 - accuracy: 0.9954 - val_loss: -0.2448 - val_dice_coef: 0.2448 - val_accuracy: 0.9759
# Epoch 30/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.6781 - dice_coef: 0.6781 - accuracy: 0.9955 - val_loss: -0.2508 - val_dice_coef: 0.2508 - val_accuracy: 0.9773
# Epoch 31/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6842 - dice_coef: 0.6842 - accuracy: 0.9959 - val_loss: -0.2447 - val_dice_coef: 0.2447 - val_accuracy: 0.9774
# Epoch 32/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6872 - dice_coef: 0.6872 - accuracy: 0.9961 - val_loss: -0.2607 - val_dice_coef: 0.2607 - val_accuracy: 0.9796
# Epoch 33/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.6875 - dice_coef: 0.6875 - accuracy: 0.9957 - val_loss: -0.2542 - val_dice_coef: 0.2542 - val_accuracy: 0.9759
# Epoch 34/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.6927 - dice_coef: 0.6927 - accuracy: 0.9960 - val_loss: -0.2663 - val_dice_coef: 0.2663 - val_accuracy: 0.9798
# Epoch 35/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.6978 - dice_coef: 0.6978 - accuracy: 0.9961 - val_loss: -0.2541 - val_dice_coef: 0.2541 - val_accuracy: 0.9808
# Epoch 36/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.6984 - dice_coef: 0.6984 - accuracy: 0.9960 - val_loss: -0.2717 - val_dice_coef: 0.2717 - val_accuracy: 0.9796
# Epoch 37/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.7031 - dice_coef: 0.7031 - accuracy: 0.9959 - val_loss: -0.2818 - val_dice_coef: 0.2818 - val_accuracy: 0.9826
# Epoch 38/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.7076 - dice_coef: 0.7076 - accuracy: 0.9961 - val_loss: -0.2793 - val_dice_coef: 0.2793 - val_accuracy: 0.9813
# Epoch 39/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.7137 - dice_coef: 0.7137 - accuracy: 0.9964 - val_loss: -0.2795 - val_dice_coef: 0.2795 - val_accuracy: 0.9798
# Epoch 40/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.7188 - dice_coef: 0.7188 - accuracy: 0.9965 - val_loss: -0.2813 - val_dice_coef: 0.2813 - val_accuracy: 0.9807
# Epoch 41/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.7199 - dice_coef: 0.7199 - accuracy: 0.9962 - val_loss: -0.2763 - val_dice_coef: 0.2763 - val_accuracy: 0.9794
# Epoch 42/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.7242 - dice_coef: 0.7242 - accuracy: 0.9965 - val_loss: -0.3000 - val_dice_coef: 0.3000 - val_accuracy: 0.9805
# Epoch 43/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.7277 - dice_coef: 0.7277 - accuracy: 0.9965 - val_loss: -0.2768 - val_dice_coef: 0.2768 - val_accuracy: 0.9809
# Epoch 44/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.7345 - dice_coef: 0.7345 - accuracy: 0.9967 - val_loss: -0.3070 - val_dice_coef: 0.3070 - val_accuracy: 0.9807
# Epoch 45/50
# 80/80 [==============================] - 9s 118ms/step - loss: -0.7394 - dice_coef: 0.7394 - accuracy: 0.9968 - val_loss: -0.3167 - val_dice_coef: 0.3167 - val_accuracy: 0.9818
# Epoch 46/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.7413 - dice_coef: 0.7413 - accuracy: 0.9966 - val_loss: -0.3106 - val_dice_coef: 0.3106 - val_accuracy: 0.9824
# Epoch 47/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.7451 - dice_coef: 0.7451 - accuracy: 0.9967 - val_loss: -0.3049 - val_dice_coef: 0.3049 - val_accuracy: 0.9804
# Epoch 48/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.7480 - dice_coef: 0.7480 - accuracy: 0.9967 - val_loss: -0.3072 - val_dice_coef: 0.3072 - val_accuracy: 0.9810
# Epoch 49/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.7494 - dice_coef: 0.7494 - accuracy: 0.9967 - val_loss: -0.3180 - val_dice_coef: 0.3180 - val_accuracy: 0.9825
# Epoch 50/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.7514 - dice_coef: 0.7514 - accuracy: 0.9965 - val_loss: -0.3335 - val_dice_coef: 0.3335 - val_accuracy: 0.9794
# model_fine_tuning_No_NAIP_100_samples_r9_
# index  0
# index  1
# index  2
# index  3
# (80, 224, 224, 8)
# (80, 224, 224, 1)
# (20, 224, 224, 8)
# (20, 224, 224, 1)
# Train on 80 samples, validate on 20 samples
# Epoch 1/50
# 80/80 [==============================] - 7s 92ms/step - loss: -0.0588 - dice_coef: 0.0588 - accuracy: 0.5986 - val_loss: -0.0432 - val_dice_coef: 0.0432 - val_accuracy: 0.5103
# Epoch 2/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.1187 - dice_coef: 0.1187 - accuracy: 0.8310 - val_loss: -0.0870 - val_dice_coef: 0.0870 - val_accuracy: 0.9629
# Epoch 3/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.1990 - dice_coef: 0.1990 - accuracy: 0.9607 - val_loss: -0.1180 - val_dice_coef: 0.1180 - val_accuracy: 0.9204
# Epoch 4/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.2820 - dice_coef: 0.2820 - accuracy: 0.9608 - val_loss: -0.1375 - val_dice_coef: 0.1375 - val_accuracy: 0.8775
# Epoch 5/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.3859 - dice_coef: 0.3859 - accuracy: 0.9639 - val_loss: -0.0451 - val_dice_coef: 0.0451 - val_accuracy: 0.0847
# Epoch 6/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.4572 - dice_coef: 0.4572 - accuracy: 0.9672 - val_loss: -0.1226 - val_dice_coef: 0.1226 - val_accuracy: 0.7566
# Epoch 7/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.4669 - dice_coef: 0.4669 - accuracy: 0.9667 - val_loss: -0.2065 - val_dice_coef: 0.2065 - val_accuracy: 0.9396
# Epoch 8/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5033 - dice_coef: 0.5033 - accuracy: 0.9674 - val_loss: -0.2074 - val_dice_coef: 0.2074 - val_accuracy: 0.9771
# Epoch 9/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5595 - dice_coef: 0.5595 - accuracy: 0.9709 - val_loss: -0.1977 - val_dice_coef: 0.1977 - val_accuracy: 0.9772
# Epoch 10/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5151 - dice_coef: 0.5151 - accuracy: 0.9682 - val_loss: -0.2084 - val_dice_coef: 0.2084 - val_accuracy: 0.9746
# Epoch 11/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5804 - dice_coef: 0.5804 - accuracy: 0.9726 - val_loss: -0.1310 - val_dice_coef: 0.1310 - val_accuracy: 0.9760
# Epoch 12/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5511 - dice_coef: 0.5511 - accuracy: 0.9690 - val_loss: -0.1039 - val_dice_coef: 0.1039 - val_accuracy: 0.9798
# Epoch 13/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5722 - dice_coef: 0.5722 - accuracy: 0.9712 - val_loss: -0.0944 - val_dice_coef: 0.0944 - val_accuracy: 0.9801
# Epoch 14/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6103 - dice_coef: 0.6103 - accuracy: 0.9728 - val_loss: -0.0866 - val_dice_coef: 0.0866 - val_accuracy: 0.9799
# Epoch 15/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6026 - dice_coef: 0.6026 - accuracy: 0.9721 - val_loss: -0.1105 - val_dice_coef: 0.1105 - val_accuracy: 0.9802
# Epoch 16/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5796 - dice_coef: 0.5796 - accuracy: 0.9725 - val_loss: -0.1153 - val_dice_coef: 0.1153 - val_accuracy: 0.9802
# Epoch 17/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6107 - dice_coef: 0.6107 - accuracy: 0.9739 - val_loss: -0.1619 - val_dice_coef: 0.1619 - val_accuracy: 0.9772
# Epoch 18/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6120 - dice_coef: 0.6120 - accuracy: 0.9728 - val_loss: -0.1756 - val_dice_coef: 0.1756 - val_accuracy: 0.9753
# Epoch 19/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5740 - dice_coef: 0.5740 - accuracy: 0.9728 - val_loss: -0.1243 - val_dice_coef: 0.1243 - val_accuracy: 0.9768
# Epoch 20/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6206 - dice_coef: 0.6206 - accuracy: 0.9740 - val_loss: -0.1232 - val_dice_coef: 0.1232 - val_accuracy: 0.9777
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# Epoch 21/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5997 - dice_coef: 0.5997 - accuracy: 0.9731 - val_loss: -0.1103 - val_dice_coef: 0.1103 - val_accuracy: 0.9802
# Epoch 22/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6575 - dice_coef: 0.6575 - accuracy: 0.9759 - val_loss: -0.1069 - val_dice_coef: 0.1069 - val_accuracy: 0.9803
# Epoch 23/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6589 - dice_coef: 0.6589 - accuracy: 0.9758 - val_loss: -0.1143 - val_dice_coef: 0.1143 - val_accuracy: 0.9804
# Epoch 24/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6356 - dice_coef: 0.6356 - accuracy: 0.9750 - val_loss: -0.1134 - val_dice_coef: 0.1134 - val_accuracy: 0.9803
# Epoch 25/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6071 - dice_coef: 0.6071 - accuracy: 0.9750 - val_loss: -0.1178 - val_dice_coef: 0.1178 - val_accuracy: 0.9798
# Epoch 26/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6443 - dice_coef: 0.6443 - accuracy: 0.9756 - val_loss: -0.1263 - val_dice_coef: 0.1263 - val_accuracy: 0.9786
# Epoch 27/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6556 - dice_coef: 0.6556 - accuracy: 0.9765 - val_loss: -0.1272 - val_dice_coef: 0.1272 - val_accuracy: 0.9773
# Epoch 28/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6612 - dice_coef: 0.6612 - accuracy: 0.9770 - val_loss: -0.1314 - val_dice_coef: 0.1314 - val_accuracy: 0.9791
# Epoch 29/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6495 - dice_coef: 0.6495 - accuracy: 0.9756 - val_loss: -0.1062 - val_dice_coef: 0.1062 - val_accuracy: 0.9794
# Epoch 30/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6410 - dice_coef: 0.6410 - accuracy: 0.9751 - val_loss: -0.1068 - val_dice_coef: 0.1068 - val_accuracy: 0.9801
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0004900000232737511.
# Train on 80 samples, validate on 20 samples
# Epoch 1/50
# 80/80 [==============================] - 18s 228ms/step - loss: -0.5143 - dice_coef: 0.5143 - accuracy: 0.9703 - val_loss: -0.0819 - val_dice_coef: 0.0819 - val_accuracy: 0.9803
# Epoch 2/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.5718 - dice_coef: 0.5718 - accuracy: 0.9781 - val_loss: -0.1185 - val_dice_coef: 0.1185 - val_accuracy: 0.9787
# Epoch 3/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6021 - dice_coef: 0.6021 - accuracy: 0.9798 - val_loss: -0.1573 - val_dice_coef: 0.1573 - val_accuracy: 0.9796
# Epoch 4/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.6250 - dice_coef: 0.6250 - accuracy: 0.9839 - val_loss: -0.1459 - val_dice_coef: 0.1459 - val_accuracy: 0.9804
# Epoch 5/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6265 - dice_coef: 0.6265 - accuracy: 0.9839 - val_loss: -0.1938 - val_dice_coef: 0.1938 - val_accuracy: 0.9730
# Epoch 6/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.6431 - dice_coef: 0.6431 - accuracy: 0.9858 - val_loss: -0.0864 - val_dice_coef: 0.0864 - val_accuracy: 0.9802
# Epoch 7/50
# 80/80 [==============================] - 9s 118ms/step - loss: -0.6535 - dice_coef: 0.6535 - accuracy: 0.9869 - val_loss: -0.2009 - val_dice_coef: 0.2009 - val_accuracy: 0.9747
# Epoch 8/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6621 - dice_coef: 0.6621 - accuracy: 0.9874 - val_loss: -0.1005 - val_dice_coef: 0.1005 - val_accuracy: 0.9769
# Epoch 9/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6647 - dice_coef: 0.6647 - accuracy: 0.9879 - val_loss: -0.1630 - val_dice_coef: 0.1630 - val_accuracy: 0.9800
# Epoch 10/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6699 - dice_coef: 0.6699 - accuracy: 0.9888 - val_loss: -0.1067 - val_dice_coef: 0.1067 - val_accuracy: 0.9810
# Epoch 11/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6777 - dice_coef: 0.6777 - accuracy: 0.9894 - val_loss: -0.1442 - val_dice_coef: 0.1442 - val_accuracy: 0.9799
# Epoch 12/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6784 - dice_coef: 0.6784 - accuracy: 0.9892 - val_loss: -0.1294 - val_dice_coef: 0.1294 - val_accuracy: 0.9794
# Epoch 13/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6838 - dice_coef: 0.6838 - accuracy: 0.9904 - val_loss: -0.1370 - val_dice_coef: 0.1370 - val_accuracy: 0.9793
# Epoch 14/50
# 80/80 [==============================] - 9s 119ms/step - loss: -0.6882 - dice_coef: 0.6882 - accuracy: 0.9906 - val_loss: -0.1510 - val_dice_coef: 0.1510 - val_accuracy: 0.9795
# Epoch 15/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.6905 - dice_coef: 0.6905 - accuracy: 0.9912 - val_loss: -0.1317 - val_dice_coef: 0.1317 - val_accuracy: 0.9798
# Epoch 16/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.6908 - dice_coef: 0.6908 - accuracy: 0.9914 - val_loss: -0.1149 - val_dice_coef: 0.1149 - val_accuracy: 0.9804
# Epoch 17/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.6917 - dice_coef: 0.6917 - accuracy: 0.9916 - val_loss: -0.1193 - val_dice_coef: 0.1193 - val_accuracy: 0.9792
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 2.5130000358331015e-05.
# Epoch 18/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.6935 - dice_coef: 0.6935 - accuracy: 0.9916 - val_loss: -0.1326 - val_dice_coef: 0.1326 - val_accuracy: 0.9784
# Epoch 19/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6999 - dice_coef: 0.6999 - accuracy: 0.9926 - val_loss: -0.1525 - val_dice_coef: 0.1525 - val_accuracy: 0.9799
# Epoch 20/50
# 80/80 [==============================] - 10s 122ms/step - loss: -0.7021 - dice_coef: 0.7021 - accuracy: 0.9931 - val_loss: -0.1436 - val_dice_coef: 0.1436 - val_accuracy: 0.9795
# Epoch 21/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.7015 - dice_coef: 0.7015 - accuracy: 0.9928 - val_loss: -0.1556 - val_dice_coef: 0.1556 - val_accuracy: 0.9800
# Epoch 22/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.7047 - dice_coef: 0.7047 - accuracy: 0.9934 - val_loss: -0.1557 - val_dice_coef: 0.1557 - val_accuracy: 0.9794
# Epoch 23/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.7049 - dice_coef: 0.7049 - accuracy: 0.9934 - val_loss: -0.1507 - val_dice_coef: 0.1507 - val_accuracy: 0.9795
# Epoch 24/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.7054 - dice_coef: 0.7054 - accuracy: 0.9936 - val_loss: -0.1681 - val_dice_coef: 0.1681 - val_accuracy: 0.9794
# Epoch 25/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.7056 - dice_coef: 0.7056 - accuracy: 0.9936 - val_loss: -0.1571 - val_dice_coef: 0.1571 - val_accuracy: 0.9800
# Epoch 26/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.7054 - dice_coef: 0.7054 - accuracy: 0.9937 - val_loss: -0.1663 - val_dice_coef: 0.1663 - val_accuracy: 0.9793
# Epoch 27/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.7075 - dice_coef: 0.7075 - accuracy: 0.9940 - val_loss: -0.1441 - val_dice_coef: 0.1441 - val_accuracy: 0.9785
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.7591000505490227e-05.
# model_fine_tuning_No_NAIP_100_samples_r10_
# index  0
# index  1
# index  2
# index  3
# (80, 224, 224, 8)
# (80, 224, 224, 1)
# (20, 224, 224, 8)
# (20, 224, 224, 1)
# Train on 80 samples, validate on 20 samples
# Epoch 1/50
# 80/80 [==============================] - 7s 92ms/step - loss: -0.1346 - dice_coef: 0.1346 - accuracy: 0.9668 - val_loss: -0.1755 - val_dice_coef: 0.1755 - val_accuracy: 0.9253
# Epoch 2/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.2118 - dice_coef: 0.2118 - accuracy: 0.9592 - val_loss: -0.1844 - val_dice_coef: 0.1844 - val_accuracy: 0.8355
# Epoch 3/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.3107 - dice_coef: 0.3107 - accuracy: 0.9637 - val_loss: -0.2185 - val_dice_coef: 0.2185 - val_accuracy: 0.8826
# Epoch 4/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.3772 - dice_coef: 0.3772 - accuracy: 0.9647 - val_loss: -0.2144 - val_dice_coef: 0.2144 - val_accuracy: 0.8835
# Epoch 5/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.4412 - dice_coef: 0.4412 - accuracy: 0.9685 - val_loss: -0.2165 - val_dice_coef: 0.2165 - val_accuracy: 0.8615
# Epoch 6/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.4958 - dice_coef: 0.4958 - accuracy: 0.9711 - val_loss: -0.2742 - val_dice_coef: 0.2742 - val_accuracy: 0.8681
# Epoch 7/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5122 - dice_coef: 0.5122 - accuracy: 0.9714 - val_loss: -0.1955 - val_dice_coef: 0.1955 - val_accuracy: 0.8083
# Epoch 8/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5299 - dice_coef: 0.5299 - accuracy: 0.9727 - val_loss: -0.2402 - val_dice_coef: 0.2402 - val_accuracy: 0.8637
# Epoch 9/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5670 - dice_coef: 0.5670 - accuracy: 0.9758 - val_loss: -0.3270 - val_dice_coef: 0.3270 - val_accuracy: 0.9759
# Epoch 10/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5807 - dice_coef: 0.5807 - accuracy: 0.9756 - val_loss: -0.3204 - val_dice_coef: 0.3204 - val_accuracy: 0.9437
# Epoch 11/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5664 - dice_coef: 0.5664 - accuracy: 0.9758 - val_loss: -0.3227 - val_dice_coef: 0.3227 - val_accuracy: 0.9700
# Epoch 12/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5697 - dice_coef: 0.5697 - accuracy: 0.9762 - val_loss: -0.3270 - val_dice_coef: 0.3270 - val_accuracy: 0.9777
# Epoch 13/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6485 - dice_coef: 0.6485 - accuracy: 0.9792 - val_loss: -0.3343 - val_dice_coef: 0.3343 - val_accuracy: 0.9765
# Epoch 14/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6535 - dice_coef: 0.6535 - accuracy: 0.9797 - val_loss: -0.3678 - val_dice_coef: 0.3678 - val_accuracy: 0.9761
# Epoch 15/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6032 - dice_coef: 0.6032 - accuracy: 0.9776 - val_loss: -0.3265 - val_dice_coef: 0.3265 - val_accuracy: 0.8487
# Epoch 16/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5650 - dice_coef: 0.5650 - accuracy: 0.9751 - val_loss: -0.3812 - val_dice_coef: 0.3812 - val_accuracy: 0.9774
# Epoch 17/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6322 - dice_coef: 0.6322 - accuracy: 0.9786 - val_loss: -0.3490 - val_dice_coef: 0.3490 - val_accuracy: 0.9772
# Epoch 18/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6346 - dice_coef: 0.6346 - accuracy: 0.9787 - val_loss: -0.3715 - val_dice_coef: 0.3715 - val_accuracy: 0.9768
# Epoch 19/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6235 - dice_coef: 0.6235 - accuracy: 0.9786 - val_loss: -0.3829 - val_dice_coef: 0.3829 - val_accuracy: 0.9724
# Epoch 20/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6323 - dice_coef: 0.6323 - accuracy: 0.9791 - val_loss: -0.3528 - val_dice_coef: 0.3528 - val_accuracy: 0.9769
# Epoch 21/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.5831 - dice_coef: 0.5831 - accuracy: 0.9771 - val_loss: -0.3801 - val_dice_coef: 0.3801 - val_accuracy: 0.9724
# Epoch 22/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6386 - dice_coef: 0.6386 - accuracy: 0.9796 - val_loss: -0.3796 - val_dice_coef: 0.3796 - val_accuracy: 0.9766
# Epoch 23/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6242 - dice_coef: 0.6242 - accuracy: 0.9797 - val_loss: -0.3900 - val_dice_coef: 0.3900 - val_accuracy: 0.9765
# Epoch 24/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6586 - dice_coef: 0.6586 - accuracy: 0.9805 - val_loss: -0.3723 - val_dice_coef: 0.3723 - val_accuracy: 0.9728
# Epoch 25/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6288 - dice_coef: 0.6288 - accuracy: 0.9792 - val_loss: -0.3952 - val_dice_coef: 0.3952 - val_accuracy: 0.9775
# Epoch 26/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6301 - dice_coef: 0.6301 - accuracy: 0.9794 - val_loss: -0.3805 - val_dice_coef: 0.3805 - val_accuracy: 0.9779
# Epoch 27/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6249 - dice_coef: 0.6249 - accuracy: 0.9789 - val_loss: -0.3046 - val_dice_coef: 0.3046 - val_accuracy: 0.9771
# Epoch 28/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6412 - dice_coef: 0.6412 - accuracy: 0.9799 - val_loss: -0.3866 - val_dice_coef: 0.3866 - val_accuracy: 0.9775
# Epoch 29/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6212 - dice_coef: 0.6212 - accuracy: 0.9787 - val_loss: -0.3790 - val_dice_coef: 0.3790 - val_accuracy: 0.9737
# Epoch 30/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6171 - dice_coef: 0.6171 - accuracy: 0.9781 - val_loss: -0.3804 - val_dice_coef: 0.3804 - val_accuracy: 0.9764
# Epoch 31/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6152 - dice_coef: 0.6152 - accuracy: 0.9788 - val_loss: -0.3889 - val_dice_coef: 0.3889 - val_accuracy: 0.9720
# Epoch 32/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6363 - dice_coef: 0.6363 - accuracy: 0.9796 - val_loss: -0.3750 - val_dice_coef: 0.3750 - val_accuracy: 0.8975
# Epoch 33/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6422 - dice_coef: 0.6422 - accuracy: 0.9794 - val_loss: -0.3865 - val_dice_coef: 0.3865 - val_accuracy: 0.9239
# Epoch 34/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6480 - dice_coef: 0.6480 - accuracy: 0.9793 - val_loss: -0.4365 - val_dice_coef: 0.4365 - val_accuracy: 0.9760
# Epoch 35/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6615 - dice_coef: 0.6615 - accuracy: 0.9805 - val_loss: -0.4069 - val_dice_coef: 0.4069 - val_accuracy: 0.9769
# Epoch 36/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6210 - dice_coef: 0.6210 - accuracy: 0.9793 - val_loss: -0.4036 - val_dice_coef: 0.4036 - val_accuracy: 0.9759
# Epoch 37/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6278 - dice_coef: 0.6278 - accuracy: 0.9792 - val_loss: -0.3792 - val_dice_coef: 0.3792 - val_accuracy: 0.9589
# Epoch 38/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6141 - dice_coef: 0.6141 - accuracy: 0.9772 - val_loss: -0.3057 - val_dice_coef: 0.3057 - val_accuracy: 0.8499
# Epoch 39/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6403 - dice_coef: 0.6403 - accuracy: 0.9802 - val_loss: -0.3094 - val_dice_coef: 0.3094 - val_accuracy: 0.8549
# Epoch 40/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6479 - dice_coef: 0.6479 - accuracy: 0.9803 - val_loss: -0.2610 - val_dice_coef: 0.2610 - val_accuracy: 0.9763
# Epoch 41/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6120 - dice_coef: 0.6120 - accuracy: 0.9793 - val_loss: -0.3413 - val_dice_coef: 0.3413 - val_accuracy: 0.9769
# Epoch 42/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6808 - dice_coef: 0.6808 - accuracy: 0.9819 - val_loss: -0.3943 - val_dice_coef: 0.3943 - val_accuracy: 0.9770
# Epoch 43/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6977 - dice_coef: 0.6977 - accuracy: 0.9823 - val_loss: -0.3353 - val_dice_coef: 0.3353 - val_accuracy: 0.9764
# Epoch 44/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6533 - dice_coef: 0.6533 - accuracy: 0.9807 - val_loss: -0.3138 - val_dice_coef: 0.3138 - val_accuracy: 0.9533
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# Epoch 45/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6344 - dice_coef: 0.6344 - accuracy: 0.9804 - val_loss: -0.3374 - val_dice_coef: 0.3374 - val_accuracy: 0.9774
# Epoch 46/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6654 - dice_coef: 0.6654 - accuracy: 0.9809 - val_loss: -0.3497 - val_dice_coef: 0.3497 - val_accuracy: 0.9776
# Epoch 47/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6468 - dice_coef: 0.6468 - accuracy: 0.9798 - val_loss: -0.3983 - val_dice_coef: 0.3983 - val_accuracy: 0.9772
# Epoch 48/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6434 - dice_coef: 0.6434 - accuracy: 0.9795 - val_loss: -0.3603 - val_dice_coef: 0.3603 - val_accuracy: 0.9775
# Epoch 49/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6926 - dice_coef: 0.6926 - accuracy: 0.9815 - val_loss: -0.3421 - val_dice_coef: 0.3421 - val_accuracy: 0.9775
# Epoch 50/50
# 80/80 [==============================] - 3s 38ms/step - loss: -0.6728 - dice_coef: 0.6728 - accuracy: 0.9816 - val_loss: -0.3629 - val_dice_coef: 0.3629 - val_accuracy: 0.9772
# Train on 80 samples, validate on 20 samples
# Epoch 1/50
# 80/80 [==============================] - 18s 228ms/step - loss: -0.5057 - dice_coef: 0.5057 - accuracy: 0.9732 - val_loss: -0.2794 - val_dice_coef: 0.2794 - val_accuracy: 0.9724
# Epoch 2/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.5558 - dice_coef: 0.5558 - accuracy: 0.9811 - val_loss: -0.3032 - val_dice_coef: 0.3032 - val_accuracy: 0.9722
# Epoch 3/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.5869 - dice_coef: 0.5869 - accuracy: 0.9846 - val_loss: -0.2983 - val_dice_coef: 0.2983 - val_accuracy: 0.9691
# Epoch 4/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.6062 - dice_coef: 0.6062 - accuracy: 0.9863 - val_loss: -0.3133 - val_dice_coef: 0.3133 - val_accuracy: 0.9741
# Epoch 5/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6162 - dice_coef: 0.6162 - accuracy: 0.9885 - val_loss: -0.3121 - val_dice_coef: 0.3121 - val_accuracy: 0.9666
# Epoch 6/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.6277 - dice_coef: 0.6277 - accuracy: 0.9894 - val_loss: -0.2995 - val_dice_coef: 0.2995 - val_accuracy: 0.9681
# Epoch 7/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.6375 - dice_coef: 0.6375 - accuracy: 0.9911 - val_loss: -0.2877 - val_dice_coef: 0.2877 - val_accuracy: 0.9783
# Epoch 8/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.6319 - dice_coef: 0.6319 - accuracy: 0.9900 - val_loss: -0.3349 - val_dice_coef: 0.3349 - val_accuracy: 0.9707
# Epoch 9/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6408 - dice_coef: 0.6408 - accuracy: 0.9914 - val_loss: -0.3510 - val_dice_coef: 0.3510 - val_accuracy: 0.9581
# Epoch 10/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6456 - dice_coef: 0.6456 - accuracy: 0.9919 - val_loss: -0.3259 - val_dice_coef: 0.3259 - val_accuracy: 0.9709
# Epoch 11/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.6410 - dice_coef: 0.6410 - accuracy: 0.9911 - val_loss: -0.3846 - val_dice_coef: 0.3846 - val_accuracy: 0.9696
# Epoch 12/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.6380 - dice_coef: 0.6380 - accuracy: 0.9914 - val_loss: -0.3407 - val_dice_coef: 0.3407 - val_accuracy: 0.9759
# Epoch 13/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6545 - dice_coef: 0.6545 - accuracy: 0.9933 - val_loss: -0.3494 - val_dice_coef: 0.3494 - val_accuracy: 0.9758
# Epoch 14/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.6540 - dice_coef: 0.6540 - accuracy: 0.9933 - val_loss: -0.3279 - val_dice_coef: 0.3279 - val_accuracy: 0.9788
# Epoch 15/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.6661 - dice_coef: 0.6661 - accuracy: 0.9942 - val_loss: -0.3755 - val_dice_coef: 0.3755 - val_accuracy: 0.9750
# Epoch 16/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6452 - dice_coef: 0.6452 - accuracy: 0.9927 - val_loss: -0.3473 - val_dice_coef: 0.3473 - val_accuracy: 0.9759
# Epoch 17/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.6208 - dice_coef: 0.6208 - accuracy: 0.9889 - val_loss: -0.3527 - val_dice_coef: 0.3527 - val_accuracy: 0.9720
# Epoch 18/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.6378 - dice_coef: 0.6378 - accuracy: 0.9915 - val_loss: -0.3194 - val_dice_coef: 0.3194 - val_accuracy: 0.9634
# Epoch 19/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.6419 - dice_coef: 0.6419 - accuracy: 0.9915 - val_loss: -0.3247 - val_dice_coef: 0.3247 - val_accuracy: 0.9763
# Epoch 20/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.6624 - dice_coef: 0.6624 - accuracy: 0.9929 - val_loss: -0.3340 - val_dice_coef: 0.3340 - val_accuracy: 0.9775
# Epoch 21/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.5961 - dice_coef: 0.5961 - accuracy: 0.9849 - val_loss: -0.3634 - val_dice_coef: 0.3634 - val_accuracy: 0.9655
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 2.5130000358331015e-05.
# Epoch 22/50
# 80/80 [==============================] - 10s 122ms/step - loss: -0.6437 - dice_coef: 0.6437 - accuracy: 0.9909 - val_loss: -0.3104 - val_dice_coef: 0.3104 - val_accuracy: 0.9744
# Epoch 23/50
# 80/80 [==============================] - 10s 122ms/step - loss: -0.6630 - dice_coef: 0.6630 - accuracy: 0.9929 - val_loss: -0.3453 - val_dice_coef: 0.3453 - val_accuracy: 0.9763
# Epoch 24/50
# 80/80 [==============================] - 10s 121ms/step - loss: -0.6813 - dice_coef: 0.6813 - accuracy: 0.9936 - val_loss: -0.3497 - val_dice_coef: 0.3497 - val_accuracy: 0.9749
# Epoch 25/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.6919 - dice_coef: 0.6919 - accuracy: 0.9943 - val_loss: -0.3433 - val_dice_coef: 0.3433 - val_accuracy: 0.9765
# Epoch 26/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.7056 - dice_coef: 0.7056 - accuracy: 0.9954 - val_loss: -0.3272 - val_dice_coef: 0.3272 - val_accuracy: 0.9775
# Epoch 27/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.7158 - dice_coef: 0.7158 - accuracy: 0.9960 - val_loss: -0.3290 - val_dice_coef: 0.3290 - val_accuracy: 0.9775
# Epoch 28/50
# 80/80 [==============================] - 10s 120ms/step - loss: -0.7239 - dice_coef: 0.7239 - accuracy: 0.9962 - val_loss: -0.3522 - val_dice_coef: 0.3522 - val_accuracy: 0.9764
# Epoch 29/50
# 80/80 [==============================] - 10s 123ms/step - loss: -0.7293 - dice_coef: 0.7293 - accuracy: 0.9963 - val_loss: -0.3474 - val_dice_coef: 0.3474 - val_accuracy: 0.9763
# Epoch 30/50
# 80/80 [==============================] - 10s 119ms/step - loss: -0.7351 - dice_coef: 0.7351 - accuracy: 0.9964 - val_loss: -0.3478 - val_dice_coef: 0.3478 - val_accuracy: 0.9757
# Epoch 31/50
# 80/80 [==============================] - 9s 119ms/step - loss: -0.7401 - dice_coef: 0.7401 - accuracy: 0.9966 - val_loss: -0.3647 - val_dice_coef: 0.3647 - val_accuracy: 0.9767
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.7591000505490227e-05.

# %%
## Load all the dependencies
import os
import sys
import random
import warnings
import numpy as np
from itertools import chain
from numpy import genfromtxt
from tensorflow import random
from keras import backend as K
# from keras import backend as k
from keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import Layer, UpSampling2D, GlobalAveragePooling2D, Multiply, Dense, Reshape, Permute, multiply, dot, add, Input
from keras.layers.core import Dropout, Lambda, SpatialDropout2D, Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Model, load_model, model_from_yaml, Sequential

import tensorflow as tf

# os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

np.random.seed(1337) # for reproducibility
random.set_seed(1337)
print(tf.__version__)



# Use dice coefficient function as the loss function 
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)

# Jacard coefficient
def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

# calculate loss value
def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)

# calculate loss value
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def Residual_CNN_block(x, size, dropout=0.0, batch_norm=True):
    if K.image_dim_ordering() == 'th':
        axis = 1
    else:
        axis = 3
    conv = Conv2D(size, (3, 3), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    return conv

class multiplication(Layer):
    def __init__(self,inter_channel = None,**kwargs):
        super(multiplication, self).__init__(**kwargs)
        self.inter_channel = inter_channel
    def build(self,input_shape=None):
        self.k = self.add_weight(name='k',shape=(1,),initializer='zeros',dtype='float32',trainable=True)
    def get_config(self):
        base_config = super(multiplication, self).get_config()
        config = {'inter_channel':self.inter_channel}
        return dict(list(base_config.items()) + list(config.items()))  
    def call(self,inputs):
        g,x,x_query,phi_g,x_value = inputs[0],inputs[1],inputs[2],inputs[3],inputs[4]
        h,w,c = int(x.shape[1]),int(x.shape[2]),int(x.shape[3])
        x_query = K.reshape(x_query, shape=(-1,h*w, self.inter_channel//4))
        phi_g = K.reshape(phi_g,shape=(-1,h*w,self.inter_channel//4))
        x_value = K.reshape(x_value,shape=(-1,h*w,c))
        scale = dot([K.permute_dimensions(phi_g,(0,2,1)), x_query], axes=(1, 2))
        soft_scale = Activation('softmax')(scale)
        scaled_value = dot([K.permute_dimensions(soft_scale,(0,2,1)),K.permute_dimensions(x_value,(0,2,1))],axes=(1, 2))
        scaled_value = K.reshape(scaled_value, shape=(-1,h,w,c))        
        customize_multi = self.k * scaled_value
        layero = add([customize_multi,x])
        my_concat = Lambda(lambda x: K.concatenate([x[0], x[1]], axis=3))
        concate = my_concat([layero,g])
        return concate 
    def compute_output_shape(self,input_shape):
        ll = list(input_shape)[1]
        return (None,ll[1],ll[1],ll[3]*3)
    def get_custom_objects():
        return {'multiplication': multiplication}

def attention_up_and_concatenate(inputs):
    g,x = inputs[0],inputs[1]
    inter_channel = g.get_shape().as_list()[3]
    g = Conv2DTranspose(inter_channel, (2,2), strides=[2, 2],padding='same')(g)
    x_query = Conv2D(inter_channel//4, [1, 1], strides=[1, 1], data_format='channels_last')(x)
    phi_g = Conv2D(inter_channel//4, [1, 1], strides=[1, 1], data_format='channels_last')(g)
    x_value = Conv2D(inter_channel//2, [1, 1], strides=[1, 1], data_format='channels_last')(x)
    inputs = [g,x,x_query,phi_g,x_value]
    concate = multiplication(inter_channel)(inputs)
    return concate

class multiplication2(Layer):
    def __init__(self,inter_channel = None,**kwargs):
        super(multiplication2, self).__init__(**kwargs)
        self.inter_channel = inter_channel
    def build(self,input_shape=None):
        self.k = self.add_weight(name='k',shape=(1,),initializer='zeros',dtype='float32',trainable=True)
    def get_config(self):
        base_config = super(multiplication2, self).get_config()
        config = {'inter_channel':self.inter_channel}
        return dict(list(base_config.items()) + list(config.items()))  
    def call(self,inputs):
        g,x,rate = inputs[0],inputs[1],inputs[2]
        scaled_value = multiply([x, rate])
        att_x =  self.k * scaled_value
        att_x = add([att_x,x])
        my_concat = Lambda(lambda x: K.concatenate([x[0], x[1]], axis=3))
        concate = my_concat([att_x, g])
        return concate 
    def compute_output_shape(self,input_shape):
        ll = list(input_shape)[1]
        return (None,ll[1],ll[1],ll[3]*2)
    def get_custom_objects():
        return {'multiplication2': multiplication2}

def attention_up_and_concatenate2(inputs):
    g, x = inputs[0],inputs[1]
    inter_channel = g.get_shape().as_list()[3]
    g = Conv2DTranspose(inter_channel//2, (3,3), strides=[2, 2],padding='same')(g)
    g = Conv2D(inter_channel//2, [1, 1], strides=[1, 1], data_format='channels_last')(g)
    theta_x = Conv2D(inter_channel//4, [1, 1], strides=[1, 1], data_format='channels_last')(x)
    phi_g = Conv2D(inter_channel//4, [1, 1], strides=[1, 1], data_format='channels_last')(g)
    f = Activation('relu')(add([theta_x, phi_g]))
    psi_f = Conv2D(1, [1, 1], strides=[1, 1], data_format='channels_last')(f)
    rate = Activation('sigmoid')(psi_f)
    concate =  multiplication2()([g,x,rate])
    return concate


for sample_size in range(30,110,10):
    for round_num in range(1,11):
        
        name = "model_fine_tuning_"
        name += 'No_NAIP_'
        name += str(sample_size)+"_"
        name += "samples_r"+str(round_num)+"_"
        
        print(name)
        root_path = './training_results/'+str(sample_size)+'/'
        
        if os.path.exists(root_path+name+".h5"):
            print("exists")
            continue;

        loaded_model = load_model('../June21/model/model_augv_attention2.h5', 
                                     custom_objects={'multiplication': multiplication,'multiplication2': multiplication2, 
                                                     'dice_coef_loss':dice_coef_loss, 'dice_coef':dice_coef,})

        # remove the last 2 layer using pop() function
        loaded_model.layers.pop()
        loaded_model.layers.pop()

        for (index, layer) in enumerate(loaded_model.layers):
            if (index < 4):
                print("index ",index)
                layer.trainable = True
            else:
                layer.trainable = False

        # Create new model from the model using the input and output of the last layer (after poping last 2 layers)
        model_without_last = Model(loaded_model.input,  loaded_model.layers[-1].output)

        # See model structure
        #model_without_last.summary()
        # Number of output masks (1 in case you predict only one type of objects)
        OUTPUT_MASK_CHANNELS = 1

        # 1 dimensional convolution and generate probabilities from Sigmoid function
        conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1), name='conv2d_last')(model_without_last.output)
        new_out = Activation('sigmoid', name='activation_last')(conv_final)

        # Created new model with the newly added last two layers 
        transfered_model = Model(inputs=model_without_last.input, outputs=new_out)

        # New model structure
        # transfered_model.summary()



        # The dataset has 9 channels:
        # 0. Curvature
        # 1. Slope
        # 2. Openness
        # 3. DEM
        # 4. TPI 21
        # 5. Reflectance (LiDAR intensity)
        # 6. Geomorphon
        # 7. TPI 9
        # 8. TPI 3

        data_path = './samples/'+str(sample_size)+'/'+str(round_num)+'/'
        # read in training and validation data
        X_train_new = np.load(data_path+'train_data.npy')
        print(X_train_new.shape)
        Y_train = np.load(data_path+'train_label.npy')
        print(Y_train.shape)
        X_Validation_new = np.load(data_path+'vali_data.npy')
        print(X_Validation_new.shape)
        Y_Validation = np.load(data_path+'vali_label.npy')
        print(Y_Validation.shape)

        # The 300 training + 300 validation samples files
        # data_path = './samples/'
        # # read in training and validation data
        # X_train = np.load(data_path+'train_data.npy')
        # Y_train = np.load(data_path+'train_label.npy')
        # X_Validation = np.load(data_path+'vali_data.npy')
        # Y_Validation = np.load(data_path+'vali_label.npy')

        patch_size = 224
        IMG_WIDTH = patch_size
        IMG_HEIGHT = patch_size
        # Number of feature channels 
        INPUT_CHANNELS = 8
        # Number of output masks (1 in case you predict only one type of objects)
        OUTPUT_MASK_CHANNELS = 1
        maxepoch = 50
        # hyperparameters
        # learning_rate = 0.0000359
        # learning_rate = 0.0001
        learning_rate = 0.001
        patience = 10
        aug = 'v'
        transfered_model.compile(optimizer=Adam(lr=learning_rate),loss = dice_coef_loss, metrics=[dice_coef,'accuracy'])
        callbacks = [
                ReduceLROnPlateau(monitor='val_loss', factor=0.7, patience=patience, min_lr=1e-9, verbose=1, mode='min'),
                EarlyStopping(monitor='val_loss', patience=patience+10, verbose=0),
                ModelCheckpoint('first_pass_model'+aug+'_attention2.h5', monitor='val_loss', save_best_only=True, verbose=0),
            ]

        fine_tuned_model_P1_history = transfered_model.fit(X_train_new, Y_train, validation_data=(X_Validation_new,Y_Validation), batch_size=2, epochs=maxepoch, callbacks=callbacks)


        for (index, layer) in enumerate(transfered_model.layers):
            layer.trainable = True


        patch_size = 224
        IMG_WIDTH = patch_size
        IMG_HEIGHT = patch_size
        # Number of feature channels 
        INPUT_CHANNELS = 8
        # Number of output masks (1 in case you predict only one type of objects)
        OUTPUT_MASK_CHANNELS = 1
        maxepoch = 50
        # hyperparameters
        # 100 times smaller learning rate
        learning_rate = 0.0000359
        patience = 10
        aug = 'v'
        transfered_model.compile(optimizer=Adam(lr=learning_rate),loss = dice_coef_loss,metrics=[dice_coef,'accuracy'])
        callbacks = [
                ReduceLROnPlateau(monitor='val_loss', factor=0.7, patience=patience, min_lr=1e-9, verbose=1, mode='min'),
                EarlyStopping(monitor='val_loss', patience=patience+10, verbose=0),
                ModelCheckpoint('second_pass_model'+aug+'_attention2.h5', monitor='val_loss', save_best_only=True, verbose=0),
            ]

        fine_tuned_model_P2_history = transfered_model.fit(X_train_new, Y_train, validation_data=(X_Validation_new,Y_Validation), batch_size=1, epochs=maxepoch, callbacks=callbacks)


        import pickle
        # save the trained model
        model_yaml = transfered_model.to_yaml()
        with open(root_path+name+".yaml", "w") as yaml_file:
            yaml_file.write(model_yaml)
        # save the weights
        transfered_model.save(root_path+name+".h5")
        # save the intermdediate rescults and training statistics
        with open(root_path+name+".pickle", 'wb') as file_pi:
            pickle.dump(fine_tuned_model_P2_history.history, file_pi, protocol=2)

        from IPython.display import Audio
        sound_file = '../../wink.mp3'

        Audio(sound_file, autoplay=True)
# Out:
# Using TensorFlow backend.
# 2.1.0
# model_fine_tuning_No_NAIP_30_samples_r1_
# exists
# model_fine_tuning_No_NAIP_30_samples_r2_
# exists
# model_fine_tuning_No_NAIP_30_samples_r3_
# exists
# model_fine_tuning_No_NAIP_30_samples_r4_
# exists
# model_fine_tuning_No_NAIP_30_samples_r5_
# exists
# model_fine_tuning_No_NAIP_30_samples_r6_
# exists
# model_fine_tuning_No_NAIP_30_samples_r7_
# exists
# model_fine_tuning_No_NAIP_30_samples_r8_
# exists
# model_fine_tuning_No_NAIP_30_samples_r9_
# exists
# model_fine_tuning_No_NAIP_30_samples_r10_
# exists
# model_fine_tuning_No_NAIP_40_samples_r1_
# exists
# model_fine_tuning_No_NAIP_40_samples_r2_
# exists
# model_fine_tuning_No_NAIP_40_samples_r3_
# exists
# model_fine_tuning_No_NAIP_40_samples_r4_
# exists
# model_fine_tuning_No_NAIP_40_samples_r5_
# exists
# model_fine_tuning_No_NAIP_40_samples_r6_
# exists
# model_fine_tuning_No_NAIP_40_samples_r7_
# exists
# model_fine_tuning_No_NAIP_40_samples_r8_
# exists
# model_fine_tuning_No_NAIP_40_samples_r9_
# index  0
# index  1
# index  2
# index  3
# (32, 224, 224, 8)
# (32, 224, 224, 1)
# (8, 224, 224, 8)
# (8, 224, 224, 1)
# Train on 32 samples, validate on 8 samples
# Epoch 1/50
# 32/32 [==============================] - 9s 276ms/step - loss: -0.0730 - dice_coef: 0.0730 - accuracy: 0.0570 - val_loss: -0.0377 - val_dice_coef: 0.0377 - val_accuracy: 0.0188
# Epoch 2/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.0816 - dice_coef: 0.0816 - accuracy: 0.0546 - val_loss: -0.0406 - val_dice_coef: 0.0406 - val_accuracy: 0.0219
# Epoch 3/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.0931 - dice_coef: 0.0931 - accuracy: 0.0682 - val_loss: -0.0435 - val_dice_coef: 0.0435 - val_accuracy: 0.2435
# Epoch 4/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.0990 - dice_coef: 0.0990 - accuracy: 0.2513 - val_loss: -0.0446 - val_dice_coef: 0.0446 - val_accuracy: 0.4699
# Epoch 5/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1092 - dice_coef: 0.1092 - accuracy: 0.3003 - val_loss: -0.0475 - val_dice_coef: 0.0475 - val_accuracy: 0.8075
# Epoch 6/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1148 - dice_coef: 0.1148 - accuracy: 0.4842 - val_loss: -0.0536 - val_dice_coef: 0.0536 - val_accuracy: 0.8562
# Epoch 7/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1230 - dice_coef: 0.1230 - accuracy: 0.5282 - val_loss: -0.0637 - val_dice_coef: 0.0637 - val_accuracy: 0.7060
# Epoch 8/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1390 - dice_coef: 0.1390 - accuracy: 0.6242 - val_loss: -0.0628 - val_dice_coef: 0.0628 - val_accuracy: 0.4872
# Epoch 9/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1575 - dice_coef: 0.1575 - accuracy: 0.6893 - val_loss: -0.0698 - val_dice_coef: 0.0698 - val_accuracy: 0.9073
# Epoch 10/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1860 - dice_coef: 0.1860 - accuracy: 0.9542 - val_loss: -0.0827 - val_dice_coef: 0.0827 - val_accuracy: 0.9668
# Epoch 11/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.2175 - dice_coef: 0.2175 - accuracy: 0.9613 - val_loss: -0.1126 - val_dice_coef: 0.1126 - val_accuracy: 0.9674
# Epoch 12/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.2606 - dice_coef: 0.2606 - accuracy: 0.9597 - val_loss: -0.1230 - val_dice_coef: 0.1230 - val_accuracy: 0.9740
# Epoch 13/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.2857 - dice_coef: 0.2857 - accuracy: 0.9580 - val_loss: -0.1474 - val_dice_coef: 0.1474 - val_accuracy: 0.9697
# Epoch 14/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.3302 - dice_coef: 0.3302 - accuracy: 0.9593 - val_loss: -0.1899 - val_dice_coef: 0.1899 - val_accuracy: 0.9542
# Epoch 15/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.3738 - dice_coef: 0.3738 - accuracy: 0.9643 - val_loss: -0.1277 - val_dice_coef: 0.1277 - val_accuracy: 0.8577
# Epoch 16/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.4227 - dice_coef: 0.4227 - accuracy: 0.9670 - val_loss: -0.2281 - val_dice_coef: 0.2281 - val_accuracy: 0.9567
# Epoch 17/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.4223 - dice_coef: 0.4223 - accuracy: 0.9645 - val_loss: -0.2800 - val_dice_coef: 0.2800 - val_accuracy: 0.9381
# Epoch 18/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.4718 - dice_coef: 0.4718 - accuracy: 0.9668 - val_loss: -0.2695 - val_dice_coef: 0.2695 - val_accuracy: 0.9234
# Epoch 19/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.4893 - dice_coef: 0.4893 - accuracy: 0.9673 - val_loss: -0.1016 - val_dice_coef: 0.1016 - val_accuracy: 0.7174
# Epoch 20/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.5747 - dice_coef: 0.5747 - accuracy: 0.9715 - val_loss: -0.1875 - val_dice_coef: 0.1875 - val_accuracy: 0.8930
# Epoch 21/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.5688 - dice_coef: 0.5688 - accuracy: 0.9716 - val_loss: -0.2053 - val_dice_coef: 0.2053 - val_accuracy: 0.9699
# Epoch 22/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.5329 - dice_coef: 0.5329 - accuracy: 0.9681 - val_loss: -0.2975 - val_dice_coef: 0.2975 - val_accuracy: 0.9749
# Epoch 23/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.5825 - dice_coef: 0.5825 - accuracy: 0.9718 - val_loss: -0.2587 - val_dice_coef: 0.2587 - val_accuracy: 0.9743
# Epoch 24/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.5791 - dice_coef: 0.5791 - accuracy: 0.9717 - val_loss: -0.2204 - val_dice_coef: 0.2204 - val_accuracy: 0.9783
# Epoch 25/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.5704 - dice_coef: 0.5704 - accuracy: 0.9706 - val_loss: -0.2668 - val_dice_coef: 0.2668 - val_accuracy: 0.9772
# Epoch 26/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.6188 - dice_coef: 0.6188 - accuracy: 0.9737 - val_loss: -0.3416 - val_dice_coef: 0.3416 - val_accuracy: 0.9716
# Epoch 27/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.5686 - dice_coef: 0.5686 - accuracy: 0.9682 - val_loss: -0.2843 - val_dice_coef: 0.2843 - val_accuracy: 0.9757
# Epoch 28/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.6037 - dice_coef: 0.6037 - accuracy: 0.9724 - val_loss: -0.2810 - val_dice_coef: 0.2810 - val_accuracy: 0.9776
# Epoch 29/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.6093 - dice_coef: 0.6093 - accuracy: 0.9720 - val_loss: -0.3223 - val_dice_coef: 0.3223 - val_accuracy: 0.9748
# Epoch 30/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.5792 - dice_coef: 0.5792 - accuracy: 0.9691 - val_loss: -0.2713 - val_dice_coef: 0.2713 - val_accuracy: 0.9613
# Epoch 31/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.6689 - dice_coef: 0.6689 - accuracy: 0.9752 - val_loss: -0.2667 - val_dice_coef: 0.2667 - val_accuracy: 0.9648
# Epoch 32/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.5807 - dice_coef: 0.5807 - accuracy: 0.9712 - val_loss: -0.3092 - val_dice_coef: 0.3092 - val_accuracy: 0.9630
# Epoch 33/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.6153 - dice_coef: 0.6153 - accuracy: 0.9733 - val_loss: -0.3054 - val_dice_coef: 0.3054 - val_accuracy: 0.9640
# Epoch 34/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.5887 - dice_coef: 0.5887 - accuracy: 0.9710 - val_loss: -0.2598 - val_dice_coef: 0.2598 - val_accuracy: 0.9446
# Epoch 35/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.5706 - dice_coef: 0.5706 - accuracy: 0.9718 - val_loss: -0.2776 - val_dice_coef: 0.2776 - val_accuracy: 0.9584
# Epoch 36/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.5480 - dice_coef: 0.5480 - accuracy: 0.9690 - val_loss: -0.3478 - val_dice_coef: 0.3478 - val_accuracy: 0.9746
# Epoch 37/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.5797 - dice_coef: 0.5797 - accuracy: 0.9710 - val_loss: -0.2294 - val_dice_coef: 0.2294 - val_accuracy: 0.9753
# Epoch 38/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.6250 - dice_coef: 0.6250 - accuracy: 0.9732 - val_loss: -0.2368 - val_dice_coef: 0.2368 - val_accuracy: 0.9778
# Epoch 39/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.6092 - dice_coef: 0.6092 - accuracy: 0.9715 - val_loss: -0.2646 - val_dice_coef: 0.2646 - val_accuracy: 0.9769
# Epoch 40/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.5893 - dice_coef: 0.5893 - accuracy: 0.9711 - val_loss: -0.2261 - val_dice_coef: 0.2261 - val_accuracy: 0.9770
# Epoch 41/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.6780 - dice_coef: 0.6780 - accuracy: 0.9759 - val_loss: -0.2240 - val_dice_coef: 0.2240 - val_accuracy: 0.9765
# Epoch 42/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.6426 - dice_coef: 0.6426 - accuracy: 0.9753 - val_loss: -0.2229 - val_dice_coef: 0.2229 - val_accuracy: 0.9780
# Epoch 43/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.6126 - dice_coef: 0.6126 - accuracy: 0.9712 - val_loss: -0.2267 - val_dice_coef: 0.2267 - val_accuracy: 0.9767
# Epoch 44/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.6297 - dice_coef: 0.6297 - accuracy: 0.9736 - val_loss: -0.2873 - val_dice_coef: 0.2873 - val_accuracy: 0.9767
# Epoch 45/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.6565 - dice_coef: 0.6565 - accuracy: 0.9742 - val_loss: -0.3401 - val_dice_coef: 0.3401 - val_accuracy: 0.9771
# Epoch 46/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.6655 - dice_coef: 0.6655 - accuracy: 0.9760 - val_loss: -0.2647 - val_dice_coef: 0.2647 - val_accuracy: 0.9793
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# Epoch 47/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.5734 - dice_coef: 0.5734 - accuracy: 0.9724 - val_loss: -0.2636 - val_dice_coef: 0.2636 - val_accuracy: 0.9794
# Epoch 48/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.7333 - dice_coef: 0.7333 - accuracy: 0.9791 - val_loss: -0.2696 - val_dice_coef: 0.2696 - val_accuracy: 0.9801
# Epoch 49/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.6552 - dice_coef: 0.6552 - accuracy: 0.9761 - val_loss: -0.3707 - val_dice_coef: 0.3707 - val_accuracy: 0.9806
# Epoch 50/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.5725 - dice_coef: 0.5725 - accuracy: 0.9715 - val_loss: -0.4102 - val_dice_coef: 0.4102 - val_accuracy: 0.9795
# Train on 32 samples, validate on 8 samples
# Epoch 1/50
# 32/32 [==============================] - 15s 474ms/step - loss: -0.4754 - dice_coef: 0.4754 - accuracy: 0.9592 - val_loss: -0.3070 - val_dice_coef: 0.3070 - val_accuracy: 0.9794
# Epoch 2/50
# 32/32 [==============================] - 4s 123ms/step - loss: -0.5383 - dice_coef: 0.5383 - accuracy: 0.9731 - val_loss: -0.2739 - val_dice_coef: 0.2739 - val_accuracy: 0.9840
# Epoch 3/50
# 32/32 [==============================] - 4s 123ms/step - loss: -0.5762 - dice_coef: 0.5762 - accuracy: 0.9809 - val_loss: -0.2187 - val_dice_coef: 0.2187 - val_accuracy: 0.9805
# Epoch 4/50
# 32/32 [==============================] - 4s 123ms/step - loss: -0.6042 - dice_coef: 0.6042 - accuracy: 0.9838 - val_loss: -0.2214 - val_dice_coef: 0.2214 - val_accuracy: 0.9786
# Epoch 5/50
# 32/32 [==============================] - 4s 125ms/step - loss: -0.6189 - dice_coef: 0.6189 - accuracy: 0.9853 - val_loss: -0.2112 - val_dice_coef: 0.2112 - val_accuracy: 0.9814
# Epoch 6/50
# 32/32 [==============================] - 4s 126ms/step - loss: -0.6241 - dice_coef: 0.6241 - accuracy: 0.9855 - val_loss: -0.2321 - val_dice_coef: 0.2321 - val_accuracy: 0.9751
# Epoch 7/50
# 32/32 [==============================] - 4s 127ms/step - loss: -0.6350 - dice_coef: 0.6350 - accuracy: 0.9866 - val_loss: -0.2633 - val_dice_coef: 0.2633 - val_accuracy: 0.9721
# Epoch 8/50
# 32/32 [==============================] - 4s 124ms/step - loss: -0.6432 - dice_coef: 0.6432 - accuracy: 0.9874 - val_loss: -0.2471 - val_dice_coef: 0.2471 - val_accuracy: 0.9750
# Epoch 9/50
# 32/32 [==============================] - 4s 123ms/step - loss: -0.6486 - dice_coef: 0.6486 - accuracy: 0.9883 - val_loss: -0.2570 - val_dice_coef: 0.2570 - val_accuracy: 0.9756
# Epoch 10/50
# 32/32 [==============================] - 4s 123ms/step - loss: -0.6499 - dice_coef: 0.6499 - accuracy: 0.9886 - val_loss: -0.2145 - val_dice_coef: 0.2145 - val_accuracy: 0.9712
# Epoch 11/50
# 32/32 [==============================] - 4s 123ms/step - loss: -0.6590 - dice_coef: 0.6590 - accuracy: 0.9890 - val_loss: -0.2094 - val_dice_coef: 0.2094 - val_accuracy: 0.9726
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 2.5130000358331015e-05.
# Epoch 12/50
# 32/32 [==============================] - 4s 123ms/step - loss: -0.6674 - dice_coef: 0.6674 - accuracy: 0.9901 - val_loss: -0.2258 - val_dice_coef: 0.2258 - val_accuracy: 0.9741
# Epoch 13/50
# 32/32 [==============================] - 4s 122ms/step - loss: -0.6763 - dice_coef: 0.6763 - accuracy: 0.9906 - val_loss: -0.2422 - val_dice_coef: 0.2422 - val_accuracy: 0.9731
# Epoch 14/50
# 32/32 [==============================] - 4s 124ms/step - loss: -0.6821 - dice_coef: 0.6821 - accuracy: 0.9912 - val_loss: -0.2439 - val_dice_coef: 0.2439 - val_accuracy: 0.9724
# Epoch 15/50
# 32/32 [==============================] - 4s 125ms/step - loss: -0.6859 - dice_coef: 0.6859 - accuracy: 0.9915 - val_loss: -0.2352 - val_dice_coef: 0.2352 - val_accuracy: 0.9739
# Epoch 16/50
# 32/32 [==============================] - 4s 123ms/step - loss: -0.6845 - dice_coef: 0.6845 - accuracy: 0.9918 - val_loss: -0.2408 - val_dice_coef: 0.2408 - val_accuracy: 0.9734
# Epoch 17/50
# 32/32 [==============================] - 4s 123ms/step - loss: -0.6887 - dice_coef: 0.6887 - accuracy: 0.9921 - val_loss: -0.2551 - val_dice_coef: 0.2551 - val_accuracy: 0.9717
# Epoch 18/50
# 32/32 [==============================] - 4s 128ms/step - loss: -0.6892 - dice_coef: 0.6892 - accuracy: 0.9921 - val_loss: -0.2444 - val_dice_coef: 0.2444 - val_accuracy: 0.9728
# Epoch 19/50
# 32/32 [==============================] - 4s 122ms/step - loss: -0.6909 - dice_coef: 0.6909 - accuracy: 0.9926 - val_loss: -0.2372 - val_dice_coef: 0.2372 - val_accuracy: 0.9714
# Epoch 20/50
# 32/32 [==============================] - 4s 121ms/step - loss: -0.6960 - dice_coef: 0.6960 - accuracy: 0.9933 - val_loss: -0.2271 - val_dice_coef: 0.2271 - val_accuracy: 0.9743
# Epoch 21/50
# 32/32 [==============================] - 4s 121ms/step - loss: -0.6956 - dice_coef: 0.6956 - accuracy: 0.9935 - val_loss: -0.2305 - val_dice_coef: 0.2305 - val_accuracy: 0.9752
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.7591000505490227e-05.
# model_fine_tuning_No_NAIP_40_samples_r10_
# index  0
# index  1
# index  2
# index  3
# (32, 224, 224, 8)
# (32, 224, 224, 1)
# (8, 224, 224, 8)
# (8, 224, 224, 1)
# Train on 32 samples, validate on 8 samples
# Epoch 1/50
# 32/32 [==============================] - 6s 180ms/step - loss: -0.0388 - dice_coef: 0.0388 - accuracy: 0.5320 - val_loss: -0.0538 - val_dice_coef: 0.0538 - val_accuracy: 0.9613
# Epoch 2/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.0645 - dice_coef: 0.0645 - accuracy: 0.5495 - val_loss: -0.0583 - val_dice_coef: 0.0583 - val_accuracy: 0.9592
# Epoch 3/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.0803 - dice_coef: 0.0803 - accuracy: 0.5474 - val_loss: -0.0547 - val_dice_coef: 0.0547 - val_accuracy: 0.8608
# Epoch 4/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.0848 - dice_coef: 0.0848 - accuracy: 0.5502 - val_loss: -0.0494 - val_dice_coef: 0.0494 - val_accuracy: 0.9203
# Epoch 5/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.0893 - dice_coef: 0.0893 - accuracy: 0.5663 - val_loss: -0.0450 - val_dice_coef: 0.0450 - val_accuracy: 0.9560
# Epoch 6/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.0932 - dice_coef: 0.0932 - accuracy: 0.5642 - val_loss: -0.0451 - val_dice_coef: 0.0451 - val_accuracy: 0.9645
# Epoch 7/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.0969 - dice_coef: 0.0969 - accuracy: 0.5673 - val_loss: -0.0435 - val_dice_coef: 0.0435 - val_accuracy: 0.9661
# Epoch 8/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1060 - dice_coef: 0.1060 - accuracy: 0.5711 - val_loss: -0.0426 - val_dice_coef: 0.0426 - val_accuracy: 0.9708
# Epoch 9/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1071 - dice_coef: 0.1071 - accuracy: 0.5750 - val_loss: -0.0814 - val_dice_coef: 0.0814 - val_accuracy: 0.9771
# Epoch 10/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1124 - dice_coef: 0.1124 - accuracy: 0.5824 - val_loss: -0.0806 - val_dice_coef: 0.0806 - val_accuracy: 0.7646
# Epoch 11/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1160 - dice_coef: 0.1160 - accuracy: 0.5845 - val_loss: -0.0955 - val_dice_coef: 0.0955 - val_accuracy: 0.8180
# Epoch 12/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1150 - dice_coef: 0.1150 - accuracy: 0.5833 - val_loss: -0.0686 - val_dice_coef: 0.0686 - val_accuracy: 0.3898
# Epoch 13/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1214 - dice_coef: 0.1214 - accuracy: 0.5889 - val_loss: -0.0656 - val_dice_coef: 0.0656 - val_accuracy: 0.2996
# Epoch 14/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1216 - dice_coef: 0.1216 - accuracy: 0.5918 - val_loss: -0.0680 - val_dice_coef: 0.0680 - val_accuracy: 0.5798
# Epoch 15/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1209 - dice_coef: 0.1209 - accuracy: 0.5904 - val_loss: -0.1182 - val_dice_coef: 0.1182 - val_accuracy: 0.9223
# Epoch 16/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1224 - dice_coef: 0.1224 - accuracy: 0.5896 - val_loss: -0.1194 - val_dice_coef: 0.1194 - val_accuracy: 0.9612
# Epoch 17/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1283 - dice_coef: 0.1283 - accuracy: 0.5933 - val_loss: -0.0912 - val_dice_coef: 0.0912 - val_accuracy: 0.7032
# Epoch 18/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1328 - dice_coef: 0.1328 - accuracy: 0.6022 - val_loss: -0.1947 - val_dice_coef: 0.1947 - val_accuracy: 0.9380
# Epoch 19/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1326 - dice_coef: 0.1326 - accuracy: 0.6033 - val_loss: -0.1865 - val_dice_coef: 0.1865 - val_accuracy: 0.9731
# Epoch 20/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1332 - dice_coef: 0.1332 - accuracy: 0.6003 - val_loss: -0.1632 - val_dice_coef: 0.1632 - val_accuracy: 0.9750
# Epoch 21/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1297 - dice_coef: 0.1297 - accuracy: 0.5990 - val_loss: -0.2122 - val_dice_coef: 0.2122 - val_accuracy: 0.9155
# Epoch 22/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1344 - dice_coef: 0.1344 - accuracy: 0.6045 - val_loss: -0.1508 - val_dice_coef: 0.1508 - val_accuracy: 0.8554
# Epoch 23/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1300 - dice_coef: 0.1300 - accuracy: 0.5945 - val_loss: -0.1449 - val_dice_coef: 0.1449 - val_accuracy: 0.7987
# Epoch 24/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1280 - dice_coef: 0.1280 - accuracy: 0.5925 - val_loss: -0.1478 - val_dice_coef: 0.1478 - val_accuracy: 0.7449
# Epoch 25/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1354 - dice_coef: 0.1354 - accuracy: 0.6062 - val_loss: -0.1904 - val_dice_coef: 0.1904 - val_accuracy: 0.7850
# Epoch 26/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1200 - dice_coef: 0.1200 - accuracy: 0.5886 - val_loss: -0.1879 - val_dice_coef: 0.1879 - val_accuracy: 0.7829
# Epoch 27/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1305 - dice_coef: 0.1305 - accuracy: 0.6000 - val_loss: -0.1583 - val_dice_coef: 0.1583 - val_accuracy: 0.8240
# Epoch 28/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1304 - dice_coef: 0.1304 - accuracy: 0.6044 - val_loss: -0.1456 - val_dice_coef: 0.1456 - val_accuracy: 0.8048
# Epoch 29/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1278 - dice_coef: 0.1278 - accuracy: 0.5950 - val_loss: -0.1830 - val_dice_coef: 0.1830 - val_accuracy: 0.9341
# Epoch 30/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1364 - dice_coef: 0.1364 - accuracy: 0.6035 - val_loss: -0.0941 - val_dice_coef: 0.0941 - val_accuracy: 0.5109
# Epoch 31/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1343 - dice_coef: 0.1343 - accuracy: 0.6083 - val_loss: -0.0707 - val_dice_coef: 0.0707 - val_accuracy: 0.3072
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# Epoch 32/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1320 - dice_coef: 0.1320 - accuracy: 0.6032 - val_loss: -0.0719 - val_dice_coef: 0.0719 - val_accuracy: 0.3251
# Epoch 33/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1399 - dice_coef: 0.1399 - accuracy: 0.6094 - val_loss: -0.0672 - val_dice_coef: 0.0672 - val_accuracy: 0.2874
# Epoch 34/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1332 - dice_coef: 0.1332 - accuracy: 0.6062 - val_loss: -0.1387 - val_dice_coef: 0.1387 - val_accuracy: 0.7363
# Epoch 35/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1414 - dice_coef: 0.1414 - accuracy: 0.6096 - val_loss: -0.1559 - val_dice_coef: 0.1559 - val_accuracy: 0.7640
# Epoch 36/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1373 - dice_coef: 0.1373 - accuracy: 0.6017 - val_loss: -0.1801 - val_dice_coef: 0.1801 - val_accuracy: 0.8880
# Epoch 37/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1349 - dice_coef: 0.1349 - accuracy: 0.6048 - val_loss: -0.1916 - val_dice_coef: 0.1916 - val_accuracy: 0.9373
# Epoch 38/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1388 - dice_coef: 0.1388 - accuracy: 0.6070 - val_loss: -0.1825 - val_dice_coef: 0.1825 - val_accuracy: 0.9011
# Epoch 39/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1396 - dice_coef: 0.1396 - accuracy: 0.6080 - val_loss: -0.1720 - val_dice_coef: 0.1720 - val_accuracy: 0.9505
# Epoch 40/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1361 - dice_coef: 0.1361 - accuracy: 0.6057 - val_loss: -0.1732 - val_dice_coef: 0.1732 - val_accuracy: 0.9524
# Epoch 41/50
# 32/32 [==============================] - 1s 39ms/step - loss: -0.1398 - dice_coef: 0.1398 - accuracy: 0.6128 - val_loss: -0.1776 - val_dice_coef: 0.1776 - val_accuracy: 0.9293
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0004900000232737511.
# Train on 32 samples, validate on 8 samples
# Epoch 1/50
# 32/32 [==============================] - 13s 408ms/step - loss: -0.1372 - dice_coef: 0.1372 - accuracy: 0.6618 - val_loss: -0.1765 - val_dice_coef: 0.1765 - val_accuracy: 0.8161
# Epoch 2/50
# 32/32 [==============================] - 4s 124ms/step - loss: -0.2027 - dice_coef: 0.2027 - accuracy: 0.7967 - val_loss: -0.1996 - val_dice_coef: 0.1996 - val_accuracy: 0.9463
# Epoch 3/50
# 32/32 [==============================] - 4s 123ms/step - loss: -0.2556 - dice_coef: 0.2556 - accuracy: 0.8852 - val_loss: -0.1968 - val_dice_coef: 0.1968 - val_accuracy: 0.9309
# Epoch 4/50
# 32/32 [==============================] - 4s 124ms/step - loss: -0.2896 - dice_coef: 0.2896 - accuracy: 0.9144 - val_loss: -0.2241 - val_dice_coef: 0.2241 - val_accuracy: 0.9451
# Epoch 5/50
# 32/32 [==============================] - 4s 128ms/step - loss: -0.3354 - dice_coef: 0.3354 - accuracy: 0.9417 - val_loss: -0.2197 - val_dice_coef: 0.2197 - val_accuracy: 0.9624
# Epoch 6/50
# 32/32 [==============================] - 4s 124ms/step - loss: -0.3706 - dice_coef: 0.3706 - accuracy: 0.9527 - val_loss: -0.2141 - val_dice_coef: 0.2141 - val_accuracy: 0.9727
# Epoch 7/50
# 32/32 [==============================] - 4s 124ms/step - loss: -0.3969 - dice_coef: 0.3969 - accuracy: 0.9620 - val_loss: -0.1486 - val_dice_coef: 0.1486 - val_accuracy: 0.9722
# Epoch 8/50
# 32/32 [==============================] - 4s 123ms/step - loss: -0.4184 - dice_coef: 0.4184 - accuracy: 0.9671 - val_loss: -0.1544 - val_dice_coef: 0.1544 - val_accuracy: 0.9689
# Epoch 9/50
# 32/32 [==============================] - 4s 126ms/step - loss: -0.4363 - dice_coef: 0.4363 - accuracy: 0.9710 - val_loss: -0.1583 - val_dice_coef: 0.1583 - val_accuracy: 0.9706
# Epoch 10/50
# 32/32 [==============================] - 4s 125ms/step - loss: -0.4555 - dice_coef: 0.4555 - accuracy: 0.9743 - val_loss: -0.1552 - val_dice_coef: 0.1552 - val_accuracy: 0.9690
# Epoch 11/50
# 32/32 [==============================] - 4s 122ms/step - loss: -0.4561 - dice_coef: 0.4561 - accuracy: 0.9745 - val_loss: -0.1436 - val_dice_coef: 0.1436 - val_accuracy: 0.9672
# Epoch 12/50
# 32/32 [==============================] - 4s 124ms/step - loss: -0.4631 - dice_coef: 0.4631 - accuracy: 0.9760 - val_loss: -0.1725 - val_dice_coef: 0.1725 - val_accuracy: 0.9707
# Epoch 13/50
# 32/32 [==============================] - 4s 122ms/step - loss: -0.4739 - dice_coef: 0.4739 - accuracy: 0.9775 - val_loss: -0.1437 - val_dice_coef: 0.1437 - val_accuracy: 0.9657
# Epoch 14/50
# 32/32 [==============================] - 4s 123ms/step - loss: -0.4912 - dice_coef: 0.4912 - accuracy: 0.9810 - val_loss: -0.1686 - val_dice_coef: 0.1686 - val_accuracy: 0.9648
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 2.5130000358331015e-05.
# Epoch 15/50
# 32/32 [==============================] - 4s 125ms/step - loss: -0.4977 - dice_coef: 0.4977 - accuracy: 0.9822 - val_loss: -0.1713 - val_dice_coef: 0.1713 - val_accuracy: 0.9647
# Epoch 16/50
# 32/32 [==============================] - 4s 124ms/step - loss: -0.5053 - dice_coef: 0.5053 - accuracy: 0.9835 - val_loss: -0.1846 - val_dice_coef: 0.1846 - val_accuracy: 0.9659
# Epoch 17/50
# 32/32 [==============================] - 4s 122ms/step - loss: -0.5113 - dice_coef: 0.5113 - accuracy: 0.9840 - val_loss: -0.1670 - val_dice_coef: 0.1670 - val_accuracy: 0.9685
# Epoch 18/50
# 32/32 [==============================] - 4s 126ms/step - loss: -0.5151 - dice_coef: 0.5151 - accuracy: 0.9847 - val_loss: -0.1796 - val_dice_coef: 0.1796 - val_accuracy: 0.9686
# Epoch 19/50
# 32/32 [==============================] - 4s 125ms/step - loss: -0.5138 - dice_coef: 0.5138 - accuracy: 0.9842 - val_loss: -0.1708 - val_dice_coef: 0.1708 - val_accuracy: 0.9678
# Epoch 20/50
# 32/32 [==============================] - 4s 127ms/step - loss: -0.5155 - dice_coef: 0.5155 - accuracy: 0.9845 - val_loss: -0.1680 - val_dice_coef: 0.1680 - val_accuracy: 0.9684
# Epoch 21/50
# 32/32 [==============================] - 4s 126ms/step - loss: -0.5217 - dice_coef: 0.5217 - accuracy: 0.9851 - val_loss: -0.1743 - val_dice_coef: 0.1743 - val_accuracy: 0.9676
# Epoch 22/50
# 32/32 [==============================] - 4s 124ms/step - loss: -0.5219 - dice_coef: 0.5219 - accuracy: 0.9855 - val_loss: -0.1835 - val_dice_coef: 0.1835 - val_accuracy: 0.9672
# Epoch 23/50
# 32/32 [==============================] - 4s 123ms/step - loss: -0.5268 - dice_coef: 0.5268 - accuracy: 0.9862 - val_loss: -0.1854 - val_dice_coef: 0.1854 - val_accuracy: 0.9674
# Epoch 24/50
# 32/32 [==============================] - 4s 123ms/step - loss: -0.5250 - dice_coef: 0.5250 - accuracy: 0.9855 - val_loss: -0.1925 - val_dice_coef: 0.1925 - val_accuracy: 0.9673
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.7591000505490227e-05.
# model_fine_tuning_No_NAIP_50_samples_r1_
# index  0
# index  1
# index  2
# index  3
# (40, 224, 224, 8)
# (40, 224, 224, 1)
# (10, 224, 224, 8)
# (10, 224, 224, 1)
# Train on 40 samples, validate on 10 samples
# Epoch 1/50
# 40/40 [==============================] - 6s 154ms/step - loss: -0.1141 - dice_coef: 0.1141 - accuracy: 0.7591 - val_loss: -0.1232 - val_dice_coef: 0.1232 - val_accuracy: 0.9702
# Epoch 2/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.1304 - dice_coef: 0.1304 - accuracy: 0.9462 - val_loss: -0.1423 - val_dice_coef: 0.1423 - val_accuracy: 0.9571
# Epoch 3/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.1514 - dice_coef: 0.1514 - accuracy: 0.9561 - val_loss: -0.1082 - val_dice_coef: 0.1082 - val_accuracy: 0.6300
# Epoch 4/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.1770 - dice_coef: 0.1770 - accuracy: 0.9569 - val_loss: -0.1787 - val_dice_coef: 0.1787 - val_accuracy: 0.9472
# Epoch 5/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.2148 - dice_coef: 0.2148 - accuracy: 0.9585 - val_loss: -0.2249 - val_dice_coef: 0.2249 - val_accuracy: 0.9684
# Epoch 6/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.2516 - dice_coef: 0.2516 - accuracy: 0.9572 - val_loss: -0.1892 - val_dice_coef: 0.1892 - val_accuracy: 0.9762
# Epoch 7/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.2842 - dice_coef: 0.2842 - accuracy: 0.9638 - val_loss: -0.2192 - val_dice_coef: 0.2192 - val_accuracy: 0.9727
# Epoch 8/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.3282 - dice_coef: 0.3282 - accuracy: 0.9631 - val_loss: -0.2446 - val_dice_coef: 0.2446 - val_accuracy: 0.9672
# Epoch 9/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.3718 - dice_coef: 0.3718 - accuracy: 0.9644 - val_loss: -0.2500 - val_dice_coef: 0.2500 - val_accuracy: 0.9599
# Epoch 10/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.3997 - dice_coef: 0.3997 - accuracy: 0.9673 - val_loss: -0.2608 - val_dice_coef: 0.2608 - val_accuracy: 0.9541
# Epoch 11/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.4263 - dice_coef: 0.4263 - accuracy: 0.9657 - val_loss: -0.3046 - val_dice_coef: 0.3046 - val_accuracy: 0.9701
# Epoch 12/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.4487 - dice_coef: 0.4487 - accuracy: 0.9667 - val_loss: -0.3329 - val_dice_coef: 0.3329 - val_accuracy: 0.9623
# Epoch 13/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.4532 - dice_coef: 0.4532 - accuracy: 0.9686 - val_loss: -0.2951 - val_dice_coef: 0.2951 - val_accuracy: 0.9730
# Epoch 14/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.5027 - dice_coef: 0.5027 - accuracy: 0.9726 - val_loss: -0.3192 - val_dice_coef: 0.3192 - val_accuracy: 0.9636
# Epoch 15/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.4864 - dice_coef: 0.4864 - accuracy: 0.9685 - val_loss: -0.2690 - val_dice_coef: 0.2690 - val_accuracy: 0.9769
# Epoch 16/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.5157 - dice_coef: 0.5157 - accuracy: 0.9709 - val_loss: -0.3301 - val_dice_coef: 0.3301 - val_accuracy: 0.9736
# Epoch 17/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.5091 - dice_coef: 0.5091 - accuracy: 0.9713 - val_loss: -0.3340 - val_dice_coef: 0.3340 - val_accuracy: 0.9765
# Epoch 18/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.5632 - dice_coef: 0.5632 - accuracy: 0.9735 - val_loss: -0.3353 - val_dice_coef: 0.3353 - val_accuracy: 0.9744
# Epoch 19/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.5480 - dice_coef: 0.5480 - accuracy: 0.9729 - val_loss: -0.3485 - val_dice_coef: 0.3485 - val_accuracy: 0.9765
# Epoch 20/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.5927 - dice_coef: 0.5927 - accuracy: 0.9759 - val_loss: -0.3479 - val_dice_coef: 0.3479 - val_accuracy: 0.9787
# Epoch 21/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.5828 - dice_coef: 0.5828 - accuracy: 0.9759 - val_loss: -0.3432 - val_dice_coef: 0.3432 - val_accuracy: 0.9787
# Epoch 22/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.5999 - dice_coef: 0.5999 - accuracy: 0.9766 - val_loss: -0.3583 - val_dice_coef: 0.3583 - val_accuracy: 0.9781
# Epoch 23/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.6097 - dice_coef: 0.6097 - accuracy: 0.9757 - val_loss: -0.3720 - val_dice_coef: 0.3720 - val_accuracy: 0.9757
# Epoch 24/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.5350 - dice_coef: 0.5350 - accuracy: 0.9724 - val_loss: -0.3788 - val_dice_coef: 0.3788 - val_accuracy: 0.9745
# Epoch 25/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.5756 - dice_coef: 0.5756 - accuracy: 0.9751 - val_loss: -0.3726 - val_dice_coef: 0.3726 - val_accuracy: 0.9739
# Epoch 26/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.5608 - dice_coef: 0.5608 - accuracy: 0.9736 - val_loss: -0.3827 - val_dice_coef: 0.3827 - val_accuracy: 0.9773
# Epoch 27/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.6206 - dice_coef: 0.6206 - accuracy: 0.9760 - val_loss: -0.3801 - val_dice_coef: 0.3801 - val_accuracy: 0.9783
# Epoch 28/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.6234 - dice_coef: 0.6234 - accuracy: 0.9780 - val_loss: -0.3839 - val_dice_coef: 0.3839 - val_accuracy: 0.9780
# Epoch 29/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.5943 - dice_coef: 0.5943 - accuracy: 0.9761 - val_loss: -0.3833 - val_dice_coef: 0.3833 - val_accuracy: 0.9759
# Epoch 30/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.5908 - dice_coef: 0.5908 - accuracy: 0.9762 - val_loss: -0.3841 - val_dice_coef: 0.3841 - val_accuracy: 0.9763
# Epoch 31/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.6001 - dice_coef: 0.6001 - accuracy: 0.9759 - val_loss: -0.3948 - val_dice_coef: 0.3948 - val_accuracy: 0.9787
# Epoch 32/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.5629 - dice_coef: 0.5629 - accuracy: 0.9739 - val_loss: -0.4015 - val_dice_coef: 0.4015 - val_accuracy: 0.9804
# Epoch 33/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.6163 - dice_coef: 0.6163 - accuracy: 0.9763 - val_loss: -0.3998 - val_dice_coef: 0.3998 - val_accuracy: 0.9791
# Epoch 34/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.6373 - dice_coef: 0.6373 - accuracy: 0.9780 - val_loss: -0.4099 - val_dice_coef: 0.4099 - val_accuracy: 0.9812
# Epoch 35/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.6468 - dice_coef: 0.6468 - accuracy: 0.9785 - val_loss: -0.4068 - val_dice_coef: 0.4068 - val_accuracy: 0.9811
# Epoch 36/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.6460 - dice_coef: 0.6460 - accuracy: 0.9775 - val_loss: -0.3988 - val_dice_coef: 0.3988 - val_accuracy: 0.9808
# Epoch 37/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.6090 - dice_coef: 0.6090 - accuracy: 0.9782 - val_loss: -0.4055 - val_dice_coef: 0.4055 - val_accuracy: 0.9813
# Epoch 38/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.6970 - dice_coef: 0.6970 - accuracy: 0.9814 - val_loss: -0.4084 - val_dice_coef: 0.4084 - val_accuracy: 0.9813
# Epoch 39/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.6150 - dice_coef: 0.6150 - accuracy: 0.9773 - val_loss: -0.4002 - val_dice_coef: 0.4002 - val_accuracy: 0.9800
# Epoch 40/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.5986 - dice_coef: 0.5986 - accuracy: 0.9767 - val_loss: -0.3986 - val_dice_coef: 0.3986 - val_accuracy: 0.9782
# Epoch 41/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.6339 - dice_coef: 0.6339 - accuracy: 0.9791 - val_loss: -0.3938 - val_dice_coef: 0.3938 - val_accuracy: 0.9795
# Epoch 42/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.6078 - dice_coef: 0.6078 - accuracy: 0.9759 - val_loss: -0.4016 - val_dice_coef: 0.4016 - val_accuracy: 0.9807
# Epoch 43/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.6558 - dice_coef: 0.6558 - accuracy: 0.9785 - val_loss: -0.3958 - val_dice_coef: 0.3958 - val_accuracy: 0.9807
# Epoch 44/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.6120 - dice_coef: 0.6120 - accuracy: 0.9778 - val_loss: -0.3744 - val_dice_coef: 0.3744 - val_accuracy: 0.9795
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# Epoch 45/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.6706 - dice_coef: 0.6706 - accuracy: 0.9818 - val_loss: -0.4079 - val_dice_coef: 0.4079 - val_accuracy: 0.9806
# Epoch 46/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.6580 - dice_coef: 0.6580 - accuracy: 0.9803 - val_loss: -0.4093 - val_dice_coef: 0.4093 - val_accuracy: 0.9801
# Epoch 47/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.6946 - dice_coef: 0.6946 - accuracy: 0.9805 - val_loss: -0.3995 - val_dice_coef: 0.3995 - val_accuracy: 0.9794
# Epoch 48/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.6649 - dice_coef: 0.6649 - accuracy: 0.9803 - val_loss: -0.4057 - val_dice_coef: 0.4057 - val_accuracy: 0.9798
# Epoch 49/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.6309 - dice_coef: 0.6309 - accuracy: 0.9773 - val_loss: -0.4118 - val_dice_coef: 0.4118 - val_accuracy: 0.9805
# Epoch 50/50
# 40/40 [==============================] - 2s 40ms/step - loss: -0.6919 - dice_coef: 0.6919 - accuracy: 0.9810 - val_loss: -0.4048 - val_dice_coef: 0.4048 - val_accuracy: 0.9808
# Train on 40 samples, validate on 10 samples
# Epoch 1/50
# 40/40 [==============================] - 14s 349ms/step - loss: -0.4876 - dice_coef: 0.4876 - accuracy: 0.9701 - val_loss: -0.3113 - val_dice_coef: 0.3113 - val_accuracy: 0.9789
# Epoch 2/50
# 40/40 [==============================] - 5s 125ms/step - loss: -0.5505 - dice_coef: 0.5505 - accuracy: 0.9771 - val_loss: -0.2899 - val_dice_coef: 0.2899 - val_accuracy: 0.9797
# Epoch 3/50
# 40/40 [==============================] - 5s 124ms/step - loss: -0.5844 - dice_coef: 0.5844 - accuracy: 0.9820 - val_loss: -0.2832 - val_dice_coef: 0.2832 - val_accuracy: 0.9788
# Epoch 4/50
# 40/40 [==============================] - 5s 123ms/step - loss: -0.5979 - dice_coef: 0.5979 - accuracy: 0.9830 - val_loss: -0.3419 - val_dice_coef: 0.3419 - val_accuracy: 0.9761
# Epoch 5/50
# 40/40 [==============================] - 5s 126ms/step - loss: -0.6135 - dice_coef: 0.6135 - accuracy: 0.9845 - val_loss: -0.3316 - val_dice_coef: 0.3316 - val_accuracy: 0.9750
# Epoch 6/50
# 40/40 [==============================] - 5s 126ms/step - loss: -0.6185 - dice_coef: 0.6185 - accuracy: 0.9850 - val_loss: -0.3324 - val_dice_coef: 0.3324 - val_accuracy: 0.9795
# Epoch 7/50
# 40/40 [==============================] - 5s 122ms/step - loss: -0.6186 - dice_coef: 0.6186 - accuracy: 0.9852 - val_loss: -0.3321 - val_dice_coef: 0.3321 - val_accuracy: 0.9781
# Epoch 8/50
# 40/40 [==============================] - 5s 123ms/step - loss: -0.6216 - dice_coef: 0.6216 - accuracy: 0.9860 - val_loss: -0.3243 - val_dice_coef: 0.3243 - val_accuracy: 0.9767
# Epoch 9/50
# 40/40 [==============================] - 5s 122ms/step - loss: -0.6250 - dice_coef: 0.6250 - accuracy: 0.9860 - val_loss: -0.3452 - val_dice_coef: 0.3452 - val_accuracy: 0.9756
# Epoch 10/50
# 40/40 [==============================] - 5s 122ms/step - loss: -0.6318 - dice_coef: 0.6318 - accuracy: 0.9881 - val_loss: -0.3431 - val_dice_coef: 0.3431 - val_accuracy: 0.9743
# Epoch 11/50
# 40/40 [==============================] - 5s 125ms/step - loss: -0.6309 - dice_coef: 0.6309 - accuracy: 0.9875 - val_loss: -0.3335 - val_dice_coef: 0.3335 - val_accuracy: 0.9723
# Epoch 12/50
# 40/40 [==============================] - 5s 120ms/step - loss: -0.6347 - dice_coef: 0.6347 - accuracy: 0.9882 - val_loss: -0.3302 - val_dice_coef: 0.3302 - val_accuracy: 0.9768
# Epoch 13/50
# 40/40 [==============================] - 5s 123ms/step - loss: -0.6370 - dice_coef: 0.6370 - accuracy: 0.9886 - val_loss: -0.3379 - val_dice_coef: 0.3379 - val_accuracy: 0.9747
# Epoch 14/50
# 40/40 [==============================] - 5s 122ms/step - loss: -0.6416 - dice_coef: 0.6416 - accuracy: 0.9895 - val_loss: -0.3397 - val_dice_coef: 0.3397 - val_accuracy: 0.9744
# Epoch 15/50
# 40/40 [==============================] - 5s 120ms/step - loss: -0.6428 - dice_coef: 0.6428 - accuracy: 0.9897 - val_loss: -0.3399 - val_dice_coef: 0.3399 - val_accuracy: 0.9732
# Epoch 16/50
# 40/40 [==============================] - 5s 121ms/step - loss: -0.6391 - dice_coef: 0.6391 - accuracy: 0.9894 - val_loss: -0.3327 - val_dice_coef: 0.3327 - val_accuracy: 0.9755
# Epoch 17/50
# 40/40 [==============================] - 5s 121ms/step - loss: -0.6392 - dice_coef: 0.6392 - accuracy: 0.9899 - val_loss: -0.3366 - val_dice_coef: 0.3366 - val_accuracy: 0.9782
# Epoch 18/50
# 40/40 [==============================] - 5s 121ms/step - loss: -0.6419 - dice_coef: 0.6419 - accuracy: 0.9898 - val_loss: -0.3358 - val_dice_coef: 0.3358 - val_accuracy: 0.9772
# Epoch 19/50
# 40/40 [==============================] - 5s 120ms/step - loss: -0.6459 - dice_coef: 0.6459 - accuracy: 0.9906 - val_loss: -0.3382 - val_dice_coef: 0.3382 - val_accuracy: 0.9765
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 2.5130000358331015e-05.
# Epoch 20/50
# 40/40 [==============================] - 5s 120ms/step - loss: -0.6494 - dice_coef: 0.6494 - accuracy: 0.9912 - val_loss: -0.3419 - val_dice_coef: 0.3419 - val_accuracy: 0.9761
# Epoch 21/50
# 40/40 [==============================] - 5s 120ms/step - loss: -0.6538 - dice_coef: 0.6538 - accuracy: 0.9919 - val_loss: -0.3422 - val_dice_coef: 0.3422 - val_accuracy: 0.9749
# Epoch 22/50
# 40/40 [==============================] - 5s 120ms/step - loss: -0.6555 - dice_coef: 0.6555 - accuracy: 0.9922 - val_loss: -0.3446 - val_dice_coef: 0.3446 - val_accuracy: 0.9752
# Epoch 23/50
# 40/40 [==============================] - 5s 121ms/step - loss: -0.6562 - dice_coef: 0.6562 - accuracy: 0.9925 - val_loss: -0.3445 - val_dice_coef: 0.3445 - val_accuracy: 0.9747
# Epoch 24/50
# 40/40 [==============================] - 5s 121ms/step - loss: -0.6574 - dice_coef: 0.6574 - accuracy: 0.9926 - val_loss: -0.3478 - val_dice_coef: 0.3478 - val_accuracy: 0.9750
# Epoch 25/50
# 40/40 [==============================] - 5s 120ms/step - loss: -0.6579 - dice_coef: 0.6579 - accuracy: 0.9930 - val_loss: -0.3461 - val_dice_coef: 0.3461 - val_accuracy: 0.9752
# Epoch 26/50
# 40/40 [==============================] - 5s 122ms/step - loss: -0.6585 - dice_coef: 0.6585 - accuracy: 0.9933 - val_loss: -0.3450 - val_dice_coef: 0.3450 - val_accuracy: 0.9760
# Epoch 27/50
# 40/40 [==============================] - 5s 121ms/step - loss: -0.6584 - dice_coef: 0.6584 - accuracy: 0.9933 - val_loss: -0.3441 - val_dice_coef: 0.3441 - val_accuracy: 0.9759
# Epoch 28/50
# 40/40 [==============================] - 5s 121ms/step - loss: -0.6587 - dice_coef: 0.6587 - accuracy: 0.9936 - val_loss: -0.3512 - val_dice_coef: 0.3512 - val_accuracy: 0.9745
# Epoch 29/50
# 40/40 [==============================] - 5s 121ms/step - loss: -0.6554 - dice_coef: 0.6554 - accuracy: 0.9934 - val_loss: -0.3429 - val_dice_coef: 0.3429 - val_accuracy: 0.9770
# Epoch 30/50
# 40/40 [==============================] - 5s 122ms/step - loss: -0.6561 - dice_coef: 0.6561 - accuracy: 0.9937 - val_loss: -0.3435 - val_dice_coef: 0.3435 - val_accuracy: 0.9759
# Epoch 31/50
# 40/40 [==============================] - 5s 120ms/step - loss: -0.6595 - dice_coef: 0.6595 - accuracy: 0.9938 - val_loss: -0.3503 - val_dice_coef: 0.3503 - val_accuracy: 0.9750
# Epoch 32/50
# 40/40 [==============================] - 5s 121ms/step - loss: -0.6586 - dice_coef: 0.6586 - accuracy: 0.9939 - val_loss: -0.3479 - val_dice_coef: 0.3479 - val_accuracy: 0.9757
# Epoch 33/50
# 40/40 [==============================] - 5s 120ms/step - loss: -0.6596 - dice_coef: 0.6596 - accuracy: 0.9943 - val_loss: -0.3488 - val_dice_coef: 0.3488 - val_accuracy: 0.9762
# Epoch 34/50
# 40/40 [==============================] - 5s 121ms/step - loss: -0.6615 - dice_coef: 0.6615 - accuracy: 0.9946 - val_loss: -0.3464 - val_dice_coef: 0.3464 - val_accuracy: 0.9756
# Epoch 35/50
# 40/40 [==============================] - 5s 123ms/step - loss: -0.6624 - dice_coef: 0.6624 - accuracy: 0.9947 - val_loss: -0.3520 - val_dice_coef: 0.3520 - val_accuracy: 0.9743
# Epoch 36/50
# 40/40 [==============================] - 5s 122ms/step - loss: -0.6615 - dice_coef: 0.6615 - accuracy: 0.9949 - val_loss: -0.3569 - val_dice_coef: 0.3569 - val_accuracy: 0.9743
# Epoch 37/50
# 40/40 [==============================] - 5s 122ms/step - loss: -0.6619 - dice_coef: 0.6619 - accuracy: 0.9948 - val_loss: -0.3554 - val_dice_coef: 0.3554 - val_accuracy: 0.9736
# Epoch 38/50
# 40/40 [==============================] - 5s 120ms/step - loss: -0.6630 - dice_coef: 0.6630 - accuracy: 0.9952 - val_loss: -0.3496 - val_dice_coef: 0.3496 - val_accuracy: 0.9767
# Epoch 39/50
# 40/40 [==============================] - 5s 121ms/step - loss: -0.6631 - dice_coef: 0.6631 - accuracy: 0.9952 - val_loss: -0.3574 - val_dice_coef: 0.3574 - val_accuracy: 0.9743
# Epoch 40/50
# 40/40 [==============================] - 5s 122ms/step - loss: -0.6613 - dice_coef: 0.6613 - accuracy: 0.9949 - val_loss: -0.3550 - val_dice_coef: 0.3550 - val_accuracy: 0.9746
# Epoch 41/50
# 40/40 [==============================] - 5s 121ms/step - loss: -0.6600 - dice_coef: 0.6600 - accuracy: 0.9949 - val_loss: -0.3523 - val_dice_coef: 0.3523 - val_accuracy: 0.9745
# Epoch 42/50
# 40/40 [==============================] - 5s 121ms/step - loss: -0.6578 - dice_coef: 0.6578 - accuracy: 0.9948 - val_loss: -0.3489 - val_dice_coef: 0.3489 - val_accuracy: 0.9745
# Epoch 43/50
# 40/40 [==============================] - 5s 121ms/step - loss: -0.6616 - dice_coef: 0.6616 - accuracy: 0.9954 - val_loss: -0.3599 - val_dice_coef: 0.3599 - val_accuracy: 0.9742
# Epoch 44/50
# 40/40 [==============================] - 5s 121ms/step - loss: -0.6619 - dice_coef: 0.6619 - accuracy: 0.9953 - val_loss: -0.3579 - val_dice_coef: 0.3579 - val_accuracy: 0.9751
# Epoch 45/50
# 40/40 [==============================] - 5s 120ms/step - loss: -0.6625 - dice_coef: 0.6625 - accuracy: 0.9956 - val_loss: -0.3531 - val_dice_coef: 0.3531 - val_accuracy: 0.9757
# Epoch 46/50
# 40/40 [==============================] - 5s 119ms/step - loss: -0.6605 - dice_coef: 0.6605 - accuracy: 0.9955 - val_loss: -0.3536 - val_dice_coef: 0.3536 - val_accuracy: 0.9751
# Epoch 47/50
# 40/40 [==============================] - 5s 121ms/step - loss: -0.6606 - dice_coef: 0.6606 - accuracy: 0.9955 - val_loss: -0.3590 - val_dice_coef: 0.3590 - val_accuracy: 0.9756
# Epoch 48/50
# 40/40 [==============================] - 5s 122ms/step - loss: -0.6621 - dice_coef: 0.6621 - accuracy: 0.9957 - val_loss: -0.3527 - val_dice_coef: 0.3527 - val_accuracy: 0.9753
# Epoch 49/50
# 40/40 [==============================] - 5s 122ms/step - loss: -0.6629 - dice_coef: 0.6629 - accuracy: 0.9957 - val_loss: -0.3588 - val_dice_coef: 0.3588 - val_accuracy: 0.9756
# Epoch 50/50
# 40/40 [==============================] - 5s 122ms/step - loss: -0.6640 - dice_coef: 0.6640 - accuracy: 0.9960 - val_loss: -0.3535 - val_dice_coef: 0.3535 - val_accuracy: 0.9761
# model_fine_tuning_No_NAIP_50_samples_r2_
# index  0
# index  1
# index  2
# index  3
# (40, 224, 224, 8)
# (40, 224, 224, 1)
# (10, 224, 224, 8)
# (10, 224, 224, 1)
# Train on 40 samples, validate on 10 samples
# Epoch 1/50
# 40/40 [==============================] - 6s 150ms/step - loss: -0.0962 - dice_coef: 0.0962 - accuracy: 0.4772 - val_loss: -0.0529 - val_dice_coef: 0.0529 - val_accuracy: 0.2265
# Epoch 2/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.1227 - dice_coef: 0.1227 - accuracy: 0.5017 - val_loss: -0.0645 - val_dice_coef: 0.0645 - val_accuracy: 0.6014
# Epoch 3/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.1369 - dice_coef: 0.1369 - accuracy: 0.7319 - val_loss: -0.0811 - val_dice_coef: 0.0811 - val_accuracy: 0.8437
# Epoch 4/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.1579 - dice_coef: 0.1579 - accuracy: 0.8437 - val_loss: -0.0878 - val_dice_coef: 0.0878 - val_accuracy: 0.8264
# Epoch 5/50
# 40/40 [==============================] - 2s 39ms/step - loss: -0.1744 - dice_coef: 0.1744 - accuracy: 0.9399 - val_loss: -0.1064 - val_dice_coef: 0.1064 - val_accuracy: 0.9152
# Epoch 6/50
# ...
# Epoch 39/50
# 48/48 [==============================] - 41s 859ms/step - loss: -0.6196 - dice_coef: 0.6196 - accuracy: 0.9783 - val_loss: -0.5254 - val_dice_coef: 0.5254 - val_accuracy: 0.9790
# Epoch 40/50
# 48/48 [==============================] - 39s 811ms/step - loss: -0.6087 - dice_coef: 0.6087 - accuracy: 0.9775 - val_loss: -0.5173 - val_dice_coef: 0.5173 - val_accuracy: 0.9790
# Epoch 41/50
# 48/48 [==============================] - 40s 824ms/step - loss: -0.5717 - dice_coef: 0.5717 - accuracy: 0.9758 - val_loss: -0.4987 - val_dice_coef: 0.4987 - val_accuracy: 0.9793
# Epoch 42/50
# 48/48 [==============================] - 39s 818ms/step - loss: -0.5871 - dice_coef: 0.5871 - accuracy: 0.9771 - val_loss: -0.5262 - val_dice_coef: 0.5262 - val_accuracy: 0.9799
# Epoch 43/50
# 48/48 [==============================] - 40s 827ms/step - loss: -0.6117 - dice_coef: 0.6117 - accuracy: 0.9771 - val_loss: -0.5282 - val_dice_coef: 0.5282 - val_accuracy: 0.9799
# Epoch 44/50
# 48/48 [==============================] - 39s 806ms/step - loss: -0.5729 - dice_coef: 0.5729 - accuracy: 0.9768 - val_loss: -0.5146 - val_dice_coef: 0.5146 - val_accuracy: 0.9792
# Epoch 45/50
# 48/48 [==============================] - 39s 809ms/step - loss: -0.5656 - dice_coef: 0.5656 - accuracy: 0.9755 - val_loss: -0.5293 - val_dice_coef: 0.5293 - val_accuracy: 0.9790
# Epoch 46/50
# 48/48 [==============================] - 39s 819ms/step - loss: -0.5762 - dice_coef: 0.5762 - accuracy: 0.9773 - val_loss: -0.5280 - val_dice_coef: 0.5280 - val_accuracy: 0.9792
# Epoch 47/50
# 48/48 [==============================] - 39s 805ms/step - loss: -0.6183 - dice_coef: 0.6183 - accuracy: 0.9774 - val_loss: -0.5223 - val_dice_coef: 0.5223 - val_accuracy: 0.9794
# Epoch 48/50
# 48/48 [==============================] - 39s 815ms/step - loss: -0.6177 - dice_coef: 0.6177 - accuracy: 0.9793 - val_loss: -0.5166 - val_dice_coef: 0.5166 - val_accuracy: 0.9791
# Epoch 49/50
# 48/48 [==============================] - 40s 823ms/step - loss: -0.6044 - dice_coef: 0.6044 - accuracy: 0.9764 - val_loss: -0.5005 - val_dice_coef: 0.5005 - val_accuracy: 0.9795
# Epoch 50/50
# 48/48 [==============================] - 39s 806ms/step - loss: -0.6000 - dice_coef: 0.6000 - accuracy: 0.9786 - val_loss: -0.5019 - val_dice_coef: 0.5019 - val_accuracy: 0.9791
# Train on 48 samples, validate on 12 samples
# Epoch 1/50
# 48/48 [==============================] - 90s 2s/step - loss: -0.4384 - dice_coef: 0.4384 - accuracy: 0.9721 - val_loss: -0.5842 - val_dice_coef: 0.5842 - val_accuracy: 0.9823
# Epoch 2/50
# 48/48 [==============================] - 92s 2s/step - loss: -0.5057 - dice_coef: 0.5057 - accuracy: 0.9805 - val_loss: -0.5553 - val_dice_coef: 0.5553 - val_accuracy: 0.9814
# Epoch 3/50
# 48/48 [==============================] - 82s 2s/step - loss: -0.5436 - dice_coef: 0.5436 - accuracy: 0.9841 - val_loss: -0.5383 - val_dice_coef: 0.5383 - val_accuracy: 0.9810
# Epoch 4/50
# 48/48 [==============================] - 82s 2s/step - loss: -0.5633 - dice_coef: 0.5633 - accuracy: 0.9863 - val_loss: -0.4908 - val_dice_coef: 0.4908 - val_accuracy: 0.9804
# Epoch 5/50
# 48/48 [==============================] - 90s 2s/step - loss: -0.5562 - dice_coef: 0.5562 - accuracy: 0.9862 - val_loss: -0.5193 - val_dice_coef: 0.5193 - val_accuracy: 0.9792
# Epoch 6/50
# 48/48 [==============================] - 77s 2s/step - loss: -0.5716 - dice_coef: 0.5716 - accuracy: 0.9869 - val_loss: -0.4793 - val_dice_coef: 0.4793 - val_accuracy: 0.9651
# Epoch 7/50
# 48/48 [==============================] - 80s 2s/step - loss: -0.5839 - dice_coef: 0.5839 - accuracy: 0.9887 - val_loss: -0.4147 - val_dice_coef: 0.4147 - val_accuracy: 0.9362
# Epoch 8/50
# 48/48 [==============================] - 90s 2s/step - loss: -0.5934 - dice_coef: 0.5934 - accuracy: 0.9892 - val_loss: -0.4597 - val_dice_coef: 0.4597 - val_accuracy: 0.9598
# Epoch 9/50
# 48/48 [==============================] - 97s 2s/step - loss: -0.6004 - dice_coef: 0.6004 - accuracy: 0.9899 - val_loss: -0.4548 - val_dice_coef: 0.4548 - val_accuracy: 0.9617
# Epoch 10/50
# 48/48 [==============================] - 99s 2s/step - loss: -0.6061 - dice_coef: 0.6061 - accuracy: 0.9910 - val_loss: -0.4493 - val_dice_coef: 0.4493 - val_accuracy: 0.9594
# Epoch 11/50
# 48/48 [==============================] - 84s 2s/step - loss: -0.6080 - dice_coef: 0.6080 - accuracy: 0.9909 - val_loss: -0.4957 - val_dice_coef: 0.4957 - val_accuracy: 0.9691
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 2.5130000358331015e-05.
# Epoch 12/50
# 48/48 [==============================] - 86s 2s/step - loss: -0.6100 - dice_coef: 0.6100 - accuracy: 0.9913 - val_loss: -0.5092 - val_dice_coef: 0.5092 - val_accuracy: 0.9756
# Epoch 13/50
# 48/48 [==============================] - 86s 2s/step - loss: -0.6195 - dice_coef: 0.6195 - accuracy: 0.9922 - val_loss: -0.4792 - val_dice_coef: 0.4792 - val_accuracy: 0.9689
# Epoch 14/50
# 48/48 [==============================] - 84s 2s/step - loss: -0.6179 - dice_coef: 0.6179 - accuracy: 0.9920 - val_loss: -0.4868 - val_dice_coef: 0.4868 - val_accuracy: 0.9660
# Epoch 15/50
# 48/48 [==============================] - 92s 2s/step - loss: -0.6229 - dice_coef: 0.6229 - accuracy: 0.9924 - val_loss: -0.4873 - val_dice_coef: 0.4873 - val_accuracy: 0.9685
# Epoch 16/50
# 48/48 [==============================] - 79s 2s/step - loss: -0.6252 - dice_coef: 0.6252 - accuracy: 0.9927 - val_loss: -0.4615 - val_dice_coef: 0.4615 - val_accuracy: 0.9603
# Epoch 17/50
# 48/48 [==============================] - 81s 2s/step - loss: -0.6272 - dice_coef: 0.6272 - accuracy: 0.9930 - val_loss: -0.4758 - val_dice_coef: 0.4758 - val_accuracy: 0.9583
# Epoch 18/50
# 48/48 [==============================] - 83s 2s/step - loss: -0.6271 - dice_coef: 0.6271 - accuracy: 0.9930 - val_loss: -0.4416 - val_dice_coef: 0.4416 - val_accuracy: 0.9544
# Epoch 19/50
# 48/48 [==============================] - 91s 2s/step - loss: -0.6282 - dice_coef: 0.6282 - accuracy: 0.9933 - val_loss: -0.4685 - val_dice_coef: 0.4685 - val_accuracy: 0.9577
# Epoch 20/50
# 48/48 [==============================] - 85s 2s/step - loss: -0.6314 - dice_coef: 0.6314 - accuracy: 0.9935 - val_loss: -0.4762 - val_dice_coef: 0.4762 - val_accuracy: 0.9643
# Epoch 21/50
# 48/48 [==============================] - 86s 2s/step - loss: -0.6285 - dice_coef: 0.6285 - accuracy: 0.9936 - val_loss: -0.4650 - val_dice_coef: 0.4650 - val_accuracy: 0.9575
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.7591000505490227e-05.
# model_fine_tuning_No_NAIP_60_samples_r4_
# index  0
# index  1
# index  2
# index  3
# (48, 224, 224, 8)
# (48, 224, 224, 1)
# (12, 224, 224, 8)
# (12, 224, 224, 1)
# Train on 48 samples, validate on 12 samples
# Epoch 1/50
# 48/48 [==============================] - 10s 213ms/step - loss: -0.0696 - dice_coef: 0.0696 - accuracy: 0.5420 - val_loss: -0.0190 - val_dice_coef: 0.0190 - val_accuracy: 0.9363
# Epoch 2/50
# 48/48 [==============================] - 6s 116ms/step - loss: -0.1142 - dice_coef: 0.1142 - accuracy: 0.5604 - val_loss: -0.0319 - val_dice_coef: 0.0319 - val_accuracy: 0.9799
# Epoch 3/50
# 48/48 [==============================] - 6s 116ms/step - loss: -0.1366 - dice_coef: 0.1366 - accuracy: 0.5761 - val_loss: -0.0371 - val_dice_coef: 0.0371 - val_accuracy: 0.9823
# Epoch 4/50
# 48/48 [==============================] - 6s 116ms/step - loss: -0.1460 - dice_coef: 0.1460 - accuracy: 0.5850 - val_loss: -0.0406 - val_dice_coef: 0.0406 - val_accuracy: 0.9867
# Epoch 5/50
# 48/48 [==============================] - 6s 116ms/step - loss: -0.1397 - dice_coef: 0.1397 - accuracy: 0.5769 - val_loss: -0.0361 - val_dice_coef: 0.0361 - val_accuracy: 0.9870
# Epoch 6/50
# 48/48 [==============================] - 6s 116ms/step - loss: -0.1463 - dice_coef: 0.1463 - accuracy: 0.5816 - val_loss: -0.0209 - val_dice_coef: 0.0209 - val_accuracy: 0.9865
# Epoch 7/50
# 48/48 [==============================] - 6s 116ms/step - loss: -0.1584 - dice_coef: 0.1584 - accuracy: 0.5917 - val_loss: -0.0199 - val_dice_coef: 0.0199 - val_accuracy: 0.9799
# Epoch 8/50
# 48/48 [==============================] - 6s 115ms/step - loss: -0.1502 - dice_coef: 0.1502 - accuracy: 0.5926 - val_loss: -0.0133 - val_dice_coef: 0.0133 - val_accuracy: 0.9764
# Epoch 9/50
# 48/48 [==============================] - 6s 116ms/step - loss: -0.1532 - dice_coef: 0.1532 - accuracy: 0.5975 - val_loss: -0.0139 - val_dice_coef: 0.0139 - val_accuracy: 0.9665
# Epoch 10/50
# 48/48 [==============================] - 6s 115ms/step - loss: -0.1594 - dice_coef: 0.1594 - accuracy: 0.6007 - val_loss: -0.0137 - val_dice_coef: 0.0137 - val_accuracy: 0.9038
# Epoch 11/50
# 48/48 [==============================] - 6s 116ms/step - loss: -0.1644 - dice_coef: 0.1644 - accuracy: 0.6053 - val_loss: -0.0169 - val_dice_coef: 0.0169 - val_accuracy: 0.9868
# Epoch 12/50
# 48/48 [==============================] - 6s 115ms/step - loss: -0.1739 - dice_coef: 0.1739 - accuracy: 0.6093 - val_loss: -0.0345 - val_dice_coef: 0.0345 - val_accuracy: 0.9339
# Epoch 13/50
# 48/48 [==============================] - 6s 116ms/step - loss: -0.1636 - dice_coef: 0.1636 - accuracy: 0.6031 - val_loss: -0.0400 - val_dice_coef: 0.0400 - val_accuracy: 0.8318
# Epoch 14/50
# 48/48 [==============================] - 6s 116ms/step - loss: -0.1669 - dice_coef: 0.1669 - accuracy: 0.6076 - val_loss: -0.0093 - val_dice_coef: 0.0093 - val_accuracy: 0.9582
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# Epoch 15/50
# 48/48 [==============================] - 6s 116ms/step - loss: -0.1723 - dice_coef: 0.1723 - accuracy: 0.6150 - val_loss: -0.0074 - val_dice_coef: 0.0074 - val_accuracy: 0.9210
# Epoch 16/50
# 48/48 [==============================] - 6s 115ms/step - loss: -0.1740 - dice_coef: 0.1740 - accuracy: 0.6140 - val_loss: -0.0069 - val_dice_coef: 0.0069 - val_accuracy: 0.9144
# Epoch 17/50
# 48/48 [==============================] - 6s 116ms/step - loss: -0.1673 - dice_coef: 0.1673 - accuracy: 0.6153 - val_loss: -0.0064 - val_dice_coef: 0.0064 - val_accuracy: 0.9303
# Epoch 18/50
# 48/48 [==============================] - 6s 115ms/step - loss: -0.1767 - dice_coef: 0.1767 - accuracy: 0.6185 - val_loss: -0.0076 - val_dice_coef: 0.0076 - val_accuracy: 0.9841
# Epoch 19/50
# 48/48 [==============================] - 6s 116ms/step - loss: -0.1772 - dice_coef: 0.1772 - accuracy: 0.6160 - val_loss: -0.0165 - val_dice_coef: 0.0165 - val_accuracy: 0.9544
# Epoch 20/50
# 48/48 [==============================] - 6s 116ms/step - loss: -0.1749 - dice_coef: 0.1749 - accuracy: 0.6199 - val_loss: -0.0360 - val_dice_coef: 0.0360 - val_accuracy: 0.8843
# Epoch 21/50
# 48/48 [==============================] - 6s 117ms/step - loss: -0.1788 - dice_coef: 0.1788 - accuracy: 0.6227 - val_loss: -0.0053 - val_dice_coef: 0.0053 - val_accuracy: 0.9724
# Epoch 22/50
# 48/48 [==============================] - 6s 116ms/step - loss: -0.1746 - dice_coef: 0.1746 - accuracy: 0.6198 - val_loss: -0.0056 - val_dice_coef: 0.0056 - val_accuracy: 0.9828
# Epoch 23/50
# 48/48 [==============================] - 6s 115ms/step - loss: -0.1797 - dice_coef: 0.1797 - accuracy: 0.6228 - val_loss: -0.0053 - val_dice_coef: 0.0053 - val_accuracy: 0.9836
# Epoch 24/50
# 48/48 [==============================] - 6s 115ms/step - loss: -0.1858 - dice_coef: 0.1858 - accuracy: 0.6280 - val_loss: -0.0062 - val_dice_coef: 0.0062 - val_accuracy: 0.9777
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0004900000232737511.
# Train on 48 samples, validate on 12 samples
# Epoch 1/50
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-1-10d9f10ceb70> in <module>
#     280             ]
#     281
# --> 282         fine_tuned_model_P2_history = transfered_model.fit(X_train_new, Y_train, validation_data=(X_Validation_new,Y_Validation), batch_size=1, epochs=maxepoch, callbacks=callbacks)
#     283
#     284
#
# C:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# C:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# C:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# C:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# C:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      65     else:
#      66       message = e.message
# ---> 67     six.raise_from(core._status_to_exception(e.code, message), None)
#      68   except TypeError as e:
#      69     keras_symbolic_tensors = [
#
# C:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\six.py in raise_from(value, from_value)
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[1,32,224,224] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node gradients_47/batch_normalization_2_15/cond_grad/StatelessIf/then/_1464/zeros_like_0}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_keras_scratch_graph_1881100]
#
# Function call stack:
# keras_scratch_graph
