# %%
## Load all the dependencies
import os
import sys
import random
import warnings
import numpy as np
from itertools import chain
from numpy import genfromtxt
from tensorflow import random
from keras import backend as K
from keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import Layer, UpSampling2D, GlobalAveragePooling2D, Multiply, Dense, Reshape, Permute, multiply, dot, add, Input
from keras.layers.core import Dropout, Lambda, SpatialDropout2D, Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Model, load_model, model_from_yaml, Sequential
import tensorflow as tf

np.random.seed(1337) # for reproducibility
random.set_seed(1337)
print(tf.__version__)
# Out:
# 2.1.0

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, False)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# Use dice coefficient function as the loss function 
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)

# Jacard coefficient
def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

# calculate loss value
def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)

# calculate loss value
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def Residual_CNN_block(x, size, dropout=0.0, batch_norm=True):
    if K.image_dim_ordering() == 'th':
        axis = 1
    else:
        axis = 3
    conv = Conv2D(size, (3, 3), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    return conv

class multiplication(Layer):
    def __init__(self,inter_channel = None,**kwargs):
        super(multiplication, self).__init__(**kwargs)
        self.inter_channel = inter_channel
    def build(self,input_shape=None):
        self.k = self.add_weight(name='k',shape=(1,),initializer='zeros',dtype='float32',trainable=True)
    def get_config(self):
        base_config = super(multiplication, self).get_config()
        config = {'inter_channel':self.inter_channel}
        return dict(list(base_config.items()) + list(config.items()))  
    def call(self,inputs):
        g,x,x_query,phi_g,x_value = inputs[0],inputs[1],inputs[2],inputs[3],inputs[4]
        h,w,c = int(x.shape[1]),int(x.shape[2]),int(x.shape[3])
        x_query = K.reshape(x_query, shape=(-1,h*w, self.inter_channel//4))
        phi_g = K.reshape(phi_g,shape=(-1,h*w,self.inter_channel//4))
        x_value = K.reshape(x_value,shape=(-1,h*w,c))
        scale = dot([K.permute_dimensions(phi_g,(0,2,1)), x_query], axes=(1, 2))
        soft_scale = Activation('softmax')(scale)
        scaled_value = dot([K.permute_dimensions(soft_scale,(0,2,1)),K.permute_dimensions(x_value,(0,2,1))],axes=(1, 2))
        scaled_value = K.reshape(scaled_value, shape=(-1,h,w,c))        
        customize_multi = self.k * scaled_value
        layero = add([customize_multi,x])
        my_concat = Lambda(lambda x: K.concatenate([x[0], x[1]], axis=3))
        concate = my_concat([layero,g])
        return concate 
    def compute_output_shape(self,input_shape):
        ll = list(input_shape)[1]
        return (None,ll[1],ll[1],ll[3]*3)
    def get_custom_objects():
        return {'multiplication': multiplication}

def attention_up_and_concatenate(inputs):
    g,x = inputs[0],inputs[1]
    inter_channel = g.get_shape().as_list()[3]
    g = Conv2DTranspose(inter_channel, (2,2), strides=[2, 2],padding='same')(g)
    x_query = Conv2D(inter_channel//4, [1, 1], strides=[1, 1], data_format='channels_last')(x)
    phi_g = Conv2D(inter_channel//4, [1, 1], strides=[1, 1], data_format='channels_last')(g)
    x_value = Conv2D(inter_channel//2, [1, 1], strides=[1, 1], data_format='channels_last')(x)
    inputs = [g,x,x_query,phi_g,x_value]
    concate = multiplication(inter_channel)(inputs)
    return concate

class multiplication2(Layer):
    def __init__(self,inter_channel = None,**kwargs):
        super(multiplication2, self).__init__(**kwargs)
        self.inter_channel = inter_channel
    def build(self,input_shape=None):
        self.k = self.add_weight(name='k',shape=(1,),initializer='zeros',dtype='float32',trainable=True)
    def get_config(self):
        base_config = super(multiplication2, self).get_config()
        config = {'inter_channel':self.inter_channel}
        return dict(list(base_config.items()) + list(config.items()))  
    def call(self,inputs):
        g,x,rate = inputs[0],inputs[1],inputs[2]
        scaled_value = multiply([x, rate])
        att_x =  self.k * scaled_value
        att_x = add([att_x,x])
        my_concat = Lambda(lambda x: K.concatenate([x[0], x[1]], axis=3))
        concate = my_concat([att_x, g])
        return concate 
    def compute_output_shape(self,input_shape):
        ll = list(input_shape)[1]
        return (None,ll[1],ll[1],ll[3]*2)
    def get_custom_objects():
        return {'multiplication2': multiplication2}

def attention_up_and_concatenate2(inputs):
    g, x = inputs[0],inputs[1]
    inter_channel = g.get_shape().as_list()[3]
    g = Conv2DTranspose(inter_channel//2, (3,3), strides=[2, 2],padding='same')(g)
    g = Conv2D(inter_channel//2, [1, 1], strides=[1, 1], data_format='channels_last')(g)
    theta_x = Conv2D(inter_channel//4, [1, 1], strides=[1, 1], data_format='channels_last')(x)
    phi_g = Conv2D(inter_channel//4, [1, 1], strides=[1, 1], data_format='channels_last')(g)
    f = Activation('relu')(add([theta_x, phi_g]))
    psi_f = Conv2D(1, [1, 1], strides=[1, 1], data_format='channels_last')(f)
    rate = Activation('sigmoid')(psi_f)
    concate =  multiplication2()([g,x,rate])
    return concate

# %%
loaded_model = load_model('June21/model/model_augv_attention2.h5', 
                             custom_objects={'multiplication': multiplication,'multiplication2': multiplication2, 
                                             'dice_coef_loss':dice_coef_loss, 'dice_coef':dice_coef,})

# remove the last 2 layer using pop() function
loaded_model.layers.pop()
loaded_model.layers.pop()

for (index, layer) in enumerate(loaded_model.layers):
    if (index > len(loaded_model.layers)-5):
        print("Here")
        layer.trainable = True
    else:
        layer.trainable = False

# Create new model from the model using the input and output of the last layer (after poping last 2 layers)
# model_without_last = Model(loaded_model.input,  loaded_model.layers[-1].output)
model_without_last = Model(loaded_model.input,  loaded_model.output)

# model_without_last.trainable = False

# See model structure
# model_without_last.summary()
# Out:
# Here
# Here
# Here
# Here

# %%
# Number of output masks (1 in case you predict only one type of objects)
OUTPUT_MASK_CHANNELS = 1

# 1 dimensional convolution and generate probabilities from Sigmoid function
conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1), name='conv2d_last')(model_without_last.output)
new_out = Activation('sigmoid', name='activation_last')(conv_final)

# Created new model with the newly added last two layers 
transfered_model = Model(inputs=model_without_last.input, outputs=new_out)

# New model structure
# transfered_model.summary()

# %% [markdown]
# # If want to train on the data **without** the NAIP, run the block below.

# %%
data_path = 'Covington_data/without_NAIP/nodata_as_0/'

# read in training and validation data
X_train = np.load(data_path+'train_data.npy')
Y_train = np.load(data_path+'train_label.npy')
X_Validation = np.load(data_path+'vali_data.npy')
Y_Validation = np.load(data_path+'vali_label.npy')

# The dataset has 9 channels:
# 0. Curvature
# 1. Slope
# 2. Openness
# 3. DEM
# 4. TPI 21
# 5. Reflectance (LiDAR intensity)
# 6. Geomorphon
# 7. TPI 9
# 8. TPI 3
# but the model expects 8 channels
# So we exclude TPI_9 channel from the data set
# X_train_new = X_train[:,:,:,(0,1,2,3,4,5,6,8)]
# print(X_train_new.shape)
X_train_new = X_train
print(X_train_new.shape)

# X_Validation_new = X_Validation[:,:,:,(0,1,2,3,4,5,6,8)]
# print(X_Validation_new.shape)

X_Validation_new = X_Validation
print(X_Validation_new.shape)
# Out:
# (600, 224, 224, 8)
# (600, 224, 224, 8)

# %%
data_path = 'Covington_data/without_NAIP/nodata_as_0/'

# read in training and validation data
X_train = np.load(data_path+'train_data.npy')
Y_train = np.load(data_path+'train_label.npy')
X_Validation = np.load(data_path+'vali_data.npy')
Y_Validation = np.load(data_path+'vali_label.npy')

# The dataset has 9 channels:
# 0. Curvature
# 1. Slope
# 2. Openness
# 3. DEM
# 4. TPI 21
# 5. Reflectance (LiDAR intensity)
# 6. Geomorphon
# 7. TPI 9
# 8. TPI 3

##############################################
# 100 samples 
X_train_new = X_train[0:50,:,:,:]
print(X_train_new.shape)
Y_train = np.load(data_path+'train_label.npy')[0:50,:,:,:]
print(Y_train.shape)

X_Validation_new = X_Validation[0:50,:,:,:]
print(X_Validation_new.shape)
Y_Validation = np.load(data_path+'vali_label.npy')[0:50,:,:,:]
print(Y_Validation.shape)
##############################################



# ##############################################
# # 700 samples 
# X_train_new = X_train[0:350,:,:,:]
# print(X_train_new.shape)
# Y_train = np.load(data_path+'train_label.npy')[0:350,:,:,:]
# print(Y_train.shape)

# X_Validation_new = X_Validation[0:350,:,:,:]
# print(X_Validation_new.shape)
# Y_Validation = np.load(data_path+'vali_label.npy')[0:350,:,:,:]
# print(Y_Validation.shape)
# ##############################################


# ##############################################
# # 1200 samples 
# X_train_new = X_train
# print(X_train_new.shape)
# Y_train = np.load(data_path+'train_label.npy')
# print(Y_train.shape)

# X_Validation_new = X_Validation
# print(X_Validation_new.shape)
# Y_Validation = np.load(data_path+'vali_label.npy')
# print(Y_Validation.shape)
# ##############################################
# Out:
# (50, 224, 224, 8)
# (50, 224, 224, 1)
# (50, 224, 224, 8)
# (50, 224, 224, 1)

# %% [markdown]
# ## First pass

# %%
patch_size = 224
IMG_WIDTH = patch_size
IMG_HEIGHT = patch_size
# Number of feature channels 
INPUT_CHANNELS = 8
# Number of output masks (1 in case you predict only one type of objects)
OUTPUT_MASK_CHANNELS = 1
maxepoch = 100
# hyperparameters
# learning_rate = 0.0000359
learning_rate = 0.0001
patience = 20
aug = 'v'
transfered_model.compile(optimizer=Adam(lr=learning_rate),loss = dice_coef_loss,metrics=[dice_coef,'accuracy'])
callbacks = [
        ReduceLROnPlateau(monitor='val_loss', factor=0.7, patience=patience, min_lr=1e-9, verbose=1, mode='min'),
        EarlyStopping(monitor='val_loss', patience=patience+10, verbose=0),
        ModelCheckpoint('model'+aug+'_attention2.h5', monitor='val_loss', save_best_only=True, verbose=0),
    ]

# %%
tranfer_learning_history = transfered_model.fit(X_train_new, Y_train, validation_data=(X_Validation_new,Y_Validation), batch_size=2, epochs=maxepoch, callbacks=callbacks)
# Out:
# Train on 50 samples, validate on 50 samples
# Epoch 1/100
# 50/50 [==============================] - 6s 113ms/step - loss: -0.0605 - dice_coef: 0.0605 - accuracy: 0.0314 - val_loss: -0.0456 - val_dice_coef: 0.0456 - val_accuracy: 0.0233
# Epoch 2/100
# 50/50 [==============================] - 2s 30ms/step - loss: -0.0606 - dice_coef: 0.0606 - accuracy: 0.0314 - val_loss: -0.0456 - val_dice_coef: 0.0456 - val_accuracy: 0.0233
# Epoch 3/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0612 - dice_coef: 0.0612 - accuracy: 0.0314 - val_loss: -0.0456 - val_dice_coef: 0.0456 - val_accuracy: 0.0233
# Epoch 4/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0604 - dice_coef: 0.0604 - accuracy: 0.0314 - val_loss: -0.0457 - val_dice_coef: 0.0457 - val_accuracy: 0.0233
# Epoch 5/100
# 50/50 [==============================] - 2s 30ms/step - loss: -0.0604 - dice_coef: 0.0604 - accuracy: 0.0314 - val_loss: -0.0457 - val_dice_coef: 0.0457 - val_accuracy: 0.0233
# Epoch 6/100
# 50/50 [==============================] - 2s 30ms/step - loss: -0.0610 - dice_coef: 0.0610 - accuracy: 0.0314 - val_loss: -0.0457 - val_dice_coef: 0.0457 - val_accuracy: 0.0233
# Epoch 7/100
# 50/50 [==============================] - 2s 30ms/step - loss: -0.0599 - dice_coef: 0.0599 - accuracy: 0.0314 - val_loss: -0.0457 - val_dice_coef: 0.0457 - val_accuracy: 0.0233
# Epoch 8/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0604 - dice_coef: 0.0604 - accuracy: 0.0314 - val_loss: -0.0458 - val_dice_coef: 0.0458 - val_accuracy: 0.0233
# Epoch 9/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0609 - dice_coef: 0.0609 - accuracy: 0.0314 - val_loss: -0.0458 - val_dice_coef: 0.0458 - val_accuracy: 0.0233
# Epoch 10/100
# 50/50 [==============================] - 2s 30ms/step - loss: -0.0609 - dice_coef: 0.0609 - accuracy: 0.0314 - val_loss: -0.0458 - val_dice_coef: 0.0458 - val_accuracy: 0.0233
# Epoch 11/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0610 - dice_coef: 0.0610 - accuracy: 0.0314 - val_loss: -0.0458 - val_dice_coef: 0.0458 - val_accuracy: 0.0233
# Epoch 12/100
# 50/50 [==============================] - 2s 30ms/step - loss: -0.0619 - dice_coef: 0.0619 - accuracy: 0.0314 - val_loss: -0.0459 - val_dice_coef: 0.0459 - val_accuracy: 0.0233
# Epoch 13/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0614 - dice_coef: 0.0614 - accuracy: 0.0314 - val_loss: -0.0459 - val_dice_coef: 0.0459 - val_accuracy: 0.0233
# Epoch 14/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0611 - dice_coef: 0.0611 - accuracy: 0.0314 - val_loss: -0.0459 - val_dice_coef: 0.0459 - val_accuracy: 0.0233
# Epoch 15/100
# 50/50 [==============================] - 2s 30ms/step - loss: -0.0617 - dice_coef: 0.0617 - accuracy: 0.0314 - val_loss: -0.0459 - val_dice_coef: 0.0459 - val_accuracy: 0.0233
# Epoch 16/100
# 50/50 [==============================] - 2s 30ms/step - loss: -0.0607 - dice_coef: 0.0607 - accuracy: 0.0314 - val_loss: -0.0460 - val_dice_coef: 0.0460 - val_accuracy: 0.0233
# Epoch 17/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0612 - dice_coef: 0.0612 - accuracy: 0.0314 - val_loss: -0.0460 - val_dice_coef: 0.0460 - val_accuracy: 0.0233
# Epoch 18/100
# 50/50 [==============================] - 2s 30ms/step - loss: -0.0620 - dice_coef: 0.0620 - accuracy: 0.0314 - val_loss: -0.0460 - val_dice_coef: 0.0460 - val_accuracy: 0.0233
# Epoch 19/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0620 - dice_coef: 0.0620 - accuracy: 0.0314 - val_loss: -0.0460 - val_dice_coef: 0.0460 - val_accuracy: 0.0233
# Epoch 20/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0619 - dice_coef: 0.0619 - accuracy: 0.0314 - val_loss: -0.0461 - val_dice_coef: 0.0461 - val_accuracy: 0.0233
# Epoch 21/100
# 50/50 [==============================] - 2s 30ms/step - loss: -0.0616 - dice_coef: 0.0616 - accuracy: 0.0314 - val_loss: -0.0461 - val_dice_coef: 0.0461 - val_accuracy: 0.0233
# Epoch 22/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0616 - dice_coef: 0.0616 - accuracy: 0.0314 - val_loss: -0.0461 - val_dice_coef: 0.0461 - val_accuracy: 0.0233
# Epoch 23/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0617 - dice_coef: 0.0617 - accuracy: 0.0314 - val_loss: -0.0461 - val_dice_coef: 0.0461 - val_accuracy: 0.0233
# Epoch 24/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0619 - dice_coef: 0.0619 - accuracy: 0.0314 - val_loss: -0.0462 - val_dice_coef: 0.0462 - val_accuracy: 0.0233
# Epoch 25/100
# 50/50 [==============================] - 2s 30ms/step - loss: -0.0619 - dice_coef: 0.0619 - accuracy: 0.0314 - val_loss: -0.0462 - val_dice_coef: 0.0462 - val_accuracy: 0.0233
# Epoch 26/100
# 50/50 [==============================] - 2s 32ms/step - loss: -0.0619 - dice_coef: 0.0619 - accuracy: 0.0314 - val_loss: -0.0462 - val_dice_coef: 0.0462 - val_accuracy: 0.0233
# Epoch 27/100
# 50/50 [==============================] - 2s 32ms/step - loss: -0.0618 - dice_coef: 0.0618 - accuracy: 0.0314 - val_loss: -0.0462 - val_dice_coef: 0.0462 - val_accuracy: 0.0233
# Epoch 28/100
# 50/50 [==============================] - 2s 33ms/step - loss: -0.0624 - dice_coef: 0.0624 - accuracy: 0.0314 - val_loss: -0.0462 - val_dice_coef: 0.0462 - val_accuracy: 0.0233
# Epoch 29/100
# 50/50 [==============================] - 2s 34ms/step - loss: -0.0620 - dice_coef: 0.0620 - accuracy: 0.0314 - val_loss: -0.0463 - val_dice_coef: 0.0463 - val_accuracy: 0.0233
# Epoch 30/100
# 50/50 [==============================] - 2s 32ms/step - loss: -0.0629 - dice_coef: 0.0629 - accuracy: 0.0314 - val_loss: -0.0463 - val_dice_coef: 0.0463 - val_accuracy: 0.0233
# Epoch 31/100
# 50/50 [==============================] - 2s 33ms/step - loss: -0.0625 - dice_coef: 0.0625 - accuracy: 0.0314 - val_loss: -0.0463 - val_dice_coef: 0.0463 - val_accuracy: 0.0233
# Epoch 32/100
# 50/50 [==============================] - 2s 33ms/step - loss: -0.0621 - dice_coef: 0.0621 - accuracy: 0.0314 - val_loss: -0.0464 - val_dice_coef: 0.0464 - val_accuracy: 0.0233
# Epoch 33/100
# 50/50 [==============================] - 2s 34ms/step - loss: -0.0625 - dice_coef: 0.0625 - accuracy: 0.0314 - val_loss: -0.0463 - val_dice_coef: 0.0463 - val_accuracy: 0.0233
# Epoch 34/100
# 50/50 [==============================] - 2s 34ms/step - loss: -0.0623 - dice_coef: 0.0623 - accuracy: 0.0314 - val_loss: -0.0464 - val_dice_coef: 0.0464 - val_accuracy: 0.0233
# Epoch 35/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0625 - dice_coef: 0.0625 - accuracy: 0.0314 - val_loss: -0.0464 - val_dice_coef: 0.0464 - val_accuracy: 0.0233
# Epoch 36/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0623 - dice_coef: 0.0623 - accuracy: 0.0314 - val_loss: -0.0464 - val_dice_coef: 0.0464 - val_accuracy: 0.0233
# Epoch 37/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0623 - dice_coef: 0.0623 - accuracy: 0.0314 - val_loss: -0.0465 - val_dice_coef: 0.0465 - val_accuracy: 0.0233
# Epoch 38/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0633 - dice_coef: 0.0633 - accuracy: 0.0314 - val_loss: -0.0465 - val_dice_coef: 0.0465 - val_accuracy: 0.0233
# Epoch 39/100
# 50/50 [==============================] - 2s 33ms/step - loss: -0.0626 - dice_coef: 0.0626 - accuracy: 0.0314 - val_loss: -0.0465 - val_dice_coef: 0.0465 - val_accuracy: 0.0233
# Epoch 40/100
# 50/50 [==============================] - 2s 32ms/step - loss: -0.0630 - dice_coef: 0.0630 - accuracy: 0.0314 - val_loss: -0.0465 - val_dice_coef: 0.0465 - val_accuracy: 0.0233
# Epoch 41/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0628 - dice_coef: 0.0628 - accuracy: 0.0314 - val_loss: -0.0466 - val_dice_coef: 0.0466 - val_accuracy: 0.0233
# Epoch 42/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0630 - dice_coef: 0.0630 - accuracy: 0.0314 - val_loss: -0.0465 - val_dice_coef: 0.0465 - val_accuracy: 0.0233
# Epoch 43/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0618 - dice_coef: 0.0618 - accuracy: 0.0314 - val_loss: -0.0466 - val_dice_coef: 0.0466 - val_accuracy: 0.0233
# Epoch 44/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0620 - dice_coef: 0.0620 - accuracy: 0.0314 - val_loss: -0.0466 - val_dice_coef: 0.0466 - val_accuracy: 0.0233
# Epoch 45/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0629 - dice_coef: 0.0629 - accuracy: 0.0314 - val_loss: -0.0466 - val_dice_coef: 0.0466 - val_accuracy: 0.0233
# Epoch 46/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0626 - dice_coef: 0.0626 - accuracy: 0.0314 - val_loss: -0.0467 - val_dice_coef: 0.0467 - val_accuracy: 0.0233
# Epoch 47/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0635 - dice_coef: 0.0635 - accuracy: 0.0314 - val_loss: -0.0466 - val_dice_coef: 0.0466 - val_accuracy: 0.0233
# Epoch 48/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0628 - dice_coef: 0.0628 - accuracy: 0.0314 - val_loss: -0.0467 - val_dice_coef: 0.0467 - val_accuracy: 0.0233
# Epoch 49/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0623 - dice_coef: 0.0623 - accuracy: 0.0314 - val_loss: -0.0467 - val_dice_coef: 0.0467 - val_accuracy: 0.0233
# Epoch 50/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0626 - dice_coef: 0.0626 - accuracy: 0.0314 - val_loss: -0.0467 - val_dice_coef: 0.0467 - val_accuracy: 0.0233
# Epoch 51/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0633 - dice_coef: 0.0633 - accuracy: 0.0314 - val_loss: -0.0466 - val_dice_coef: 0.0466 - val_accuracy: 0.0233
# Epoch 52/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0635 - dice_coef: 0.0635 - accuracy: 0.0314 - val_loss: -0.0468 - val_dice_coef: 0.0468 - val_accuracy: 0.0233
# Epoch 53/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0628 - dice_coef: 0.0628 - accuracy: 0.0314 - val_loss: -0.0468 - val_dice_coef: 0.0468 - val_accuracy: 0.0233
# Epoch 54/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0634 - dice_coef: 0.0634 - accuracy: 0.0314 - val_loss: -0.0469 - val_dice_coef: 0.0469 - val_accuracy: 0.0233
# Epoch 55/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0631 - dice_coef: 0.0631 - accuracy: 0.0314 - val_loss: -0.0469 - val_dice_coef: 0.0469 - val_accuracy: 0.0233
# Epoch 56/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0634 - dice_coef: 0.0634 - accuracy: 0.0315 - val_loss: -0.0468 - val_dice_coef: 0.0468 - val_accuracy: 0.0462
# Epoch 57/100
# 50/50 [==============================] - 2s 32ms/step - loss: -0.0630 - dice_coef: 0.0630 - accuracy: 0.4822 - val_loss: -0.0469 - val_dice_coef: 0.0469 - val_accuracy: 0.3996
# Epoch 58/100
# 50/50 [==============================] - 2s 32ms/step - loss: -0.0633 - dice_coef: 0.0633 - accuracy: 0.8302 - val_loss: -0.0469 - val_dice_coef: 0.0469 - val_accuracy: 0.4155
# Epoch 59/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0623 - dice_coef: 0.0623 - accuracy: 0.8385 - val_loss: -0.0469 - val_dice_coef: 0.0469 - val_accuracy: 0.4657
# Epoch 60/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0636 - dice_coef: 0.0636 - accuracy: 0.8420 - val_loss: -0.0469 - val_dice_coef: 0.0469 - val_accuracy: 0.3053
# Epoch 61/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0635 - dice_coef: 0.0635 - accuracy: 0.8690 - val_loss: -0.0469 - val_dice_coef: 0.0469 - val_accuracy: 0.3559
# Epoch 62/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0634 - dice_coef: 0.0634 - accuracy: 0.8760 - val_loss: -0.0470 - val_dice_coef: 0.0470 - val_accuracy: 0.7891
# Epoch 63/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0632 - dice_coef: 0.0632 - accuracy: 0.8837 - val_loss: -0.0470 - val_dice_coef: 0.0470 - val_accuracy: 0.6346
# Epoch 64/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0634 - dice_coef: 0.0634 - accuracy: 0.8849 - val_loss: -0.0471 - val_dice_coef: 0.0471 - val_accuracy: 0.7463
# Epoch 65/100
# 50/50 [==============================] - 2s 32ms/step - loss: -0.0639 - dice_coef: 0.0639 - accuracy: 0.8837 - val_loss: -0.0471 - val_dice_coef: 0.0471 - val_accuracy: 0.6704
# Epoch 66/100
# 50/50 [==============================] - 2s 33ms/step - loss: -0.0634 - dice_coef: 0.0634 - accuracy: 0.8860 - val_loss: -0.0471 - val_dice_coef: 0.0471 - val_accuracy: 0.7096
# Epoch 67/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0640 - dice_coef: 0.0640 - accuracy: 0.8837 - val_loss: -0.0470 - val_dice_coef: 0.0470 - val_accuracy: 0.4978
# Epoch 68/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0628 - dice_coef: 0.0628 - accuracy: 0.8840 - val_loss: -0.0472 - val_dice_coef: 0.0472 - val_accuracy: 0.7589
# Epoch 69/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0639 - dice_coef: 0.0639 - accuracy: 0.8970 - val_loss: -0.0472 - val_dice_coef: 0.0472 - val_accuracy: 0.7463
# Epoch 70/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0635 - dice_coef: 0.0635 - accuracy: 0.8906 - val_loss: -0.0470 - val_dice_coef: 0.0470 - val_accuracy: 0.5093
# Epoch 71/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0636 - dice_coef: 0.0636 - accuracy: 0.8899 - val_loss: -0.0472 - val_dice_coef: 0.0472 - val_accuracy: 0.7546
# Epoch 72/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0647 - dice_coef: 0.0647 - accuracy: 0.9009 - val_loss: -0.0472 - val_dice_coef: 0.0472 - val_accuracy: 0.7606
# Epoch 73/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0635 - dice_coef: 0.0635 - accuracy: 0.8933 - val_loss: -0.0473 - val_dice_coef: 0.0473 - val_accuracy: 0.7963
# Epoch 74/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0635 - dice_coef: 0.0635 - accuracy: 0.8938 - val_loss: -0.0473 - val_dice_coef: 0.0473 - val_accuracy: 0.8687
# Epoch 75/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0641 - dice_coef: 0.0641 - accuracy: 0.9041 - val_loss: -0.0473 - val_dice_coef: 0.0473 - val_accuracy: 0.8489
# Epoch 76/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0644 - dice_coef: 0.0644 - accuracy: 0.9074 - val_loss: -0.0474 - val_dice_coef: 0.0474 - val_accuracy: 0.8469
# Epoch 77/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0647 - dice_coef: 0.0647 - accuracy: 0.9073 - val_loss: -0.0473 - val_dice_coef: 0.0473 - val_accuracy: 0.7908
# Epoch 78/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0647 - dice_coef: 0.0647 - accuracy: 0.9043 - val_loss: -0.0474 - val_dice_coef: 0.0474 - val_accuracy: 0.8376
# Epoch 79/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0642 - dice_coef: 0.0642 - accuracy: 0.9105 - val_loss: -0.0474 - val_dice_coef: 0.0474 - val_accuracy: 0.8900
# Epoch 80/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0638 - dice_coef: 0.0638 - accuracy: 0.9060 - val_loss: -0.0475 - val_dice_coef: 0.0475 - val_accuracy: 0.8803
# Epoch 81/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0639 - dice_coef: 0.0639 - accuracy: 0.9057 - val_loss: -0.0474 - val_dice_coef: 0.0474 - val_accuracy: 0.8190
# Epoch 82/100
# 50/50 [==============================] - 2s 30ms/step - loss: -0.0637 - dice_coef: 0.0637 - accuracy: 0.9092 - val_loss: -0.0475 - val_dice_coef: 0.0475 - val_accuracy: 0.8501
# Epoch 83/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0645 - dice_coef: 0.0645 - accuracy: 0.9070 - val_loss: -0.0475 - val_dice_coef: 0.0475 - val_accuracy: 0.8387
# Epoch 84/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0646 - dice_coef: 0.0646 - accuracy: 0.9060 - val_loss: -0.0474 - val_dice_coef: 0.0474 - val_accuracy: 0.7513
# Epoch 85/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0646 - dice_coef: 0.0646 - accuracy: 0.9100 - val_loss: -0.0476 - val_dice_coef: 0.0476 - val_accuracy: 0.8963
# Epoch 86/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0640 - dice_coef: 0.0640 - accuracy: 0.9129 - val_loss: -0.0476 - val_dice_coef: 0.0476 - val_accuracy: 0.8991
# Epoch 87/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0647 - dice_coef: 0.0647 - accuracy: 0.9129 - val_loss: -0.0476 - val_dice_coef: 0.0476 - val_accuracy: 0.8693
# Epoch 88/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0637 - dice_coef: 0.0637 - accuracy: 0.9097 - val_loss: -0.0477 - val_dice_coef: 0.0477 - val_accuracy: 0.8972
# Epoch 89/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0642 - dice_coef: 0.0642 - accuracy: 0.9125 - val_loss: -0.0476 - val_dice_coef: 0.0476 - val_accuracy: 0.8616
# Epoch 90/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0643 - dice_coef: 0.0643 - accuracy: 0.9072 - val_loss: -0.0477 - val_dice_coef: 0.0477 - val_accuracy: 0.8878
# Epoch 91/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0646 - dice_coef: 0.0646 - accuracy: 0.9121 - val_loss: -0.0477 - val_dice_coef: 0.0477 - val_accuracy: 0.8807
# Epoch 92/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0647 - dice_coef: 0.0647 - accuracy: 0.9092 - val_loss: -0.0477 - val_dice_coef: 0.0477 - val_accuracy: 0.8886
# Epoch 93/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0645 - dice_coef: 0.0645 - accuracy: 0.9086 - val_loss: -0.0477 - val_dice_coef: 0.0477 - val_accuracy: 0.8687
# Epoch 94/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0650 - dice_coef: 0.0650 - accuracy: 0.9068 - val_loss: -0.0477 - val_dice_coef: 0.0477 - val_accuracy: 0.8032
# Epoch 95/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0642 - dice_coef: 0.0642 - accuracy: 0.9058 - val_loss: -0.0477 - val_dice_coef: 0.0477 - val_accuracy: 0.7978
# Epoch 96/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0642 - dice_coef: 0.0642 - accuracy: 0.9028 - val_loss: -0.0478 - val_dice_coef: 0.0478 - val_accuracy: 0.8712
# Epoch 97/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0649 - dice_coef: 0.0649 - accuracy: 0.9070 - val_loss: -0.0478 - val_dice_coef: 0.0478 - val_accuracy: 0.8844
# Epoch 98/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0647 - dice_coef: 0.0647 - accuracy: 0.9052 - val_loss: -0.0478 - val_dice_coef: 0.0478 - val_accuracy: 0.8461
# Epoch 99/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0648 - dice_coef: 0.0648 - accuracy: 0.9064 - val_loss: -0.0479 - val_dice_coef: 0.0479 - val_accuracy: 0.8827
# Epoch 100/100
# 50/50 [==============================] - 2s 31ms/step - loss: -0.0654 - dice_coef: 0.0654 - accuracy: 0.9017 - val_loss: -0.0479 - val_dice_coef: 0.0479 - val_accuracy: 0.8616

# %%
import pickle
import time
timestr = time.strftime("%Y%m%d-%H%M%S")
root_path = './training_results/Without_NAIP/'
# save the trained model
model_yaml = transfered_model.to_yaml()
with open(root_path+"model_transfere_learning_No_NAIP_700_samples_"+timestr+".yaml", "w") as yaml_file:
    yaml_file.write(model_yaml)
# save the weights
transfered_model.save(root_path+"model_transfere_learning_No_NAIP_700_samples_"+timestr+".h5")
# save the intermdediate results and training statistics
with open(root_path+"history_transfere_learning_No_NAIP_700_samples_"+timestr+".pickle", 'wb') as file_pi:
    pickle.dump(tranfer_learning_history.history, file_pi, protocol=2)

# %% [markdown]
# ## Second pass

# %%
for (index, layer) in enumerate(transfered_model.layers):
    layer.trainable = True

# %%
patch_size = 224
IMG_WIDTH = patch_size
IMG_HEIGHT = patch_size
# Number of feature channels 
INPUT_CHANNELS = 8
# Number of output masks (1 in case you predict only one type of objects)
OUTPUT_MASK_CHANNELS = 1
maxepoch = 100
# hyperparameters
# 100 times smaller learning rate
learning_rate = 0.0000359
patience = 20
aug = 'v'
transfered_model.compile(optimizer=Adam(lr=learning_rate),loss = dice_coef_loss,metrics=[dice_coef,'accuracy'])
callbacks = [
        ReduceLROnPlateau(monitor='val_loss', factor=0.7, patience=patience, min_lr=1e-9, verbose=1, mode='min'),
        EarlyStopping(monitor='val_loss', patience=patience+10, verbose=0),
        ModelCheckpoint('model'+aug+'_attention2.h5', monitor='val_loss', save_best_only=True, verbose=0),
    ]

# %%
fine_tuned_model = transfered_model.fit(X_train_new, Y_train, validation_data=(X_Validation_new,Y_Validation), batch_size=2, epochs=maxepoch, callbacks=callbacks)
# Out:
# Train on 50 samples, validate on 50 samples
# Epoch 1/100
# 50/50 [==============================] - 15s 292ms/step - loss: -0.0666 - dice_coef: 0.0666 - accuracy: 0.9112 - val_loss: -0.0486 - val_dice_coef: 0.0486 - val_accuracy: 0.6207
# Epoch 2/100
# 50/50 [==============================] - 4s 86ms/step - loss: -0.0669 - dice_coef: 0.0669 - accuracy: 0.9041 - val_loss: -0.0484 - val_dice_coef: 0.0484 - val_accuracy: 0.9226
# Epoch 3/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0671 - dice_coef: 0.0671 - accuracy: 0.9310 - val_loss: -0.0492 - val_dice_coef: 0.0492 - val_accuracy: 0.9151
# Epoch 4/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0675 - dice_coef: 0.0675 - accuracy: 0.9390 - val_loss: -0.0486 - val_dice_coef: 0.0486 - val_accuracy: 0.9431
# Epoch 5/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0680 - dice_coef: 0.0680 - accuracy: 0.9502 - val_loss: -0.0492 - val_dice_coef: 0.0492 - val_accuracy: 0.9354
# Epoch 6/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0682 - dice_coef: 0.0682 - accuracy: 0.9558 - val_loss: -0.0490 - val_dice_coef: 0.0490 - val_accuracy: 0.9443
# Epoch 7/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0678 - dice_coef: 0.0678 - accuracy: 0.9515 - val_loss: -0.0491 - val_dice_coef: 0.0491 - val_accuracy: 0.9465
# Epoch 8/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0687 - dice_coef: 0.0687 - accuracy: 0.9653 - val_loss: -0.0489 - val_dice_coef: 0.0489 - val_accuracy: 0.9507
# Epoch 9/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0689 - dice_coef: 0.0689 - accuracy: 0.9625 - val_loss: -0.0484 - val_dice_coef: 0.0484 - val_accuracy: 0.9594
# Epoch 10/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0680 - dice_coef: 0.0680 - accuracy: 0.9696 - val_loss: -0.0481 - val_dice_coef: 0.0481 - val_accuracy: 0.9689
# Epoch 11/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0683 - dice_coef: 0.0683 - accuracy: 0.9642 - val_loss: -0.0483 - val_dice_coef: 0.0483 - val_accuracy: 0.9616
# Epoch 12/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0685 - dice_coef: 0.0685 - accuracy: 0.9702 - val_loss: -0.0483 - val_dice_coef: 0.0483 - val_accuracy: 0.9660
# Epoch 13/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0686 - dice_coef: 0.0686 - accuracy: 0.9722 - val_loss: -0.0481 - val_dice_coef: 0.0481 - val_accuracy: 0.9717
# Epoch 14/100
# 50/50 [==============================] - 4s 84ms/step - loss: -0.0680 - dice_coef: 0.0680 - accuracy: 0.9719 - val_loss: -0.0480 - val_dice_coef: 0.0480 - val_accuracy: 0.9747
# Epoch 15/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0692 - dice_coef: 0.0692 - accuracy: 0.9808 - val_loss: -0.0480 - val_dice_coef: 0.0480 - val_accuracy: 0.9744
# Epoch 16/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0686 - dice_coef: 0.0686 - accuracy: 0.9769 - val_loss: -0.0478 - val_dice_coef: 0.0478 - val_accuracy: 0.9765
# Epoch 17/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0693 - dice_coef: 0.0693 - accuracy: 0.9795 - val_loss: -0.0480 - val_dice_coef: 0.0480 - val_accuracy: 0.9761
# Epoch 18/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0689 - dice_coef: 0.0689 - accuracy: 0.9816 - val_loss: -0.0479 - val_dice_coef: 0.0479 - val_accuracy: 0.9768
# Epoch 19/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0692 - dice_coef: 0.0692 - accuracy: 0.9824 - val_loss: -0.0480 - val_dice_coef: 0.0480 - val_accuracy: 0.9762
# Epoch 20/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0688 - dice_coef: 0.0688 - accuracy: 0.9826 - val_loss: -0.0480 - val_dice_coef: 0.0480 - val_accuracy: 0.9759
# Epoch 21/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0691 - dice_coef: 0.0691 - accuracy: 0.9852 - val_loss: -0.0480 - val_dice_coef: 0.0480 - val_accuracy: 0.9754
# Epoch 22/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0693 - dice_coef: 0.0693 - accuracy: 0.9830 - val_loss: -0.0479 - val_dice_coef: 0.0479 - val_accuracy: 0.9772
# Epoch 23/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0686 - dice_coef: 0.0686 - accuracy: 0.9847 - val_loss: -0.0479 - val_dice_coef: 0.0479 - val_accuracy: 0.9763
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 2.5130000358331015e-05.
# Epoch 24/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0684 - dice_coef: 0.0684 - accuracy: 0.9807 - val_loss: -0.0479 - val_dice_coef: 0.0479 - val_accuracy: 0.9763
# Epoch 25/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0686 - dice_coef: 0.0686 - accuracy: 0.9857 - val_loss: -0.0479 - val_dice_coef: 0.0479 - val_accuracy: 0.9760
# Epoch 26/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0695 - dice_coef: 0.0695 - accuracy: 0.9879 - val_loss: -0.0480 - val_dice_coef: 0.0480 - val_accuracy: 0.9742
# Epoch 27/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0690 - dice_coef: 0.0690 - accuracy: 0.9829 - val_loss: -0.0480 - val_dice_coef: 0.0480 - val_accuracy: 0.9761
# Epoch 28/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0697 - dice_coef: 0.0697 - accuracy: 0.9828 - val_loss: -0.0479 - val_dice_coef: 0.0479 - val_accuracy: 0.9761
# Epoch 29/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0692 - dice_coef: 0.0692 - accuracy: 0.9862 - val_loss: -0.0478 - val_dice_coef: 0.0478 - val_accuracy: 0.9766
# Epoch 30/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0685 - dice_coef: 0.0685 - accuracy: 0.9784 - val_loss: -0.0479 - val_dice_coef: 0.0479 - val_accuracy: 0.9753
# Epoch 31/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0682 - dice_coef: 0.0682 - accuracy: 0.9844 - val_loss: -0.0481 - val_dice_coef: 0.0481 - val_accuracy: 0.9718
# Epoch 32/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0697 - dice_coef: 0.0697 - accuracy: 0.9874 - val_loss: -0.0479 - val_dice_coef: 0.0479 - val_accuracy: 0.9698
# Epoch 33/100
# 50/50 [==============================] - 4s 85ms/step - loss: -0.0692 - dice_coef: 0.0692 - accuracy: 0.9881 - val_loss: -0.0480 - val_dice_coef: 0.0480 - val_accuracy: 0.9714

# %%
import pickle
import time
timestr = time.strftime("%Y%m%d-%H%M%S")
root_path = './training_results/Without_NAIP/'
# save the trained model
model_yaml = transfered_model.to_yaml()
with open(root_path+"model_transfere_learning_No_NAIP_700_samples_"+timestr+".yaml", "w") as yaml_file:
    yaml_file.write(model_yaml)
# save the weights
transfered_model.save(root_path+"model_transfere_learning_No_NAIP_700_samples_"+timestr+".h5")
# save the intermdediate rescults and training statistics
with open(root_path+"history_transfere_learning_No_NAIP_700_samples_"+timestr+".pickle", 'wb') as file_pi:
    pickle.dump(tranfer_learning_history.history, file_pi, protocol=2)

# %% [markdown]
# ## Plots

# %%
# first pass 
training_loss = tranfer_learning_history.history['loss']
validation_loss = tranfer_learning_history.history['val_loss']

training_accuracy = tranfer_learning_history.history['accuracy']
validation_accuracy = tranfer_learning_history.history['val_accuracy']

training_dice = tranfer_learning_history.history['dice_coef']
validation_dice = tranfer_learning_history.history['val_dice_coef']

# fine_tuned_model.history

training_loss += fine_tuned_model.history['loss']
validation_loss += fine_tuned_model.history['val_loss']

training_accuracy += fine_tuned_model.history['accuracy']
validation_accuracy +=  fine_tuned_model.history['val_accuracy']

training_dice += fine_tuned_model.history['dice_coef']
validation_dice +=  fine_tuned_model.history['val_dice_coef']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 8))
plt.subplot(1,3, 1)
plt.plot(training_accuracy, label='Training Accuracy')
plt.plot(validation_accuracy, label='Validation Accuracy')
# plt.ylim([0, 1])
plt.plot([99,99], plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 3, 2)
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
# plt.ylim([0, 1.0])
plt.plot([99,99],  plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')

plt.subplot(1, 3, 3)
plt.plot(training_dice, label='Training Dice Coeff')
plt.plot(validation_dice, label='Validation  Dice Coeff')
# plt.ylim([0, 1.0])
plt.plot([99,99],  plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Dice Coeff')
plt.xlabel('epoch')

plt.show()

# %% [markdown]
# #
#
# ---
#
# .

# %%
import pickle
import time
timestr = time.strftime("%Y%m%d-%H%M%S")
root_path = './training_results/Without_NAIP/'
# save the trained model
model_yaml = transfered_model.to_yaml()
with open(root_path+"model_transfere_learning_No_NAIP_700_samples_"+timestr+".yaml", "w") as yaml_file:
    yaml_file.write(model_yaml)
# save the weights
transfered_model.save(root_path+"model_transfere_learning_No_NAIP_700_samples_"+timestr+".h5")
# save the intermdediate results and training statistics
with open(root_path+"history_transfere_learning_No_NAIP_700_samples_"+timestr+".pickle", 'wb') as file_pi:
    pickle.dump(ltranfer_learning_results.history, file_pi, protocol=2)

# %% [markdown]
# ### Will wait for the whole area data to do prediction

# %%
root_path = './training_results/Without_NAIP/'
loaded_model = load_model(root_path+"model_transfere_learning_No_NAIP_700_samples_20201116-121041.h5", 
                             custom_objects={'multiplication': multiplication,'multiplication2': multiplication2, 
                                             'dice_coef_loss':dice_coef_loss, 'dice_coef':dice_coef,})

for (index, layer) in enumerate(loaded_model.layers):
    layer.trainable = True

# %%
patch_size = 224
IMG_WIDTH = patch_size
IMG_HEIGHT = patch_size
# Number of feature channels 
INPUT_CHANNELS = 8
# Number of output masks (1 in case you predict only one type of objects)
OUTPUT_MASK_CHANNELS = 1
maxepoch = 100
# hyperparameters
# 100 times smaller learning rate
learning_rate = 0.0000359
patience = 20
aug = 'v'
loaded_model.compile(optimizer=Adam(lr=learning_rate),loss = dice_coef_loss,metrics=[dice_coef,'accuracy'])
callbacks = [
        ReduceLROnPlateau(monitor='val_loss', factor=0.7, patience=patience, min_lr=1e-9, verbose=1, mode='min'),
        EarlyStopping(monitor='val_loss', patience=patience+10, verbose=0),
        ModelCheckpoint('model'+aug+'_attention2.h5', monitor='val_loss', save_best_only=True, verbose=0),
    ]

# %%
fine_tuned_model = loaded_model.fit(X_train_new, Y_train, validation_data=(X_Validation_new,Y_Validation), batch_size=2, epochs=maxepoch, callbacks=callbacks)
# Out:
# Train on 350 samples, validate on 350 samples
# Epoch 1/100
# 350/350 [==============================] - 43s 122ms/step - loss: -0.1419 - dice_coef: 0.1419 - accuracy: 0.9432 - val_loss: -0.0814 - val_dice_coef: 0.0814 - val_accuracy: 0.9769
# Epoch 2/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1457 - dice_coef: 0.1457 - accuracy: 0.9539 - val_loss: -0.0830 - val_dice_coef: 0.0830 - val_accuracy: 0.9652
# Epoch 3/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1485 - dice_coef: 0.1485 - accuracy: 0.9582 - val_loss: -0.0862 - val_dice_coef: 0.0862 - val_accuracy: 0.9656
# Epoch 4/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1510 - dice_coef: 0.1510 - accuracy: 0.9650 - val_loss: -0.0866 - val_dice_coef: 0.0866 - val_accuracy: 0.9747
# Epoch 5/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1524 - dice_coef: 0.1524 - accuracy: 0.9678 - val_loss: -0.0845 - val_dice_coef: 0.0845 - val_accuracy: 0.9714
# Epoch 6/100
# 350/350 [==============================] - 30s 84ms/step - loss: -0.1545 - dice_coef: 0.1545 - accuracy: 0.9673 - val_loss: -0.0842 - val_dice_coef: 0.0842 - val_accuracy: 0.9681
# Epoch 7/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1544 - dice_coef: 0.1544 - accuracy: 0.9689 - val_loss: -0.0906 - val_dice_coef: 0.0906 - val_accuracy: 0.9571
# Epoch 8/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1589 - dice_coef: 0.1589 - accuracy: 0.9732 - val_loss: -0.0825 - val_dice_coef: 0.0825 - val_accuracy: 0.9755
# Epoch 9/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1585 - dice_coef: 0.1585 - accuracy: 0.9753 - val_loss: -0.0860 - val_dice_coef: 0.0860 - val_accuracy: 0.9731
# Epoch 10/100
# 350/350 [==============================] - 30s 84ms/step - loss: -0.1620 - dice_coef: 0.1620 - accuracy: 0.9788 - val_loss: -0.0851 - val_dice_coef: 0.0851 - val_accuracy: 0.9754
# Epoch 11/100
# 350/350 [==============================] - 30s 85ms/step - loss: -0.1598 - dice_coef: 0.1598 - accuracy: 0.9737 - val_loss: -0.0824 - val_dice_coef: 0.0824 - val_accuracy: 0.9729
# Epoch 12/100
# 350/350 [==============================] - 30s 85ms/step - loss: -0.1623 - dice_coef: 0.1623 - accuracy: 0.9765 - val_loss: -0.0904 - val_dice_coef: 0.0904 - val_accuracy: 0.9681
# Epoch 13/100
# 350/350 [==============================] - 30s 85ms/step - loss: -0.1629 - dice_coef: 0.1629 - accuracy: 0.9780 - val_loss: -0.0860 - val_dice_coef: 0.0860 - val_accuracy: 0.9696
# Epoch 14/100
# 350/350 [==============================] - 30s 84ms/step - loss: -0.1653 - dice_coef: 0.1653 - accuracy: 0.9813 - val_loss: -0.0861 - val_dice_coef: 0.0861 - val_accuracy: 0.9694
# Epoch 15/100
# 350/350 [==============================] - 30s 84ms/step - loss: -0.1643 - dice_coef: 0.1643 - accuracy: 0.9812 - val_loss: -0.0882 - val_dice_coef: 0.0882 - val_accuracy: 0.9681
# Epoch 16/100
# 350/350 [==============================] - 30s 84ms/step - loss: -0.1658 - dice_coef: 0.1658 - accuracy: 0.9819 - val_loss: -0.0835 - val_dice_coef: 0.0835 - val_accuracy: 0.9781
# Epoch 17/100
# 350/350 [==============================] - 30s 84ms/step - loss: -0.1658 - dice_coef: 0.1658 - accuracy: 0.9828 - val_loss: -0.0827 - val_dice_coef: 0.0827 - val_accuracy: 0.9789
# Epoch 18/100
# 350/350 [==============================] - 30s 85ms/step - loss: -0.1664 - dice_coef: 0.1664 - accuracy: 0.9821 - val_loss: -0.0836 - val_dice_coef: 0.0836 - val_accuracy: 0.9771
# Epoch 19/100
# 350/350 [==============================] - 30s 84ms/step - loss: -0.1693 - dice_coef: 0.1693 - accuracy: 0.9836 - val_loss: -0.0827 - val_dice_coef: 0.0827 - val_accuracy: 0.9802
# Epoch 20/100
# 350/350 [==============================] - 30s 84ms/step - loss: -0.1692 - dice_coef: 0.1692 - accuracy: 0.9843 - val_loss: -0.0870 - val_dice_coef: 0.0870 - val_accuracy: 0.9773
# Epoch 21/100
# 350/350 [==============================] - 30s 84ms/step - loss: -0.1702 - dice_coef: 0.1702 - accuracy: 0.9859 - val_loss: -0.0883 - val_dice_coef: 0.0883 - val_accuracy: 0.9615
# Epoch 22/100
# 350/350 [==============================] - 30s 84ms/step - loss: -0.1707 - dice_coef: 0.1707 - accuracy: 0.9856 - val_loss: -0.0843 - val_dice_coef: 0.0843 - val_accuracy: 0.9783
# Epoch 23/100
# 350/350 [==============================] - 30s 84ms/step - loss: -0.1716 - dice_coef: 0.1716 - accuracy: 0.9859 - val_loss: -0.0861 - val_dice_coef: 0.0861 - val_accuracy: 0.9729
# Epoch 24/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1719 - dice_coef: 0.1719 - accuracy: 0.9867 - val_loss: -0.0855 - val_dice_coef: 0.0855 - val_accuracy: 0.9732
# Epoch 25/100
# 350/350 [==============================] - 30s 84ms/step - loss: -0.1722 - dice_coef: 0.1722 - accuracy: 0.9859 - val_loss: -0.0862 - val_dice_coef: 0.0862 - val_accuracy: 0.9789
# Epoch 26/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1735 - dice_coef: 0.1735 - accuracy: 0.9873 - val_loss: -0.0779 - val_dice_coef: 0.0779 - val_accuracy: 0.9798
# Epoch 27/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1734 - dice_coef: 0.1734 - accuracy: 0.9857 - val_loss: -0.0884 - val_dice_coef: 0.0884 - val_accuracy: 0.9715
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 2.5130000358331015e-05.
# Epoch 28/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1747 - dice_coef: 0.1747 - accuracy: 0.9882 - val_loss: -0.0864 - val_dice_coef: 0.0864 - val_accuracy: 0.9799
# Epoch 29/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1758 - dice_coef: 0.1758 - accuracy: 0.9890 - val_loss: -0.0892 - val_dice_coef: 0.0892 - val_accuracy: 0.9775
# Epoch 30/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1768 - dice_coef: 0.1768 - accuracy: 0.9904 - val_loss: -0.0867 - val_dice_coef: 0.0867 - val_accuracy: 0.9820
# Epoch 31/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1781 - dice_coef: 0.1781 - accuracy: 0.9903 - val_loss: -0.0853 - val_dice_coef: 0.0853 - val_accuracy: 0.9831
# Epoch 32/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1779 - dice_coef: 0.1779 - accuracy: 0.9908 - val_loss: -0.0874 - val_dice_coef: 0.0874 - val_accuracy: 0.9812
# Epoch 33/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1784 - dice_coef: 0.1784 - accuracy: 0.9900 - val_loss: -0.0840 - val_dice_coef: 0.0840 - val_accuracy: 0.9830
# Epoch 34/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1803 - dice_coef: 0.1803 - accuracy: 0.9920 - val_loss: -0.0878 - val_dice_coef: 0.0878 - val_accuracy: 0.9780
# Epoch 35/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1775 - dice_coef: 0.1775 - accuracy: 0.9908 - val_loss: -0.0840 - val_dice_coef: 0.0840 - val_accuracy: 0.9822
# Epoch 36/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1800 - dice_coef: 0.1800 - accuracy: 0.9904 - val_loss: -0.0858 - val_dice_coef: 0.0858 - val_accuracy: 0.9816
# Epoch 37/100
# 350/350 [==============================] - 29s 84ms/step - loss: -0.1798 - dice_coef: 0.1798 - accuracy: 0.9904 - val_loss: -0.0864 - val_dice_coef: 0.0864 - val_accuracy: 0.9832

# %%
import pickle
import time
timestr = time.strftime("%Y%m%d-%H%M%S")
root_path = './training_results/Without_NAIP/'
# save the trained model
model_yaml = loaded_model.to_yaml()
with open(root_path+"model_fine_tuning_No_NAIP_700_samples"+timestr+".yaml", "w") as yaml_file:
    yaml_file.write(model_yaml)
# save the weights
loaded_model.save(root_path+"model_fine_tuning_learning_No_NAIP_700_samples"+timestr+".h5")
# save the intermdediate results and training statistics
with open(root_path+"history_fine_tuning_learning_No_NAIP_700_samples"+timestr+".pickle", 'wb') as file_pi:
    pickle.dump(fine_tuned_model.history, file_pi, protocol=2)
